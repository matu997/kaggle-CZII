# %%
import numpy as np


image = np.load('../analyze/train_image_TS_5_4.npy')
label = np.load('../analyze/train_label_TS_5_4.npy')

print(image.shape, label.shape)
# Out:
# (184, 630, 630) (184, 630, 630)

# %%
#imageを表示
import matplotlib.pyplot as plt

plt.imshow(image[32], cmap='gray')
plt.show()

# %%
plt.imshow(label[32], cmap='gray')
plt.show()
