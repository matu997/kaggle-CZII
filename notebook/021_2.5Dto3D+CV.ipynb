# %%
from helpers import *
from dataset import *
from model2 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
DEBAG = False

# %%
mask_size2 = {key: math.floor(value * 0.7) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 4,
#  'beta-galactosidase': 6,
#  'ribosome': 10,
#  'thyroglobulin': 9,
#  'virus-like-particle': 9}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.05,
    },
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_99_9",]

volumes = np.empty((len(valid_id), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id), 184, 630, 630), dtype=np.uint8)

for idx in range(len(valid_id)):
    data = read_one_data(valid_id[idx], train_dir)
    data = data.astype(np.float32)
    volumes[idx, :, :, :] = data
    
    y = read_one_truth(valid_id[idx], mask_dir)
    mask_data = generate_mask(y, mask_size2)
    mask_data = mask_data.astype(np.uint8)
    masks[idx, :, :, :] = mask_data

print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (6, 184, 630, 630)
# (6, 184, 630, 630)

# %%
vol_data = []
mask_data = []
for exp in range(len(valid_id)):
    vol_slices_list = []
    mask_slices_list = []

    volume = volumes[exp, :, :, :]
    mask = masks[exp, :, :, :]
    print("exp=", exp)
    
    #何もなし
    vol_slices,mask_slices=process_rotation_and_slicing(volume, mask, anglex=0, angley=0, anglez=0, zz_range=range(48, 184, 16))
    vol_slices_list.append(vol_slices)
    mask_slices_list.append(mask_slices)
    print("vol_slices shape:", vol_slices.shape)
    if DEBAG:
        combined_vol_slices = np.concatenate(vol_slices_list, axis=0)
        combined_mask_slices = np.concatenate(mask_slices_list, axis=0)

        vol_data.append(combined_vol_slices)
        mask_data.append(combined_mask_slices)
        continue
    # 180度回転
    vol_slices,mask_slices=process_rotation_and_slicing(volume, mask, anglex=30, angley=0, anglez=0, zz_range=range(48, 184, 16))
    vol_slices_list.append(vol_slices)
    mask_slices_list.append(mask_slices)
    print("vol_slices shape:", vol_slices.shape)

    #斜め
    vol_slices,mask_slices=process_rotation_and_slicing(volume, mask, anglex=2, angley=2, anglez=2, zz_range=range(48, 184, 16))
    vol_slices_list.append(vol_slices)
    mask_slices_list.append(mask_slices)
    print("vol_slices shape:", vol_slices.shape)


    combined_vol_slices = np.concatenate(vol_slices_list, axis=0)
    combined_mask_slices = np.concatenate(mask_slices_list, axis=0)

    vol_data.append(combined_vol_slices)
    mask_data.append(combined_mask_slices)

vol_data = np.concatenate(vol_data, axis=0)
mask_data = np.concatenate(mask_data, axis=0)

print("vol_data shape:", vol_data.shape)
print("mask_data shape:", mask_data.shape)
# Out:
# exp= 0
# -58 -89 44
# 58 48 28
# 64 -63 12
# 60 -13 -4
# 6 59 -20
# -14 -47 -36
# 42 -65 -52
# 43 -59 -68
# -62 -23 -84
# vol_slices shape: (9, 32, 640, 640)
# 32 -25 44
# 39 22 28
# 9 50 12
# -71 20 -4
# -66 -70 -20
# -77 -98 -36
# 29 -7 -52
# 9 -99 -68
# -53 60 -84
# vol_slices shape: (9, 32, 640, 640)
# -60 100 44
# 35 -23 28
# -74 -78 12
# -95 28 -4
# -92 -97 -20
# -20 -19 -36
# 84 57 -52
# -22 29 -68
# -12 -77 -84
# vol_slices shape: (9, 32, 640, 640)
# exp= 1
# -79 -20 44
# -97 84 28
# -95 -86 12
# -65 84 -4
# -45 34 -20
# 84 4 -36
# -80 -45 -52
# -65 39 -68
# -52 39 -84
# vol_slices shape: (9, 32, 640, 640)
# 96 57 44
# -70 71 28
# -22 -93 12
# 68 -19 -4
# 15 6 -20
# -93 11 -36
# 92 8 -52
# -3 -36 -68
# 76 92 -84
# vol_slices shape: (9, 32, 640, 640)
# 86 66 44
# -15 26 28
# -99 -68 12
# 41 60 -4
# 55 52 -20
# 97 91 -36
# 26 68 -52
# 19 79 -68
# 60 -99 -84
# vol_slices shape: (9, 32, 640, 640)
# exp= 2
# 5 42 44
# 35 16 28
# -60 49 12
# 73 -15 -4
# 62 -74 -20
# -79 65 -36
# 73 6 -52
# 58 -67 -68
# -50 70 -84
# vol_slices shape: (9, 32, 640, 640)
# -4 -27 44
# -49 -80 28
# -71 -38 12
# -19 32 -4
# 47 -78 -20
# 91 -7 -36
# 36 78 -52
# -54 27 -68
# 18 55 -84
# vol_slices shape: (9, 32, 640, 640)
# 100 26 44
# 16 27 28
# -34 29 12
# 2 -90 -4
# 86 90 -20
# 29 76 -36
# -29 7 -52
# 74 65 -68
# 16 54 -84
# vol_slices shape: (9, 32, 640, 640)
# exp= 3
# -76 -10 44
# -34 -92 28
# -34 61 12
# 65 69 -4
# -72 -47 -20
# 74 -41 -36
# 27 0 -52
# -81 23 -68
# 33 88 -84
# vol_slices shape: (9, 32, 640, 640)
# -69 -7 44
# -57 -89 28
# -41 -25 12
# 46 -3 -4
# -48 -31 -20
# 95 -2 -36
# 62 -79 -52
# 20 -33 -68
# -94 -21 -84
# vol_slices shape: (9, 32, 640, 640)
# -32 -74 44
# 64 97 28
# -53 11 12
# -73 60 -4
# -86 9 -20
# 16 94 -36
# 69 -64 -52
# 63 -38 -68
# -84 -12 -84
# vol_slices shape: (9, 32, 640, 640)
# exp= 4
# 20 67 44
# -85 -27 28
# -64 -88 12
# -77 -36 -4
# 5 25 -20
# -100 67 -36
# 59 56 -52
# -5 38 -68
# -27 -10 -84
# vol_slices shape: (9, 32, 640, 640)
# 61 -67 44
# 0 61 28
# 23 -10 12
# -6 1 -4
# -40 89 -20
# 86 46 -36
# 26 -16 -52
# -59 16 -68
# -42 80 -84
# vol_slices shape: (9, 32, 640, 640)
# 36 -67 44
# -28 88 28
# 98 99 12
# -24 41 -4
# 19 -52 -20
# 32 29 -36
# 83 -14 -52
# 80 74 -68
# 6 -2 -84
# vol_slices shape: (9, 32, 640, 640)
# exp= 5
# -76 -59 44
# -93 -38 28
# -12 82 12
# 1 -49 -4
# 30 37 -20
# 15 51 -36
# -13 92 -52
# -68 -95 -68
# -26 -34 -84
# vol_slices shape: (9, 32, 640, 640)
# -52 -52 44
# 50 65 28
# -29 -32 12
# 44 54 -4
# 69 -75 -20
# 76 80 -36
# -98 -6 -52
# -69 -87 -68
# -72 -66 -84
# vol_slices shape: (9, 32, 640, 640)
# 46 -19 44
# 32 -70 28
# 31 -83 12
# -70 -2 -4
# -31 -94 -20
# -9 15 -36
# 80 -21 -52
# -86 -86 -68
# -65 76 -84
# vol_slices shape: (9, 32, 640, 640)
# vol_data shape: (162, 32, 640, 640)
# mask_data shape: (162, 32, 640, 640)

# %%
class VolumeDataset(Dataset):
    def __init__(self, vol_data, mask_data, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, 32, 640, 640) を想定
            mask_data (numpy.ndarray): 形状 (N, 32, 640, 640) を想定
            transform (callable, optional): 
                MONAIの辞書ベースのTransformsなどを含むパイプライン。
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.transform = transform

    def __len__(self):
        # サンプル数を返す
        return len(self.vol_data)

    def __getitem__(self, idx):
        # 1. Pythonの辞書形式でデータを作る
        data_dict = {
            "image": self.vol_data[idx],  # (32, 640, 640)
            "label": self.mask_data[idx], # (32, 640, 640)
        }

        # 2. 辞書ベースのトランスフォームを適用
        if self.transform:
            data_dict = self.transform(data_dict)

        # 3. 変換後のデータを取り出して返す
        volume = data_dict["image"]
        mask   = data_dict["label"]

        return volume, mask


# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    ToTensorD(keys=["image", "label"]),  # まずテンソルに変換
    NormalizeIntensityd(
        keys=["image"], 
        nonzero=False,      # ゼロ以外のボクセルに限定せず全体で正規化する例
        channel_wise=False  # チャネルごとの正規化をしない（1チャネル想定ならFalseでOK）
    ),
])

# %%
# Dataset のインスタンスを作成
dataset = VolumeDataset(vol_data, mask_data, transform=transforms)

# DataLoader のインスタンスを作成
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
net = Net(pretrained=True,cfg=None).cuda()
# Out:
# cuda

# %%
# 学習ループにCV計算を追加
num_epochs = 20
learning_rate = 1e-3
optimizer = torch.optim.AdamW(
    net.parameters(), 
    lr=learning_rate,
    weight_decay=0.01
)
scaler = torch.cuda.amp.GradScaler(init_scale=4096)
epoch_losses = []
cv_scores = []  # CVスコアの記録リスト

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(), 
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        batch = {
            'image': volumes.to(device).float(),
            'mask': masks.to(device).long(),
        }
        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss']

        running_loss += loss.item()

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_(net.parameters(), 1.0)
        scaler.step(optimizer)
        scaler.update()

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"損失: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score = evaluate_cv(net, test_id, cfg, valid_dir, device,mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/20
# ----------
# 損失: 0.7174
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.20554092526435852
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin  327  36    0    36  327        0.0     0.0      0.0
# 1         beta-amylase   42  21    0    21   42        0.0     0.0      0.0
# 2   beta-galactosidase    0  24    0    24    0        0.0     0.0      0.0
# 3             ribosome   48  65    0    65   48        0.0     0.0      0.0
# 4        thyroglobulin    0  49    0    49    0        0.0     0.0      0.0
# 5  virus-like-particle    0  13    0    13    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/20
# ----------
# 損失: 0.0921
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.14722992181777955
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   0  36    0    36   0   0.000000  0.000000  0.00000
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.00000
# 2   beta-galactosidase   0  24    0    24   0   0.000000  0.000000  0.00000
# 3             ribosome  87  65   42    23  45   0.482759  0.646154  0.63354
# 4        thyroglobulin   0  49    0    49   0   0.000000  0.000000  0.00000
# 5  virus-like-particle   0  13    0    13   0   0.000000  0.000000  0.00000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.09050576752440107)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.0905
# エポック 3/20
# ----------
# 損失: 0.0451
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.15347183421254157
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  36    0    36   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  24    0    24   0   0.000000  0.000000  0.000000
# 3             ribosome  51  65   33    32  18   0.647059  0.507692  0.514207
# 4        thyroglobulin  14  49    0    49  14   0.000000  0.000000  0.000000
# 5  virus-like-particle   2  13    0    13   2   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.07345816420060233)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.0735
# エポック 4/20
# ----------
# 損失: 0.0330
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.16106122210621834
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   0  36    0    36   0    0.00000  0.000000  0.00000
# 1         beta-amylase   0  21    0    21   0    0.00000  0.000000  0.00000
# 2   beta-galactosidase   0  24    0    24   0    0.00000  0.000000  0.00000
# 3             ribosome  32  65   17    48  15    0.53125  0.261538  0.26959
# 4        thyroglobulin   8  49    0    49   8    0.00000  0.000000  0.00000
# 5  virus-like-particle   0  13    0    13   0    0.00000  0.000000  0.00000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.03851279317697228)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.0385
# エポック 5/20
# ----------
# 損失: 0.0272
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.11455102190375328
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  36    0    36    0   0.000000  0.000000
# 1         beta-amylase    0  21    0    21    0   0.000000  0.000000
# 2   beta-galactosidase    0  24    0    24    0   0.000000  0.000000
# 3             ribosome  283  65   45    20  238   0.159011  0.692308
# 4        thyroglobulin   98  49   19    30   79   0.193878  0.387755
# 5  virus-like-particle  105  13   11     2   94   0.104762  0.846154
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.578231       1
# 4  0.366213       2
# 5  0.597444       1  , 0.272585955118393)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2726
# エポック 6/20
# ----------
# 損失: 0.0192
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.2219385474920273
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  36    0    36   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  24    0    24   1   0.000000  0.000000  0.000000
# 3             ribosome  59  65   33    32  26   0.559322  0.507692  0.510464
# 4        thyroglobulin   6  49    0    49   6   0.000000  0.000000  0.000000
# 5  virus-like-particle   5  13    5     8   0   1.000000  0.384615  0.399061
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1299321558712298)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.1299
# エポック 7/20
# ----------
# 損失: 0.0149
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.1376962549984455
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  36    0    36    0   0.000000  0.000000
# 1         beta-amylase    0  21    0    21    0   0.000000  0.000000
# 2   beta-galactosidase    9  24    0    24    9   0.000000  0.000000
# 3             ribosome  162  65   38    27  124   0.234568  0.584615
# 4        thyroglobulin  173  49   21    28  152   0.121387  0.428571
# 5  virus-like-particle   91  13   13     0   78   0.142857  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.537438       1
# 4  0.373041       2
# 5  0.739130       1  , 0.28894993478259245)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2889
# エポック 8/20
# ----------
# 損失: 0.0124
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.20612609311938285
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   2  36    1    35   1   0.500000  0.027778  0.029412
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   2  24    0    24   2   0.000000  0.000000  0.000000
# 3             ribosome  80  65   55    10  25   0.687500  0.846154  0.834821
# 4        thyroglobulin  57  49    5    44  52   0.087719  0.102041  0.101070
# 5  virus-like-particle  23  13   13     0  10   0.565217  1.000000  0.956710
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.2890119227347192)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2890
# エポック 9/20
# ----------
# 損失: 0.0105
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.20951732248067856
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   3  36    0    36   3   0.000000  0.000000  0.000000
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  24    0    24   1   0.000000  0.000000  0.000000
# 3             ribosome  48  65   35    30  13   0.729167  0.538462  0.546875
# 4        thyroglobulin  14  49    0    49  14   0.000000  0.000000  0.000000
# 5  virus-like-particle  10  13   10     3   0   1.000000  0.769231  0.779817
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.18952735910878113)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.1895
# エポック 10/20
# ----------
# 損失: 0.0093
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.2758074775338173
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   5  36    3    33   2   0.600000  0.083333  0.087780
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   5  24    0    24   5   0.000000  0.000000  0.000000
# 3             ribosome  39  65   33    32   6   0.846154  0.507692  0.519926
# 4        thyroglobulin  26  49    1    48  25   0.038462  0.020408  0.020988
# 5  virus-like-particle  16  13   13     0   3   0.812500  1.000000  0.986607
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.23375542842338598)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2338
# エポック 11/20
# ----------
# 損失: 0.0082
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.28514026999473574
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   2  36    0    36   2   0.000000  0.000000  0.000000
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  24    0    24   1   0.000000  0.000000  0.000000
# 3             ribosome  28  65   23    42   5   0.821429  0.353846  0.366105
# 4        thyroglobulin   1  49    0    49   1   0.000000  0.000000  0.000000
# 5  virus-like-particle   2  13    2    11   0   1.000000  0.153846  0.161905
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0754299472598028)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.0754
# エポック 12/20
# ----------
# 損失: 0.0071
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.22352916970849038
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  69  36   34     2  35   0.492754  0.944444  0.896124
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  75  24    2    22  73   0.026667  0.083333  0.074074
# 3             ribosome  62  65   46    19  16   0.741935  0.707692  0.709619
# 4        thyroglobulin  51  49   16    33  35   0.313725  0.326531  0.325749
# 5  virus-like-particle  16  13   13     0   3   0.812500  1.000000  0.986607
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.48457074325345806)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.4846
# エポック 13/20
# ----------
# 損失: 0.0073
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.3396602287888527
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  16  36    6    30  10   0.375000  0.166667  0.172297
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   3  24    0    24   3   0.000000  0.000000  0.000000
# 3             ribosome  11  65    8    57   3   0.727273  0.123077  0.129401
# 4        thyroglobulin   1  49    0    49   1   0.000000  0.000000  0.000000
# 5  virus-like-particle   7  13    7     6   0   1.000000  0.538462  0.553488
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.122169462896456)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.1222
# エポック 14/20
# ----------
# 損失: 0.0059
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.33789296448230743
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  10  36    6    30   4   0.600000  0.166667  0.174061
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   5  24    0    24   5   0.000000  0.000000  0.000000
# 3             ribosome  39  65   20    45  19   0.512821  0.307692  0.315107
# 4        thyroglobulin   6  49    0    49   6   0.000000  0.000000  0.000000
# 5  virus-like-particle  12  13   12     1   0   1.000000  0.923077  0.927273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20234867726952108)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2023
# エポック 15/20
# ----------
# 損失: 0.0050
# Evaluating CV for ID TS_99_9 (1/1)
# mask_loss=0.3593581184744835
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  23  36   16    20   7   0.695652  0.444444  0.454090
# 1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  24    0    24   1   0.000000  0.000000  0.000000
# 3             ribosome  13  65   11    54   2   0.846154  0.169231  0.177588
# 4        thyroglobulin   0  49    0    49   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  13  13   13     0   0   1.000000  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.23309685635784688)
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# CVスコア: lb_score: 0.2331
# エポック 16/20
# ----------

# %%
# 損失の推移をグラフ化
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(epoch_losses)+1), epoch_losses, marker='o', label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.grid(True)
plt.legend()
plt.show()
