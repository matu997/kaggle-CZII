# %%
from helpers import *
from dataset import *
from model2_for27 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(100, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
    RandGaussianNoised(
        keys=["image"],
        prob=0.2,  # 適用確率
        mean=0.0,  # ノイズの平均
        std=0.05   # ノイズの標準偏差
    ),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 208
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1234890.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 730978.0

# %%
GPU_ID = 4
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:4

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.0050
# 検証_loss=0.7343651294708252
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    1  46    0    46    1        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome  108  31    0    31  108        0.0     0.0      0.0
# 4        thyroglobulin    1  30    0    30    1        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.5921
# 検証_loss=0.39757617712020876
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin     1  46    0    46     1   0.000000  0.000000
# 1         beta-amylase  3777  10    0    10  3777   0.000000  0.000000
# 2   beta-galactosidase     1  12    0    12     1   0.000000  0.000000
# 3             ribosome   243  31    3    28   240   0.012346  0.096774
# 4        thyroglobulin  4427  30    0    30  4427   0.000000  0.000000
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.069012       1
# 4  0.000000       2
# 5  0.000000       1  , 0.009858882659965203)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0099
# エポック 3/30
# ----------
# 訓練_loss: 0.3331
# 検証_loss=0.269038251042366
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  3492  46    2    44  3490   0.000573  0.043478
# 1         beta-amylase   438  10    0    10   438   0.000000  0.000000
# 2   beta-galactosidase   804  12    0    12   804   0.000000  0.000000
# 3             ribosome  1827  31   28     3  1799   0.015326  0.903226
# 4        thyroglobulin  3262  30    7    23  3255   0.002146  0.233333
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.008042       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.204907       1
# 4  0.031801       2
# 5  0.000000       1  , 0.039507346599568956)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0395
# エポック 4/30
# ----------
# 訓練_loss: 0.2037
# 検証_loss=0.17587990164756775
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   89  46    0    46   89   0.000000  0.000000
# 1         beta-amylase   49  10    0    10   49   0.000000  0.000000
# 2   beta-galactosidase  775  12    0    12  775   0.000000  0.000000
# 3             ribosome   51  31   23     8   28   0.450980  0.741935
# 4        thyroglobulin   56  30    1    29   55   0.017857  0.033333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.714808       1
# 4  0.031716       2
# 5  0.000000       1  , 0.111177268528083)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1112
# エポック 5/30
# ----------
# 訓練_loss: 0.1446
# 検証_loss=0.13834632337093353
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   37  46    0    46   37   0.000000  0.000000
# 1         beta-amylase    2  10    0    10    2   0.000000  0.000000
# 2   beta-galactosidase  159  12    0    12  159   0.000000  0.000000
# 3             ribosome   28  31   18    13   10   0.642857  0.580645
# 4        thyroglobulin    3  30    0    30    3   0.000000  0.000000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.583969       1
# 4  0.000000       2
# 5  0.000000       1  , 0.08342420937840786)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0834
# エポック 6/30
# ----------
# 訓練_loss: 0.0937
# 検証_loss=0.09619293659925461
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   69  46    0    46   69   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  125  12    0    12  125   0.000000  0.000000
# 3             ribosome   63  31   28     3   35   0.444444  0.903226
# 4        thyroglobulin    1  30    0    30    1   0.000000  0.000000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.851521       1
# 4  0.000000       2
# 5  0.000000       1  , 0.12164579606440072)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1216
# エポック 7/30
# ----------
# 訓練_loss: 0.0586
# 検証_loss=0.08197573833167553
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   3  46    0    46   3   0.000000  0.000000     0.00
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000     0.00
# 2   beta-galactosidase  46  12    0    12  46   0.000000  0.000000     0.00
# 3             ribosome  84  31   29     2  55   0.345238  0.935484     0.85
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000     0.00
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000     0.00
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12142857142857141)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1214
# エポック 8/30
# ----------
# 訓練_loss: 0.0455
# 検証_loss=0.07524126060307026
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   14  12    0    12   14   0.000000  0.000000
# 3             ribosome   64  31   10    21   54   0.156250  0.322581
# 4        thyroglobulin  176  30   23     7  153   0.130682  0.766667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.303571       1
# 4  0.596037       2
# 5  0.000000       1  , 0.21366351418616228)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2137
# エポック 9/30
# ----------
# 訓練_loss: 0.0368
# 検証_loss=0.09000450558960438
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  39  31   19    12  20   0.487179  0.612903  0.603738
# 4        thyroglobulin  49  30    2    28  47   0.040816  0.066667  0.064272
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10461182017106616)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1046
# エポック 10/30
# ----------
# 訓練_loss: 0.0353
# 検証_loss=0.08824722394347191
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome   39  31   17    14   22   0.435897  0.548387
# 4        thyroglobulin  126  30   14    16  112   0.111111  0.466667
# 5  virus-like-particle    3  11    1    10    2   0.333333  0.090909
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.540187       1
# 4  0.392739       2
# 5  0.094972       1  , 0.20294821868310597)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2029
# エポック 11/30
# ----------
# 訓練_loss: 0.0320
# 検証_loss=0.07445582654327154
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin    0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase    0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase    1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome   49  31   20    11  29   0.408163  0.645161  0.623853
# 4        thyroglobulin  105  30   14    16  91   0.133333  0.466667  0.406838
# 5  virus-like-particle   13  11   10     1   3   0.769231  0.909091  0.899471
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.33385704630789814)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3339
# エポック 12/30
# ----------
# 訓練_loss: 0.0266
# 検証_loss=0.100545996427536
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    3  12    0    12    3   0.000000  0.000000
# 3             ribosome   37  31   13    18   24   0.351351  0.419355
# 4        thyroglobulin  111  30    6    24  105   0.054054  0.200000
# 5  virus-like-particle   15  11   11     0    4   0.733333  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.414634       1
# 4  0.172589       2
# 5  0.979058       1  , 0.24840991470558849)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2484
# エポック 13/30
# ----------
# 訓練_loss: 0.0272
# 検証_loss=0.06896484792232513
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   24  12    0    12   24   0.000000  0.000000
# 3             ribosome   43  31    9    22   34   0.209302  0.290323
# 4        thyroglobulin  185  30   22     8  163   0.118919  0.733333
# 5  virus-like-particle   16  11   11     0    5   0.687500  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.283859       1
# 4  0.562406       2
# 5  0.973958       1  , 0.3403756230790334)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3404
# エポック 14/30
# ----------
# 訓練_loss: 0.0265
# location_df is empty,
# 検証_loss=0.14829264134168624
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 15/30
# ----------
# 訓練_loss: 0.0235
# 検証_loss=0.08123997785151005
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    1  12    0    12    1   0.000000  0.000000
# 3             ribosome   66  31   15    16   51   0.227273  0.483871
# 4        thyroglobulin  263  30   27     3  236   0.102662  0.900000
# 5  virus-like-particle   13  11   11     0    2   0.846154  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.453737       1
# 4  0.617766       2
# 5  0.989418       1  , 0.382669467536462)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3827
# エポック 16/30
# ----------
# 訓練_loss: 0.0255
# 検証_loss=0.10025730170309544
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  35  31   12    19  23   0.342857  0.387097  0.384181
# 4        thyroglobulin  95  30   13    17  82   0.136842  0.433333  0.384348
# 5  virus-like-particle  11  11   10     1   1   0.909091  0.909091  0.909091
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.2945667646036106)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2946
# エポック 17/30
# ----------
# 訓練_loss: 0.0244
# 検証_loss=0.08721742350608111
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin    2  46    0    46   2   0.000000  0.000000  0.000000
# 1         beta-amylase    0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome   57  31   15    16  42   0.263158  0.483871  0.461121
# 4        thyroglobulin  110  30   12    18  98   0.109091  0.400000  0.345763
# 5  virus-like-particle   14  11    9     2   5   0.642857  0.818182  0.805263
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.27970139127817706)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2797
# エポック 18/30
# ----------
# 訓練_loss: 0.0249
# 検証_loss=0.0944183599203825
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   25  12    0    12   25   0.000000  0.000000
# 3             ribosome   23  31    4    27   19   0.173913  0.129032
# 4        thyroglobulin  232  30   21     9  211   0.090517  0.700000
# 5  virus-like-particle   13  11   11     0    2   0.846154  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.131021       1
# 4  0.501404       2
# 5  0.989418       1  , 0.3033211675410063)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3033
# エポック 19/30
# ----------
# 訓練_loss: 0.0231
# 検証_loss=0.10973365679383278
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  53  31   10    21  43   0.188679  0.322581  0.309654
# 4        thyroglobulin  29  30    0    30  29   0.000000  0.000000  0.000000
# 5  virus-like-particle  11  11    9     2   2   0.818182  0.818182  0.818182
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.16111939062758737)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1611
# エポック 20/30
# ----------
# 訓練_loss: 0.0221
# 検証_loss=0.09321509562432766
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  48  46    0    46  48   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   3  12    0    12   3   0.000000  0.000000  0.000000
# 3             ribosome  53  31   19    12  34   0.358491  0.612903  0.588342
# 4        thyroglobulin  28  30    0    30  28   0.000000  0.000000  0.000000
# 5  virus-like-particle  18  11   11     0   7   0.611111  1.000000  0.963918
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.221751423796379)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2218
# エポック 21/30
# ----------
# 訓練_loss: 0.0231
# 検証_loss=0.13825703039765358
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  10  31    1    30   9        0.1  0.032258  0.033597
# 4        thyroglobulin   1  30    0    30   1        0.0  0.000000  0.000000
# 5  virus-like-particle   2  11    2     9   0        1.0  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.032086867699960026)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0321
# エポック 22/30
# ----------
# 訓練_loss: 0.0216
# 検証_loss=0.10777786001563072
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  27  46    0    46  27   0.000000  0.000000  0.00000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.00000
# 2   beta-galactosidase   3  12    0    12   3   0.000000  0.000000  0.00000
# 3             ribosome  37  31    4    27  33   0.108108  0.129032  0.12758
# 4        thyroglobulin  37  30    0    30  37   0.000000  0.000000  0.00000
# 5  virus-like-particle   8  11    8     3   0   1.000000  0.727273  0.73913
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12381573887406337)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1238
# エポック 23/30
# ----------
# 訓練_loss: 0.0204
# 検証_loss=0.15729508623480798
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  1  31    0    31   1   0.000000  0.000000  0.000000
# 4        thyroglobulin  3  30    1    29   2   0.333333  0.033333  0.035197
# 5  virus-like-particle  0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.010056196391600117)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0101
# エポック 24/30
# ----------
# 訓練_loss: 0.0212
# 検証_loss=0.12091674208641053
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  13  46    0    46  13   0.000000  0.000000  0.00000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.00000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.00000
# 3             ribosome  43  31    1    30  42   0.023256  0.032258  0.03154
# 4        thyroglobulin   5  30    0    30   5   0.000000  0.000000  0.00000
# 5  virus-like-particle   8  11    8     3   0   1.000000  0.727273  0.73913
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11009576049505065)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1101
# エポック 25/30
# ----------
# 訓練_loss: 0.0202
# 検証_loss=0.1027013711631298
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  50  31   20    11  30        0.4  0.645161  0.622711
# 4        thyroglobulin   2  30    0    30   2        0.0  0.000000  0.000000
# 5  virus-like-particle   8  11    8     3   0        1.0  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.19454872249903307)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1945
# エポック 26/30
# ----------
# 訓練_loss: 0.0217
# 検証_loss=0.11536607444286347
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  10  46    1    45   9       0.10  0.021739  0.022788
# 1         beta-amylase   0  10    0    10   0       0.00  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0       0.00  0.000000  0.000000
# 3             ribosome   8  31    2    29   6       0.25  0.064516  0.067460
# 4        thyroglobulin  40  30    0    30  40       0.00  0.000000  0.000000
# 5  virus-like-particle  10  11    9     2   1       0.90  0.818182  0.822581
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13040416662499416)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1304
# エポック 27/30
# ----------
# 訓練_loss: 0.0205
# 検証_loss=0.10688026770949363
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  22  46    0    46  22   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   7  12    0    12   7   0.000000  0.000000  0.000000
# 3             ribosome   8  31    4    27   4   0.500000  0.129032  0.134921
# 4        thyroglobulin  50  30    1    29  49   0.020000  0.033333  0.032075
# 5  virus-like-particle  12  11   10     1   2   0.833333  0.909091  0.904255
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.15761812820939963)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1576
# エポック 28/30
# ----------
# 訓練_loss: 0.0193
# 検証_loss=0.17772943452000617
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 29/30
# ----------
# 訓練_loss: 0.0182
# location_df is empty,
# 検証_loss=0.14566147662699222
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 30/30
# ----------
# 訓練_loss: 0.0189
# 検証_loss=0.14698043391108512
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  3  46    0    46   3        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
#
# 全エポックの結果:
# エポック 1: 損失: 1.0050, lb_score: 0.0000
# エポック 2: 損失: 0.5921, lb_score: 0.0099
# エポック 3: 損失: 0.3331, lb_score: 0.0395
# エポック 4: 損失: 0.2037, lb_score: 0.1112
# エポック 5: 損失: 0.1446, lb_score: 0.0834
# エポック 6: 損失: 0.0937, lb_score: 0.1216
# エポック 7: 損失: 0.0586, lb_score: 0.1214
# エポック 8: 損失: 0.0455, lb_score: 0.2137
# エポック 9: 損失: 0.0368, lb_score: 0.1046
# エポック 10: 損失: 0.0353, lb_score: 0.2029
# エポック 11: 損失: 0.0320, lb_score: 0.3339
# エポック 12: 損失: 0.0266, lb_score: 0.2484
# エポック 13: 損失: 0.0272, lb_score: 0.3404
# エポック 14: 損失: 0.0265, lb_score: 0.0000
# エポック 15: 損失: 0.0235, lb_score: 0.3827
# エポック 16: 損失: 0.0255, lb_score: 0.2946
# エポック 17: 損失: 0.0244, lb_score: 0.2797
# エポック 18: 損失: 0.0249, lb_score: 0.3033
# エポック 19: 損失: 0.0231, lb_score: 0.1611
# エポック 20: 損失: 0.0221, lb_score: 0.2218
# エポック 21: 損失: 0.0231, lb_score: 0.0321
# エポック 22: 損失: 0.0216, lb_score: 0.1238
# エポック 23: 損失: 0.0204, lb_score: 0.0101
# エポック 24: 損失: 0.0212, lb_score: 0.1101
# エポック 25: 損失: 0.0202, lb_score: 0.1945
# エポック 26: 損失: 0.0217, lb_score: 0.1304
# エポック 27: 損失: 0.0205, lb_score: 0.1576
# エポック 28: 損失: 0.0193, lb_score: 0.0000
# エポック 29: 損失: 0.0182, lb_score: 0.0000
# エポック 30: 損失: 0.0189, lb_score: 0.0000

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
#  0         apo-ferritin  104  36   19    17   85   0.182692  0.527778
#  1         beta-amylase    0  21    0    21    0   0.000000  0.000000
#  2   beta-galactosidase    0  24    0    24    0   0.000000  0.000000
#  3             ribosome  157  65   34    31  123   0.216561  0.523077
#  4        thyroglobulin   17  49    6    43   11   0.352941  0.122449
#  5  virus-like-particle   19  13   13     0    6   0.684211  1.000000
#
#      f-beta4  weight
#  0  0.475000       1
#  1  0.000000       0
#  2  0.000000       2
#  3  0.482874       1
#  4  0.127341       2
#  5  0.973568       1  ,
#  0.31230339731047213)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
