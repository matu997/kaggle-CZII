# %%
from helpers import *
from dataset import *
from model2_for40 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(100, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
    RandGaussianNoised(
        keys=["image"],
        prob=0.2,  # 適用確率
        mean=0.0,  # ノイズの平均
        std=0.05   # ノイズの標準偏差
    ),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 215
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 165057.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 517845.0

# %%
GPU_ID = 2
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:2

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.5643
# 検証_loss=1.5596980333328248
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.9680
# 検証_loss=1.2801924228668213
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 3/30
# ----------
# 訓練_loss: 0.6193
# 検証_loss=1.0512715458869935
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   5  12    0    12   5        0.0     0.0      0.0
# 3             ribosome  10  31    0    31  10        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 4/30
# ----------
# 訓練_loss: 0.3977
# 検証_loss=0.8612905383110047
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  1806  46    0    46  1806   0.000000  0.000000
# 1         beta-amylase  2858  10    2     8  2856   0.000700  0.200000
# 2   beta-galactosidase   355  12   10     2   345   0.028169  0.833333
# 3             ribosome  3273  31   11    20  3262   0.003361  0.354839
# 4        thyroglobulin  2725  30   18    12  2707   0.006606  0.600000
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.011266       0
# 2  0.310786       2
# 3  0.049615       1
# 4  0.095476       2
# 5  0.000000       1  , 0.1231627332428081)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1232
# エポック 5/30
# ----------
# 訓練_loss: 0.2954
# 検証_loss=0.831415593624115
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  1815  46    1    45  1814   0.000551  0.021739
# 1         beta-amylase     4  10    0    10     4   0.000000  0.000000
# 2   beta-galactosidase   447  12   10     2   437   0.022371  0.833333
# 3             ribosome     2  31    0    31     2   0.000000  0.000000
# 4        thyroglobulin   300  30   20    10   280   0.066667  0.666667
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.006664       1
# 1  0.000000       0
# 2  0.266041       2
# 3  0.000000       1
# 4  0.435897       2
# 5  0.000000       1  , 0.2015057574655854)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2015
# エポック 6/30
# ----------
# 訓練_loss: 0.2458
# 検証_loss=0.383640818297863
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   18  46    0    46   18   0.000000  0.000000
# 1         beta-amylase   17  10    0    10   17   0.000000  0.000000
# 2   beta-galactosidase  407  12    9     3  398   0.022113  0.750000
# 3             ribosome   19  31    7    24   12   0.368421  0.225806
# 4        thyroglobulin  905  30   13    17  892   0.014365  0.433333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.255426       2
# 3  0.231068       1
# 4  0.159567       2
# 5  0.000000       1  , 0.1515789934577126)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1516
# エポック 7/30
# ----------
# 訓練_loss: 0.2082
# 検証_loss=0.49944916516542437
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   16  46    0    46   16   0.000000  0.000000
# 1         beta-amylase   17  10    0    10   17   0.000000  0.000000
# 2   beta-galactosidase  501  12    7     5  494   0.013972  0.583333
# 3             ribosome   12  31    2    29   10   0.166667  0.064516
# 4        thyroglobulin  508  30   20    10  488   0.039370  0.666667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.171717       2
# 3  0.066929       1
# 4  0.344130       2
# 5  0.000000       1  , 0.15694608380062172)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1569
# エポック 8/30
# ----------
# 訓練_loss: 0.2106
# 検証_loss=1.2932056605815887
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   27  46    0    46   27   0.000000  0.000000
# 1         beta-amylase   27  10    0    10   27   0.000000  0.000000
# 2   beta-galactosidase  370  12    5     7  365   0.013514  0.416667
# 3             ribosome   30  31   18    13   12   0.600000  0.580645
# 4        thyroglobulin  259  30   24     6  235   0.092664  0.800000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.151246       2
# 3  0.581749       1
# 4  0.552097       2
# 5  0.000000       1  , 0.28406214436408683)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2841
# エポック 9/30
# ----------
# 訓練_loss: 0.1929
# 検証_loss=1.7626212418079377
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   5  10    0    10   5   0.000000  0.000000  0.000000
# 2   beta-galactosidase  45  12    0    12  45   0.000000  0.000000  0.000000
# 3             ribosome   6  31    2    29   4   0.333333  0.064516  0.067729
# 4        thyroglobulin  78  30    2    28  76   0.025641  0.066667  0.060932
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.027084697564070396)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0271
# エポック 10/30
# ----------
# 訓練_loss: 0.1721
# 検証_loss=1.9022856116294862
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase   0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  10  12    0    12  10        0.0     0.0      0.0
# 3             ribosome   2  31    0    31   2        0.0     0.0      0.0
# 4        thyroglobulin  10  30    0    30  10        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 11/30
# ----------
# 訓練_loss: 0.1699
# 検証_loss=1.130617094039917
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    4  10    0    10    4   0.000000  0.000000
# 2   beta-galactosidase   84  12    8     4   76   0.095238  0.666667
# 3             ribosome   25  31    9    22   16   0.360000  0.290323
# 4        thyroglobulin  297  30   23     7  274   0.077441  0.766667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.492754       2
# 3  0.293666       1
# 4  0.503218       2
# 5  0.000000       1  , 0.32651546852617414)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3265
# エポック 12/30
# ----------
# 訓練_loss: 0.1647
# 検証_loss=2.6673055052757264
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  10  12    0    12  10        0.0  0.000000  0.000000
# 3             ribosome  20  31    4    27  16        0.2  0.129032  0.131783
# 4        thyroglobulin  46  30    0    30  46        0.0  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0        0.0  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.018826135105204873)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0188
# エポック 13/30
# ----------
# 訓練_loss: 0.1572
# 検証_loss=0.5379771307110787
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   69  12    9     3   60   0.130435  0.750000
# 3             ribosome   45  31   16    15   29   0.355556  0.516129
# 4        thyroglobulin  511  30   19    11  492   0.037182  0.633333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.586207       2
# 3  0.502773       1
# 4  0.325933       2
# 5  0.000000       1  , 0.3324361767953687)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3324
# エポック 14/30
# ----------
# 訓練_loss: 0.1698
# 検証_loss=1.4432473331689835
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   43  12    2    10   41   0.046512  0.166667
# 3             ribosome    1  31    0    31    1   0.000000  0.000000
# 4        thyroglobulin  311  30   22     8  289   0.070740  0.733333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.144681       2
# 3  0.000000       1
# 4  0.472819       2
# 5  0.000000       1  , 0.1764285906416794)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1764
# エポック 15/30
# ----------
# 訓練_loss: 0.1612
# 検証_loss=2.7141775846481324
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  34  12    0    12  34   0.000000  0.000000  0.000000
# 3             ribosome  12  31    3    28   9   0.250000  0.096774  0.100394
# 4        thyroglobulin  75  30    2    28  73   0.026667  0.066667  0.061261
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.031845174758560586)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0318
# エポック 16/30
# ----------
# 訓練_loss: 0.1598
# 検証_loss=1.4985315322875976
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   15  12    1    11   14   0.066667  0.083333
# 3             ribosome   10  31    1    30    9   0.100000  0.032258
# 4        thyroglobulin  272  30   24     6  248   0.088235  0.800000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.082126       2
# 3  0.033597       1
# 4  0.542553       2
# 5  0.000000       1  , 0.18327920409326517)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1833
# エポック 17/30
# ----------
# 訓練_loss: 0.1516
# 検証_loss=2.0113632321357726
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   23  12    3     9   20   0.130435  0.250000
# 3             ribosome    1  31    0    31    1   0.000000  0.000000
# 4        thyroglobulin  197  30   23     7  174   0.116751  0.766667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.237209       2
# 3  0.000000       1
# 4  0.577548       2
# 5  0.000000       1  , 0.2327878023525717)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2328
# エポック 18/30
# ----------
# 訓練_loss: 0.1592
# 検証_loss=0.4763273552060127
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  175  12   10     2  165   0.057143  0.833333
# 3             ribosome   18  31    6    25   12   0.333333  0.193548
# 4        thyroglobulin  729  30   17    13  712   0.023320  0.566667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.463215       2
# 3  0.198444       1
# 4  0.239041       2
# 5  0.000000       1  , 0.22899359374341838)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2290
# エポック 19/30
# ----------
# 訓練_loss: 0.1446
# 検証_loss=2.9916140496730805
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  18  12    0    12  18        0.0  0.000000  0.000000
# 3             ribosome   5  31    2    29   3        0.4  0.064516  0.067864
# 4        thyroglobulin  26  30    0    30  26        0.0  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0        0.0  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.009694895922440832)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0097
# エポック 20/30
# ----------
# 訓練_loss: 0.1363
# 検証_loss=2.866077744960785
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  47  12    1    11  46   0.021277  0.083333  0.071130
# 3             ribosome  11  31    4    27   7   0.363636  0.129032  0.134122
# 4        thyroglobulin  57  30    1    29  56   0.017544  0.033333  0.031657
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.048528059079112465)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0485
# エポック 21/30
# ----------
# 訓練_loss: 0.1600
# 検証_loss=1.3528919756412505
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   12  12    1    11   11   0.083333  0.083333
# 3             ribosome    3  31    0    31    3   0.000000  0.000000
# 4        thyroglobulin  304  30   22     8  282   0.072368  0.733333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.083333       2
# 3  0.000000       1
# 4  0.477041       2
# 5  0.000000       1  , 0.16010689990281826)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1601
# エポック 22/30
# ----------
# 訓練_loss: 0.1314
# 検証_loss=4.193603670597076
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   9  12    0    12   9   0.000000  0.000000  0.000000
# 3             ribosome  14  31    2    29  12   0.142857  0.064516  0.066667
# 4        thyroglobulin  15  30    0    30  15   0.000000  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.009523809523809523)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0095
# エポック 23/30
# ----------
# 訓練_loss: 0.1249
# 検証_loss=2.5129874765872957
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin    0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase    0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase    6  12    1    11   5   0.166667  0.083333  0.085859
# 3             ribosome    5  31    1    30   4   0.200000  0.032258  0.033932
# 4        thyroglobulin  106  30   16    14  90   0.150943  0.533333  0.464164
# 5  virus-like-particle    0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.16199670749955847)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1620
# エポック 24/30
# ----------
# 訓練_loss: 0.1313
# 検証_loss=1.5927322685718537
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   29  12    3     9   26   0.103448  0.250000
# 3             ribosome    2  31    0    31    2   0.000000  0.000000
# 4        thyroglobulin  300  30   23     7  277   0.076667  0.766667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.230769       2
# 3  0.000000       1
# 4  0.501282       2
# 5  0.000000       1  , 0.20915750915750914)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2092
# エポック 25/30
# ----------
# 訓練_loss: 0.1361
# 検証_loss=1.312801292538643
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   26  12    4     8   22   0.153846  0.333333
# 3             ribosome   21  31   13    18    8   0.619048  0.419355
# 4        thyroglobulin  499  30   21     9  478   0.042084  0.700000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.311927       2
# 3  0.427466       1
# 4  0.364658       2
# 5  0.000000       1  , 0.2543764271530876)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2544
# エポック 26/30
# ----------
# 訓練_loss: 0.1415
# 検証_loss=0.4583524793386459
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  324  12   10     2  314   0.030864  0.833333
# 3             ribosome   31  31   17    14   14   0.548387  0.548387
# 4        thyroglobulin  578  30   19    11  559   0.032872  0.633333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.329457       2
# 3  0.548387       1
# 4  0.305293       2
# 5  0.000000       1  , 0.2596982623997884)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2597
# エポック 27/30
# ----------
# 訓練_loss: 0.1279
# 検証_loss=1.179796150326729
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  173  12   10     2  163   0.057803  0.833333
# 3             ribosome   22  31   10    21   12   0.454545  0.322581
# 4        thyroglobulin  348  30   24     6  324   0.068966  0.800000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.465753       2
# 3  0.328185       1
# 4  0.492754       2
# 5  0.000000       1  , 0.3207427748396012)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3207
# エポック 28/30
# ----------
# 訓練_loss: 0.1361
# 検証_loss=0.6985901117324829
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   22  12    1    11   21   0.045455  0.083333
# 3             ribosome    1  31    0    31    1   0.000000  0.000000
# 4        thyroglobulin  675  30   17    13  658   0.025185  0.566667
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.079439       2
# 3  0.000000       1
# 4  0.250216       2
# 5  0.000000       1  , 0.09418734358654253)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0942
# エポック 29/30
# ----------
# 訓練_loss: 0.1266
# 検証_loss=1.6382830619812012
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  140  12    8     4  132   0.057143  0.666667
# 3             ribosome    8  31    0    31    8   0.000000  0.000000
# 4        thyroglobulin  189  30   12    18  177   0.063492  0.400000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.409639       2
# 3  0.000000       1
# 4  0.304933       2
# 5  0.000000       1  , 0.2041632256122504)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2042
# エポック 30/30
# ----------
# 訓練_loss: 0.1262
# 検証_loss=1.374246671795845
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall   f-beta4  \
# 0         apo-ferritin    0  46    0    46    0   0.000000    0.00  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000    0.00  0.000000
# 2   beta-galactosidase  317  12    9     3  308   0.028391    0.75  0.300589
# 3             ribosome    4  31    0    31    4   0.000000    0.00  0.000000
# 4        thyroglobulin  292  30   21     9  271   0.071918    0.70  0.462435
# 5  virus-like-particle    0  11    0    11    0   0.000000    0.00  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.21800703546379815)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2180
#
# 全エポックの結果:
# エポック 1: 損失: 1.5643, lb_score: 0.0000
# エポック 2: 損失: 0.9680, lb_score: 0.0000
# エポック 3: 損失: 0.6193, lb_score: 0.0000
# エポック 4: 損失: 0.3977, lb_score: 0.1232
# エポック 5: 損失: 0.2954, lb_score: 0.2015
# エポック 6: 損失: 0.2458, lb_score: 0.1516
# エポック 7: 損失: 0.2082, lb_score: 0.1569
# エポック 8: 損失: 0.2106, lb_score: 0.2841
# エポック 9: 損失: 0.1929, lb_score: 0.0271
# エポック 10: 損失: 0.1721, lb_score: 0.0000
# エポック 11: 損失: 0.1699, lb_score: 0.3265
# エポック 12: 損失: 0.1647, lb_score: 0.0188
# エポック 13: 損失: 0.1572, lb_score: 0.3324
# エポック 14: 損失: 0.1698, lb_score: 0.1764
# エポック 15: 損失: 0.1612, lb_score: 0.0318
# エポック 16: 損失: 0.1598, lb_score: 0.1833
# エポック 17: 損失: 0.1516, lb_score: 0.2328
# エポック 18: 損失: 0.1592, lb_score: 0.2290
# エポック 19: 損失: 0.1446, lb_score: 0.0097
# エポック 20: 損失: 0.1363, lb_score: 0.0485
# エポック 21: 損失: 0.1600, lb_score: 0.1601
# エポック 22: 損失: 0.1314, lb_score: 0.0095
# エポック 23: 損失: 0.1249, lb_score: 0.1620
# エポック 24: 損失: 0.1313, lb_score: 0.2092
# エポック 25: 損失: 0.1361, lb_score: 0.2544
# エポック 26: 損失: 0.1415, lb_score: 0.2597
# エポック 27: 損失: 0.1279, lb_score: 0.3207
# エポック 28: 損失: 0.1361, lb_score: 0.0942
# エポック 29: 損失: 0.1266, lb_score: 0.2042
# エポック 30: 損失: 0.1262, lb_score: 0.2180

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
#  0         apo-ferritin    0  36    0    36    0   0.000000  0.000000
#  1         beta-amylase    0  21    0    21    0   0.000000  0.000000
#  2   beta-galactosidase  183  24    4    20  179   0.021858  0.166667
#  3             ribosome  119  65   29    36   90   0.243697  0.446154
#  4        thyroglobulin  342  49   17    32  325   0.049708  0.346939
#  5  virus-like-particle    0  13    0    13    0   0.000000  0.000000
#
#      f-beta4  weight
#  0  0.000000       1
#  1  0.000000       0
#  2  0.119929       2
#  3  0.425367       1
#  4  0.256661       2
#  5  0.000000       1  ,
#  0.16836387056568144)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
