# %%
from helpers import *
from dataset import *
from model2_for48 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
#DEBAG = False
DEBAG = True

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
mask_size2 = {
    'defolt': 1,
    'apo-ferritin': mask_size["apo-ferritin"]*0.6,
    'beta-amylase': mask_size["beta-amylase"]*0.01,
    'beta-galactosidase': mask_size["beta-galactosidase"]*1.4,
    'ribosome': mask_size["ribosome"]*0.7,
    'thyroglobulin': mask_size["thyroglobulin"]*1.3,
    'virus-like-particle': mask_size["virus-like-particle"]*1.0,
}
print(mask_size2)
mask_check("TS_5_4",mask_size2,cfg)
# Out:
# {'defolt': 1, 'apo-ferritin': 3.5999999999999996, 'beta-amylase': 0.065, 'beta-galactosidase': 12.6, 'ribosome': 10.5, 'thyroglobulin': 16.900000000000002, 'virus-like-particle': 13.5}
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall   f-beta4  \
#  0         apo-ferritin  46  46   46     0   0        1.0     1.0  1.000000
#  1         beta-amylase   8  10    8     2   0        1.0     0.8  0.809524
#  2   beta-galactosidase  12  12   12     0   0        1.0     1.0  1.000000
#  3             ribosome  31  31   31     0   0        1.0     1.0  1.000000
#  4        thyroglobulin  30  30   30     0   0        1.0     1.0  1.000000
#  5  virus-like-particle  11  11   11     0   0        1.0     1.0  1.000000
#
#     weight
#  0       1
#  1       0
#  2       2
#  3       1
#  4       2
#  5       1  ,
#  1.0)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

#diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised","isonetcorrected","wbp","ctfdeconvolved","denoised"]
diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (1, 184, 630, 630)
# (1, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start 
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) >= 0:
                    self.indices.append((idx, start, end))
            start = d - patch_size
            end = d
            if np.sum(mask_data[idx][start:end]) >= 0:
                self.indices.append((idx, start, end))


    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
        
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant", method="end"),
    
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 11
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1357103
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1854284

# %%
GPU_ID = 0
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:0

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 200
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/200
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.7083
# 検証_loss=1.8867003267461604
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/200
# ----------
# 訓練_loss: 1.5535
# 検証_loss=1.7929195707494563
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    4  46    0    46    4        0.0     0.0      0.0
# 1         beta-amylase    5  10    0    10    5        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome    1  31    0    31    1        0.0     0.0      0.0
# 4        thyroglobulin    4  30    0    30    4        0.0     0.0      0.0
# 5  virus-like-particle  615  11    0    11  615        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 3/200
# ----------
# 訓練_loss: 1.4739
# 検証_loss=1.5493504134091465
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000  0.000000
# 1         beta-amylase      1  10    0    10      1   0.000000  0.000000
# 2   beta-galactosidase      1  12    0    12      1   0.000000  0.000000
# 3             ribosome      1  31    0    31      1   0.000000  0.000000
# 4        thyroglobulin      1  30    0    30      1   0.000000  0.000000
# 5  virus-like-particle  22997  11    9     2  22988   0.000391  0.818182
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.006603       1  , 0.0009432159348009691)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0009
# エポック 4/200
# ----------
# 訓練_loss: 1.4147
# 検証_loss=1.3819283463738181
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision  recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000     0.0
# 1         beta-amylase      1  10    0    10      1   0.000000     0.0
# 2   beta-galactosidase      1  12    0    12      1   0.000000     0.0
# 3             ribosome      1  31    0    31      1   0.000000     0.0
# 4        thyroglobulin     23  30    0    30     23   0.000000     0.0
# 5  virus-like-particle  33604  11   11     0  33593   0.000327     1.0
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.005536       1  , 0.0007908314302630467)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0008
# エポック 5/200
# ----------
# 訓練_loss: 1.3639
# 検証_loss=1.3106962334025989
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase      11  10    0    10      11   0.000000  0.000000
# 2   beta-galactosidase       1  12    0    12       1   0.000000  0.000000
# 3             ribosome       1  31    0    31       1   0.000000  0.000000
# 4        thyroglobulin     354  30    0    30     354   0.000000  0.000000
# 5  virus-like-particle  129985  11   10     1  129975   0.000077  0.909091
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.001306       1  , 0.00018658211204365584)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0002
# エポック 6/200
# ----------
# 訓練_loss: 1.3204
# 検証_loss=1.500017361207442
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000  0.000000
# 1         beta-amylase      1  10    0    10      1   0.000000  0.000000
# 2   beta-galactosidase    812  12    0    12    812   0.000000  0.000000
# 3             ribosome      1  31    0    31      1   0.000000  0.000000
# 4        thyroglobulin      1  30    0    30      1   0.000000  0.000000
# 5  virus-like-particle  32843  11    7     4  32836   0.000213  0.636364
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.003604       1  , 0.000514855083436809)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0005
# エポック 7/200
# ----------
# 訓練_loss: 1.2685
# 検証_loss=1.283651059324091
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase       1  10    0    10       1   0.000000  0.000000
# 2   beta-galactosidase       1  12    0    12       1   0.000000  0.000000
# 3             ribosome       1  31    0    31       1   0.000000  0.000000
# 4        thyroglobulin       1  30    0    30       1   0.000000  0.000000
# 5  virus-like-particle  282716  11   10     1  282706   0.000035  0.909091
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.000601       1  , 8.584800660928652e-05)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0001
# エポック 8/200
# ----------
# 訓練_loss: 1.2243
# 検証_loss=1.186157757585699
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase       1  10    0    10       1   0.000000  0.000000
# 2   beta-galactosidase       1  12    0    12       1   0.000000  0.000000
# 3             ribosome       1  31    0    31       1   0.000000  0.000000
# 4        thyroglobulin       1  30    0    30       1   0.000000  0.000000
# 5  virus-like-particle  381294  11   10     1  381284   0.000026  0.909091
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.000446       1  , 6.366349722314803e-05)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0001
# エポック 9/200
# ----------
# 訓練_loss: 1.1837
# 検証_loss=1.155345234003934
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      

# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 29/200
# ----------
# 訓練_loss: 0.5431
# 検証_loss=0.5809363614429127
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000  0.000000
# 1         beta-amylase    532  10    0    10    532   0.000000  0.000000
# 2   beta-galactosidase      1  12    0    12      1   0.000000  0.000000
# 3             ribosome  40515  31    1    30  40514   0.000025  0.032258
# 4        thyroglobulin  27750  30    1    29  27749   0.000036  0.033333
# 5  virus-like-particle      0  11    0    11      0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000415       1
# 4  0.000602       2
# 5  0.000000       1  , 0.0002312736318757513)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0002
# エポック 30/200
# ----------
# 訓練_loss: 0.5149
# 検証_loss=0.5499300306493585
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase     210  10    0    10     210   0.000000  0.000000
# 2   beta-galactosidase       1  12    0    12       1   0.000000  0.000000
# 3             ribosome  109863  31    1    30  109862   0.000009  0.032258
# 4        thyroglobulin  110663  30    0    30  110663   0.000000  0.000000
# 5  virus-like-particle       0  11    0    11       0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000154       1
# 4  0.000000       2
# 5  0.000000       1  , 2.2006102162682047e-05)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 31/200
# ----------
# 訓練_loss: 0.5007
# 検証_loss=0.5647215897386725
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000  0.000000
# 1         beta-amylase   1749  10    0    10   1749   0.000000  0.000000
# 2   beta-galactosidase      1  12    0    12      1   0.000000  0.000000
# 3             ribosome  59565  31    1    30  59564   0.000017  0.032258
# 4        thyroglobulin  27592  30    0    30  27592   0.000000  0.000000
# 5  virus-like-particle     22  11    0    11     22   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000283       1
# 4  0.000000       2
# 5  0.000000       1  , 4.0435081476689173e-05)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 32/200
# ----------
# 訓練_loss: 0.4730
# 検証_loss=0.4947746829553084
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase    1183  10    0    10    1183   0.000000  0.000000
# 2   beta-galactosidase     910  12    0    12     910   0.000000  0.000000
# 3             ribosome  188367  31    1    30  188366   0.000005  0.032258
# 4        thyroglobulin  192083  30    0    30  192083   0.000000  0.000000
# 5  virus-like-particle       3  11    0    11       3   0.000000  0.000000
#
#    f-beta4  weight
# 0  0.00000       1
# 1  0.00000       0
# 2  0.00000       2
# 3  0.00009       1
# 4  0.00000       2
# 5  0.00000       1  , 1.2858905283572899e-05)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 33/200
# ----------
# 訓練_loss: 0.4513
# 検証_loss=0.4625306860967116
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase    1348  10    0    10    1348   0.000000  0.000000
# 2   beta-galactosidase       1  12    0    12       1   0.000000  0.000000
# 3             ribosome   47818  31   12    19   47806   0.000251  0.387097
# 4        thyroglobulin  159427  30    0    30  159427   0.000000  0.000000
# 5  virus-like-particle       0  11    0    11       0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.004222       1
# 4  0.000000       2
# 5  0.000000       1  , 0.0006031969438021513)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0006
# エポック 34/200
# ----------
# 訓練_loss: 0.4286
# 検証_loss=0.43927694179795007
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase    8531  10    0    10    8531   0.000000  0.000000
# 2   beta-galactosidase       2  12    0    12       2   0.000000  0.000000
# 3             ribosome   81659  31   11    20   81648   0.000135  0.354839
# 4        thyroglobulin  189407  30   18    12  189389   0.000095  0.600000
# 5  virus-like-particle       0  11    0    11       0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.002276       1
# 4  0.001611       2
# 5  0.000000       1  , 0.0007855935299746166)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0008
# エポック 35/200
# ----------
# 訓練_loss: 0.4070
# 検証_loss=0.40037089586257935
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type       P   T  hit  miss      fp  precision    recall  \
# 0         apo-ferritin       1  46    0    46       1   0.000000  0.000000
# 1         beta-amylase   69048  10    0    10   69048   0.000000  0.000000
# 2   beta-galactosidase     484  12    0    12     484   0.000000  0.000000
# 3             ribosome  122038  31   10    21  122028   0.000082  0.322581
# 4        thyroglobulin  103843  30   21     9  103822   0.000202  0.700000
# 5  virus-like-particle       0  11    0    11       0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.001387       1
# 4  0.003422       2
# 5  0.000000       1  , 0.0011759283383243793)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  3591  46    1    45  3590   0.000278  0.021739
# 1         beta-amylase   610  10    0    10   610   0.000000  0.000000
# 2   beta-galactosidase  9622  12    9     3  9613   0.000935  0.750000
# 3             ribosome   135  31   17    14   118   0.125926  0.548387
# 4        thyroglobulin    75  30   24     6    51   0.320000  0.800000
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.003929       1
# 1  0.000000       0
# 2  0.015590       2
# 3  0.458003       1
# 4  0.735135       2
# 5  0.000000       1  , 0.28048317227143776)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2805
# エポック 54/200
# ----------
# 訓練_loss: 0.1420
# 検証_loss=0.15580955012278122
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin  43334  46    1    45  43333   0.000023  0.021739
# 1         beta-amylase   3168  10    1     9   3167   0.000316  0.100000
# 2   beta-galactosidase  73538  12    9     3  73529   0.000122  0.750000
# 3             ribosome     89  31   21    10     68   0.235955  0.677419
# 4        thyroglobulin     76  30   25     5     51   0.328947  0.833333
# 5  virus-like-particle      0  11    0    11      0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000386       1
# 1  0.005108       0
# 2  0.002075       2
# 3  0.610256       1
# 4  0.764388       2
# 5  0.000000       1  , 0.3062242023797788)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3062
# エポック 55/200
# ----------
# 訓練_loss: 0.1323
# 検証_loss=0.1401606486602263
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin   4881  46    0    46   4881   0.000000  0.000000
# 1         beta-amylase    364  10    2     8    362   0.005495  0.200000
# 2   beta-galactosidase  32429  12   10     2  32419   0.000308  0.833333
# 3             ribosome    111  31   21    10     90   0.189189  0.677419
# 4        thyroglobulin    110  30   26     4     84   0.236364  0.866667
# 5  virus-like-particle      0  11    0    11      0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.064885       0
# 2  0.005211       2
# 3  0.588138       1
# 4  0.749153       2
# 5  0.000000       1  , 0.2995523148671436)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2996
# エポック 56/200
# ----------
# 訓練_loss: 0.1301
# ...
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  23  46   18    28   5   0.782609  0.391304  0.403162
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  65  12   12     0  53   0.184615  1.000000  0.793774
# 3             ribosome  84  31   27     4  57   0.321429  0.870968  0.791379
# 4        thyroglobulin  89  30   25     5  64   0.280899  0.833333  0.746924
# 5  virus-like-particle  23  11   11     0  12   0.478261  1.000000  0.939698
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.7450910505600563)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.7451
# エポック 192/200
# ----------
# 訓練_loss: 0.0084
# 検証_loss=nan
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   40  46   14    32   26   0.350000  0.304348
# 1         beta-amylase    1  10    0    10    1   0.000000  0.000000
# 2   beta-galactosidase  335  12   12     0  323   0.035821  1.000000
# 3             ribosome  121  31   27     4   94   0.223140  0.870968
# 4        thyroglobulin  196  30   25     5  171   0.127551  0.833333
# 5  virus-like-particle   41  11   11     0   30   0.268293  1.000000
#
#     f-beta4  weight
# 0  0.306701       1
# 1  0.000000       0
# 2  0.387097       2
# 3  0.743922       1
# 4  0.628698       2
# 5  0.861751       1  , 0.5634234836152493)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.5634
# エポック 193/200
# ----------
# 訓練_loss: 0.0089
# 検証_loss=nan
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   39  46   23    23   16   0.589744  0.500000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosid
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   54  46   15    31   39   0.277778  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   77  12   12     0   65   0.155844  1.000000
# 3             ribosome  110  31   27     4   83   0.245455  0.870968
# 4        thyroglobulin  166  30   26     4  140   0.156627  0.866667
# 5  virus-like-particle   38  11   11     0   27   0.289474  1.000000
#
#     f-beta4  weight
# 0  0.322785       1
# 1  0.000000       0
# 2  0.758364       2
# 3  0.757426       1
# 4  0.684211       2
# 5  0.873832       1  , 0.6913131436526669)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.6913
# エポック 200/200
# ----------
# 訓練_loss: 0.0071
# 検証_loss=0.049008094176480714
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  21  46   18    28   3   0.857143  0.391304  0.404227
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  51  12   12     0  39   0.235294  1.000000  0.839506
# 3             ribosome  83  31   27     4  56   0.325301  0.870968  0.792746
# 4        thyroglobulin  87  30   26     4  61   0.298851  0.866667  0.779541
# 5  virus-like-particle  39  11   11     0  28   0.282051  1.000000  0.869767
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.7578337152324256)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.7578
#
# 全エポックの結果:
# エポック 1: 損失: 1.7083, lb_score: 0.0000
# エポック 2: 損失: 1.5535, lb_score: 0.0000
# エポック 3: 損失: 1.4739, lb_score: 0.0009
# エポック 4: 損失: 1.4147, lb_score: 0.0008
# エポック 5: 損失: 1.3639, lb_score: 0.0002
# エポック 6: 損失: 1.3204, lb_score: 0.0005
# エポック 7: 損失: 1.2685, lb_score: 0.0001
# エポック 8: 損失: 1.2243, lb_score: 0.0001
# エポック 9: 損失: 1.1837, lb_score: 0.0004
# エポック 10: 損失: 1.1450, lb_score: 0.0007
# エポック 11: 損失: 1.1148, lb_score: 0.0000
# エポック 12: 損失: 1.0749, lb_score: 0.0000
# エポック 13: 損失: 1.0326, lb_score: 0.0000
# エポック 14: 損失: 0.9950, lb_score: 0.0000
# エポック 15: 損失: 0.9573, lb_score: 0.0000
# エポック 16: 損失: 0.9281, lb_score: 0.0000
# エポック 17: 損失: 0.8913, lb_score: 0.0000
# エポック 18: 損失: 0.8553, lb_score: 0.0000
# エポック 19: 損失: 0.8228, lb_score: 0.0000
# エポック 20: 損失: 0.7897, lb_score: 0.0000
# エポック 21: 損失: 0.7683, lb_score: 0.0000
# エポック 22: 損失: 0.7330, lb_score: 0.0000
# エポック 23: 損失: 0.7005, lb_score: 0.0000
# エポック 24: 損失: 0.6710, lb_score: 0.0000
# エポック 25: 損失: 0.6419, lb_score: 0.0000
# エポック 26: 損失: 0.6268, lb_score: 0.0000
# エポック 27: 損失: 0.5956, lb_score: 0.0000
# エポック 28: 損失: 0.5688, lb_score: 0.0000
# エポック 29: 損失: 0.5431, lb_score: 0.0002
# エポック 30: 損失: 0.5149, lb_score: 0.0000
# エポック 31: 損失: 0.5007, lb_score: 0.0000
# エポック 32: 損失: 0.4730, lb_score: 0.0000
# エポック 33: 損失: 0.4513, lb_score: 0.0006
# エポック 34: 損失: 0.4286, lb_score: 0.0008
# エポック 35: 損失: 0.4070, lb_score: 0.0012
# エポック 36: 損失: 0.3946, lb_score: 0.0003
# エポック 37: 損失: 0.3714, lb_score: 0.0038
# エポック 38: 損失: 0.3511, lb_score: 0.0023
# エポック 39: 損失: 0.3320, lb_score: 0.0062
# エポック 152: 損失: 0.0139, lb_score: 0.5089
# エポック 153: 損失: 0.0135, lb_score: 0.4706
# エポック 154: 損失: 0.0127, lb_score: 0.4207
# エポック 155: 損失: 0.0121, lb_score: 0.4468
# エポック 156: 損失: 0.0133, lb_score: 0.4847
# エポック 157: 損失: 0.0138, lb_score: 0.4602
# エポック 158: 損失: 0.0129, lb_score: 0.5565
# エポック 159: 損失: 0.0122, lb_score: 0.5030
# エポック 160: 損失: 0.0130, lb_score: 0.5108
# エポック 161: 損失: 0.0116, lb_score: 0.3822
# エポック 162: 損失: 0.0124, lb_score: 0.4744
# エポック 163: 損失: 0.0113, lb_score: 0.4465
# エポック 164: 損失: 0.0112, lb_score: 0.4045
# エポック 165: 損失: 0.0111, lb_score: 0.5370
# エポック 166: 損失: 0.0123, lb_score: 0.5717
# エポック 167: 損失: 0.0126, lb_score: 0.3796
# エポック 168: 損失: 0.0103, lb_score: 0.6610
# エポック 169: 損失: 0.0112, lb_score: 0.5845
# エポック 170: 損失: 0.0106, lb_score: 0.6417
# エポック 171: 損失: 0.0112, lb_score: 0.5462
# エポック 172: 損失: 0.0125, lb_score: 0.6005
# エポック 173: 損失: 0.0108, lb_score: 0.5584
# エポック 174: 損失: 0.0110, lb_score: 0.5700
# エポック 175: 損失: 0.0100, lb_score: 0.5695
# エポック 176: 損失: 0.0124, lb_score: 0.5886
# エポック 177: 損失: 0.0106, lb_score: 0.5559
# エポック 178: 損失: 0.0105, lb_score: 0.6168
# エポック 179: 損失: 0.0094, lb_score: 0.6127
# エポック 180: 損失: 0.0094, lb_score: 0.5625
# エポック 181: 損失: 0.0091, lb_score: 0.5966
# エポック 182: 損失: 0.0106, lb_score: 0.5805
# エポック 183: 損失: 0.0107, lb_score: 0.5783
# エポック 184: 損失: 0.0093, lb_score: 0.6560
# エポック 185: 損失: 0.0090, lb_score: 0.6736
# エポック 186: 損失: 0.0100, lb_score: 0.7526
# エポック 187: 損失: 0.0104, lb_score: 0.7487
# エポック 188: 損失: 0.0102, lb_score: 0.7040
# エポック 189: 損失: 0.0113, lb_score: 0.7053
# エポック 190: 損失: 0.0090, lb_score: 0.7307
# エポック 191: 損失: 0.0097, lb_score: 0.7451
# エポック 192: 損失: 0.0084, lb_score: 0.5634
# エポック 193: 損失: 0.0089, lb_score: 0.6582
# エポック 194: 損失: 0.0075, lb_score: 0.7893
# エポック 195: 損失: 0.0074, lb_score: 0.7536
# エポック 196: 損失: 0.0084, lb_score: 0.8315
# エポック 197: 損失: 0.0078, lb_score: 0.7614
# エポック 198: 損失: 0.0085, lb_score: 0.6083
# エポック 199: 損失: 0.0073, lb_score: 0.6913
# エポック 200: 損失: 0.0071, lb_score: 0.7578

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_5_4']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 32
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_5_4 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=1, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
#  0         apo-ferritin  21  46   18    28   3   0.857143  0.391304  0.404227
#  1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
#  2   beta-galactosidase  51  12   12     0  39   0.235294  1.000000  0.839506
#  3             ribosome  83  31   27     4  56   0.325301  0.870968  0.792746
#  4        thyroglobulin  87  30   26     4  61   0.298851  0.866667  0.779541
#  5  virus-like-particle  39  11   11     0  28   0.282051  1.000000  0.869767
#
#     weight
#  0       1
#  1       0
#  2       2
#  3       1
#  4       2
#  5       1  ,
#  0.7578337152324256)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
