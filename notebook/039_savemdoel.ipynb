# %%
from helpers import *
from dataset import *
from model2_for39 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(100, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
    RandGaussianNoised(
        keys=["image"],
        prob=0.2,  # 適用確率
        mean=0.0,  # ノイズの平均
        std=0.05   # ノイズの標準偏差
    ),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 217
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 995027.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1521868.0

# %%
GPU_ID = 0
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:0

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.5062
# 検証_loss=2.000930142402649
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  52  11    0    11  52        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.9997
# 検証_loss=1.6502257585525513
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1   0.000000  0.000000  0.00000
# 1         beta-amylase   3  10    0    10   3   0.000000  0.000000  0.00000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.00000
# 3             ribosome   2  31    0    31   2   0.000000  0.000000  0.00000
# 4        thyroglobulin  10  30    0    30  10   0.000000  0.000000  0.00000
# 5  virus-like-particle  72  11    6     5  66   0.083333  0.545455  0.41129
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.05875576036866359)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0588
# エポック 3/30
# ----------
# 訓練_loss: 0.6369
# 検証_loss=1.3431308269500732
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision  recall  \
# 0         apo-ferritin   292  46    0    46   292   0.000000     0.0
# 1         beta-amylase  3046  10    0    10  3046   0.000000     0.0
# 2   beta-galactosidase   260  12    0    12   260   0.000000     0.0
# 3             ribosome  1631  31    0    31  1631   0.000000     0.0
# 4        thyroglobulin   433  30    3    27   430   0.006928     0.1
# 5  virus-like-particle    17  11   11     0     6   0.647059     1.0
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.055860       2
# 5  0.968912       1  , 0.15437593182770784)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1544
# エポック 4/30
# ----------
# 訓練_loss: 0.4611
# 検証_loss=1.3111966729164124
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  5000  46    7    39  4993   0.001400  0.152174
# 1         beta-amylase  1101  10    6     4  1095   0.005450  0.600000
# 2   beta-galactosidase   768  12    2    10   766   0.002604  0.166667
# 3             ribosome  4815  31    4    27  4811   0.000831  0.129032
# 4        thyroglobulin   929  30    9    21   920   0.009688  0.300000
# 5  virus-like-particle   110  11   11     0    99   0.100000  1.000000
#
#     f-beta4  weight
# 0  0.020746       1
# 1  0.080888       0
# 2  0.035417       2
# 3  0.012804       1
# 4  0.108588       2
# 5  0.653846       1  , 0.13934350978926557)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1393
# エポック 5/30
# ----------
# 訓練_loss: 0.3578
# 検証_loss=1.92311532497406
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   93  46    5    41   88   0.053763  0.108696
# 1         beta-amylase   18  10    0    10   18   0.000000  0.000000
# 2   beta-galactosidase  142  12    2    10  140   0.014085  0.166667
# 3             ribosome   32  31    8    23   24   0.250000  0.258065
# 4        thyroglobulin  463  30   23     7  440   0.049676  0.766667
# 5  virus-like-particle   19  11    8     3   11   0.421053  0.727273
#
#     f-beta4  weight
# 0  0.102533       1
# 1  0.000000       0
# 2  0.101796       2
# 3  0.257576       1
# 4  0.414634       2
# 5  0.697436       1  , 0.2986294192232605)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2986
# エポック 6/30
# ----------
# 訓練_loss: 0.3062
# 検証_loss=1.4011376917362213
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  169  46    7    39  162   0.041420  0.152174
# 1         beta-amylase    5  10    0    10    5   0.000000  0.000000
# 2   beta-galactosidase  282  12    6     6  276   0.021277  0.500000
# 3             ribosome   78  31    8    23   70   0.102564  0.258065
# 4        thyroglobulin  259  30   22     8  237   0.084942  0.733333
# 5  virus-like-particle   38  11   11     0   27   0.289474  1.000000
#
#     f-beta4  weight
# 0  0.131492       1
# 1  0.000000       0
# 2  0.215190       2
# 3  0.236934       1
# 4  0.506089       2
# 5  0.873832       1  , 0.38354509327277075)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3835
# エポック 7/30
# ----------
# 訓練_loss: 0.2614
# 検証_loss=2.3527548551559447
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  145  46    8    38  137   0.055172  0.173913
# 1         beta-amylase    1  10    0    10    1   0.000000  0.000000
# 2   beta-galactosidase  173  12    1    11  172   0.005780  0.083333
# 3             ribosome  116  31    1    30  115   0.008621  0.032258
# 4        thyroglobulin  123  30    3    27  120   0.024390  0.100000
# 5  virus-like-particle   19  11   11     0    8   0.578947  1.000000
#
#     f-beta4  weight
# 0  0.154370       1
# 1  0.000000       0
# 2  0.046575       2
# 3  0.027778       1
# 4  0.084577       2
# 5  0.958974       1  , 0.20048958351308263)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2005
# エポック 8/30
# ----------
# 訓練_loss: 0.2512
# 検証_loss=1.8481415629386901
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  153  46   11    35  142   0.071895  0.239130
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  234  12    8     4  226   0.034188  0.666667
# 3             ribosome   36  31   13    18   23   0.361111  0.419355
# 4        thyroglobulin  236  30   22     8  214   0.093220  0.733333
# 5  virus-like-particle   36  11   11     0   25   0.305556  1.000000
#
#     f-beta4  weight
# 0  0.210349       1
# 1  0.000000       0
# 2  0.319249       2
# 3  0.415414       1
# 4  0.522346       2
# 5  0.882075       1  , 0.4558611574223893)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4559
# エポック 9/30
# ----------
# 訓練_loss: 0.2234
# 検証_loss=1.4767005920410157
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   84  46   13    33   71   0.154762  0.282609
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  258  12   10     2  248   0.038760  0.833333
# 3             ribosome  147  31    5    26  142   0.034014  0.161290
# 4        thyroglobulin  430  30   18    12  412   0.041860  0.600000
# 5  virus-like-particle   19  11   11     0    8   0.578947  1.000000
#
#     f-beta4  weight
# 0  0.269512       1
# 1  0.000000       0
# 2  0.377778       2
# 3  0.132193       1
# 4  0.336264       2
# 5  0.958974       1  , 0.39839463260193614)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3984
# エポック 10/30
# ----------
# 訓練_loss: 0.2084
# 検証_loss=1.4736607909202575
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  203  46   10    36  193   0.049261  0.217391
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  307  12   10     2  297   0.032573  0.833333
# 3             ribosome   36  31    9    22   27   0.250000  0.290323
# 4        thyroglobulin  360  30   23     7  337   0.063889  0.766667
# 5  virus-like-particle   70  11   11     0   59   0.157143  1.000000
#
#     f-beta4  weight
# 0  0.181044       1
# 1  0.000000       0
# 2  0.340681       2
# 3  0.287594       1
# 4  0.465476       2
# 5  0.760163       1  , 0.40587362235192626)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4059
# エポック 11/30
# ----------
# 訓練_loss: 0.2217
# 検証_loss=2.118595576286316
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  142  46   12    34  130   0.084507  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  219  12    7     5  212   0.031963  0.583333
# 3             ribosome   85  31   17    14   68   0.200000  0.548387
# 4        thyroglobulin  432  30   23     7  409   0.053241  0.766667
# 5  virus-like-particle   13  11    9     2    4   0.692308  0.818182
#
#     f-beta4  weight
# 0  0.232346       1
# 1  0.000000       0
# 2  0.289538       2
# 3  0.497418       1
# 4  0.428728       2
# 5  0.809524       1  , 0.4251171230756423)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4251
# エポック 12/30
# ----------
# 訓練_loss: 0.1967
# 検証_loss=2.930069661140442
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   56  46    6    40   50   0.107143  0.130435
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  124  12    2    10  122   0.016129  0.166667
# 3             ribosome   29  31   10    21   19   0.344828  0.322581
# 4        thyroglobulin  128  30    6    24  122   0.046875  0.200000
# 5  virus-like-particle   30  11   11     0   19   0.366667  1.000000
#
#     f-beta4  weight
# 0  0.128788       1
# 1  0.000000       0
# 2  0.107595       2
# 3  0.323810       1
# 4  0.167763       2
# 5  0.907767       1  , 0.27301151172798)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2730
# エポック 13/30
# ----------
# 訓練_loss: 0.1969
# 検証_loss=2.604267346858978
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   30  46    8    38   22   0.266667  0.173913
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  135  12    4     8  131   0.029630  0.333333
# 3             ribosome  115  31   12    19  103   0.104348  0.387097
# 4        thyroglobulin  207  30   16    14  191   0.077295  0.533333
# 5  virus-like-particle   11  11    9     2    2   0.818182  0.818182
#
#     f-beta4  weight
# 0  0.177546       1
# 1  0.000000       0
# 2  0.207951       2
# 3  0.333879       1
# 4  0.395924       2
# 5  0.818182       1  , 0.3624795935724444)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3625
# エポック 14/30
# ----------
# 訓練_loss: 0.1962
# 検証_loss=2.5354308485984802
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   33  46   11    35   22   0.333333  0.239130
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  162  12    5     7  157   0.030864  0.416667
# 3             ribosome   51  31   15    16   36   0.294118  0.483871
# 4        thyroglobulin  245  30   20    10  225   0.081633  0.666667
# 5  virus-like-particle    8  11    6     5    2   0.750000  0.545455
#
#     f-beta4  weight
# 0  0.243173       1
# 1  0.000000       0
# 2  0.240113       2
# 3  0.466179       1
# 4  0.468966       2
# 5  0.554348       1  , 0.383122422886458)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3831
# エポック 15/30
# ----------
# 訓練_loss: 0.1968
# 検証_loss=2.34407525062561
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   35  46   12    34   23   0.342857  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  193  12    3     9  190   0.015544  0.250000
# 3             ribosome  125  31   15    16  110   0.120000  0.483871
# 4        thyroglobulin  280  30   16    14  264   0.057143  0.533333
# 5  virus-like-particle   15  11   11     0    4   0.733333  1.000000
#
#     f-beta4  weight
# 0  0.264591       1
# 1  0.000000       0
# 2  0.132468       2
# 3  0.410628       1
# 4  0.357895       2
# 5  0.979058       1  , 0.376428798464957)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3764
# エポック 16/30
# ----------
# 訓練_loss: 0.1907
# 検証_loss=2.389115941524506
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   63  46   14    32   49   0.222222  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  156  12    6     6  150   0.038462  0.500000
# 3             ribosome  116  31   10    21  106   0.086207  0.322581
# 4        thyroglobulin  404  30   23     7  381   0.056931  0.766667
# 5  virus-like-particle   45  11   11     0   34   0.244444  1.000000
#
#     f-beta4  weight
# 0  0.297872       1
# 1  0.000000       0
# 2  0.293103       2
# 3  0.277778       1
# 4  0.442308       2
# 5  0.846154       1  , 0.4132323207891807)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4132
# エポック 17/30
# ----------
# 訓練_loss: 0.1704
# 検証_loss=1.6799567699432374
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   67  46   12    34   55   0.179104  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  270  12   10     2  260   0.037037  0.833333
# 3             ribosome   56  31   14    17   42   0.250000  0.451613
# 4        thyroglobulin  581  30   23     7  558   0.039587  0.766667
# 5  virus-like-particle   46  11   11     0   35   0.239130  1.000000
#
#     f-beta4  weight
# 0  0.254047       1
# 1  0.000000       0
# 2  0.367965       2
# 3  0.431159       1
# 4  0.368520       2
# 5  0.842342       1  , 0.4286457641296236)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4286
# エポック 18/30
# ----------
# 訓練_loss: 0.1581
# 検証_loss=2.0820940375328063
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   29  46   16    30   13   0.551724  0.347826
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  166  12    8     4  158   0.048193  0.666667
# 3             ribosome   98  31   15    16   83   0.153061  0.483871
# 4        thyroglobulin  434  30   21     9  413   0.048387  0.700000
# 5  virus-like-particle   17  11   11     0    6   0.647059  1.000000
#
#     f-beta4  weight
# 0  0.355556       1
# 1  0.000000       0
# 2  0.379888       2
# 3  0.429293       1
# 4  0.390591       2
# 5  0.968912       1  , 0.4706740796451138)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4707
# エポック 19/30
# ----------
# 訓練_loss: 0.1678
# 検証_loss=3.28396418094635
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   49  46   11    35   38   0.224490  0.239130
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    9  12    0    12    9   0.000000  0.000000
# 3             ribosome   88  31   15    16   73   0.170455  0.483871
# 4        thyroglobulin  266  30    1    29  265   0.003759  0.033333
# 5  virus-like-particle   11  11    2     9    9   0.181818  0.181818
#
#     f-beta4  weight
# 0  0.238217       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.436644       1
# 4  0.022788       2
# 5  0.181818       1  , 0.12889356935012525)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1289
# エポック 20/30
# ----------
# 訓練_loss: 0.1728
# 検証_loss=3.211314058303833
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    7  46    5    41    2   0.714286  0.108696
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    9  12    0    12    9   0.000000  0.000000
# 3             ribosome   98  31    1    30   97   0.010204  0.032258
# 4        thyroglobulin  177  30    7    23  170   0.039548  0.233333
# 5  virus-like-particle    6  11    6     5    0   1.000000  0.545455
#
#     f-beta4  weight
# 0  0.114401       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.028620       1
# 4  0.181126       2
# 5  0.560440       1  , 0.1522446899139474)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1522
# エポック 21/30
# ----------
# 訓練_loss: 0.1722
# 検証_loss=1.8731637239456176
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   59  46   11    35   48   0.186441  0.239130
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  254  12    9     3  245   0.035433  0.750000
# 3             ribosome  338  31   21    10  317   0.062130  0.677419
# 4        thyroglobulin  662  30   23     7  639   0.034743  0.766667
# 5  virus-like-particle   15  11   11     0    4   0.733333  1.000000
#
#     f-beta4  weight
# 0  0.235220       1
# 1  0.000000       0
# 2  0.343049       2
# 3  0.428058       1
# 4  0.342382       2
# 5  0.979058       1  , 0.43045678553629496)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4305
# エポック 22/30
# ----------
# 訓練_loss: 0.1537
# 検証_loss=2.326325559616089
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   27  46   19    27    8   0.703704  0.413043
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  123  12    8     4  115   0.065041  0.666667
# 3             ribosome  360  31   14    17  346   0.038889  0.451613
# 4        thyroglobulin  445  30   20    10  425   0.044944  0.666667
# 5  virus-like-particle   22  11   11     0   11   0.500000  1.000000
#
#     f-beta4  weight
# 0  0.423329       1
# 1  0.000000       0
# 2  0.431746       2
# 3  0.278037       1
# 4  0.367568       2
# 5  0.944444       1  , 0.4634911415517974)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4635
# エポック 23/30
# ----------
# 訓練_loss: 0.1474
# 検証_loss=3.1021696090698243
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   42  46   15    31   27   0.357143  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   38  12    1    11   37   0.026316  0.083333
# 3             ribosome  131  31    8    23  123   0.061069  0.258065
# 4        thyroglobulin  210  30    2    28  208   0.009524  0.066667
# 5  virus-like-particle   25  11   11     0   14   0.440000  1.000000
#
#     f-beta4  weight
# 0  0.327763       1
# 1  0.000000       0
# 2  0.073913       2
# 3  0.216906       1
# 4  0.049275       2
# 5  0.930348       1  , 0.2459134953658653)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2459
# エポック 24/30
# ----------
# 訓練_loss: 0.1573
# 検証_loss=2.116064977645874
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  110  46   17    29   93   0.154545  0.369565
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   32  12    5     7   27   0.156250  0.416667
# 3             ribosome  545  31   11    20  534   0.020183  0.354839
# 4        thyroglobulin   24  30    1    29   23   0.041667  0.033333
# 5  virus-like-particle   22  11    9     2   13   0.409091  0.818182
#
#     f-beta4  weight
# 0  0.341608       1
# 1  0.000000       0
# 2  0.379464       2
# 3  0.179635       1
# 4  0.033730       2
# 5  0.772727       1  , 0.30290838471520914)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3029
# エポック 25/30
# ----------
# 訓練_loss: 0.1441
# 検証_loss=3.112099361419678
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  109  46   16    30   93   0.146789  0.347826
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  131  12    5     7  126   0.038168  0.416667
# 3             ribosome   47  31   18    13   29   0.382979  0.580645
# 4        thyroglobulin  184  30    8    22  176   0.043478  0.266667
# 5  virus-like-particle   44  11    9     2   35   0.204545  0.818182
#
#     f-beta4  weight
# 0  0.321893       1
# 1  0.000000       0
# 2  0.263158       2
# 3  0.563536       1
# 4  0.204819       2
# 5  0.695455       1  , 0.35954832741022397)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3595
# エポック 26/30
# ----------
# 訓練_loss: 0.1540
# 検証_loss=1.7544339895248413
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   44  46   20    26   24   0.454545  0.434783
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  217  12   10     2  207   0.046083  0.833333
# 3             ribosome   99  31   19    12   80   0.191919  0.612903
# 4        thyroglobulin  358  30   24     6  334   0.067039  0.800000
# 5  virus-like-particle   41  11   11     0   30   0.268293  1.000000
#
#     f-beta4  weight
# 0  0.435897       1
# 1  0.000000       0
# 2  0.415648       2
# 3  0.542857       1
# 4  0.486874       2
# 5  0.861751       1  , 0.5207926558650768)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.5208
# エポック 27/30
# ----------
# 訓練_loss: 0.1352
# 検証_loss=1.579941201210022
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   38  46   15    31   23   0.394737  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  354  12   10     2  344   0.028249  0.833333
# 3             ribosome  146  31   14    17  132   0.095890  0.451613
# 4        thyroglobulin  407  30   24     6  383   0.058968  0.800000
# 5  virus-like-particle   15  11   11     0    4   0.733333  1.000000
#
#     f-beta4  weight
# 0  0.329457       1
# 1  0.000000       0
# 2  0.311355       2
# 3  0.370717       1
# 4  0.459977       2
# 5  0.979058       1  , 0.4602709991070765)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4603
# エポック 28/30
# ----------
# 訓練_loss: 0.1431
# 検証_loss=2.3858790397644043
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  511  46    4    42  507   0.007828  0.086957
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   26  12    0    12   26   0.000000  0.000000
# 3             ribosome  408  31    1    30  407   0.002451  0.032258
# 4        thyroglobulin  209  30    2    28  207   0.009569  0.066667
# 5  virus-like-particle   23  11   11     0   12   0.478261  1.000000
#
#     f-beta4  weight
# 0  0.054531       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.018805       1
# 4  0.049347       2
# 5  0.939698       1  , 0.15881834790939672)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1588
# エポック 29/30
# ----------
# 訓練_loss: 0.1431
# 検証_loss=1.7019296407699585
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   53  46   14    32   39   0.264151  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  201  12    9     3  192   0.044776  0.750000
# 3             ribosome  119  31   12    19  107   0.100840  0.387097
# 4        thyroglobulin  415  30   22     8  393   0.053012  0.733333
# 5  virus-like-particle   30  11   11     0   19   0.366667  1.000000
#
#     f-beta4  weight
# 0  0.301648       1
# 1  0.000000       0
# 2  0.389313       2
# 3  0.331707       1
# 4  0.417877       2
# 5  0.907767       1  , 0.4507860152524089)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4508
# エポック 30/30
# ----------
# 訓練_loss: 0.1337
# 検証_loss=3.4714505195617678
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   49  46   12    34   37   0.244898  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   61  12    1    11   60   0.016393  0.083333
# 3             ribosome  169  31    1    30  168   0.005917  0.032258
# 4        thyroglobulin   99  30    1    29   98   0.010101  0.033333
# 5  virus-like-particle   19  11   11     0    8   0.578947  1.000000
#
#     f-beta4  weight
# 0  0.259873       1
# 1  0.000000       0
# 2  0.067194       2
# 3  0.025564       1
# 4  0.029361       2
# 5  0.958974       1  , 0.20536002376600315)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2054
#
# 全エポックの結果:
# エポック 1: 損失: 1.5062, lb_score: 0.0000
# エポック 2: 損失: 0.9997, lb_score: 0.0588
# エポック 3: 損失: 0.6369, lb_score: 0.1544
# エポック 4: 損失: 0.4611, lb_score: 0.1393
# エポック 5: 損失: 0.3578, lb_score: 0.2986
# エポック 6: 損失: 0.3062, lb_score: 0.3835
# エポック 7: 損失: 0.2614, lb_score: 0.2005
# エポック 8: 損失: 0.2512, lb_score: 0.4559
# エポック 9: 損失: 0.2234, lb_score: 0.3984
# エポック 10: 損失: 0.2084, lb_score: 0.4059
# エポック 11: 損失: 0.2217, lb_score: 0.4251
# エポック 12: 損失: 0.1967, lb_score: 0.2730
# エポック 13: 損失: 0.1969, lb_score: 0.3625
# エポック 14: 損失: 0.1962, lb_score: 0.3831
# エポック 15: 損失: 0.1968, lb_score: 0.3764
# エポック 16: 損失: 0.1907, lb_score: 0.4132
# エポック 17: 損失: 0.1704, lb_score: 0.4286
# エポック 18: 損失: 0.1581, lb_score: 0.4707
# エポック 19: 損失: 0.1678, lb_score: 0.1289
# エポック 20: 損失: 0.1728, lb_score: 0.1522
# エポック 21: 損失: 0.1722, lb_score: 0.4305
# エポック 22: 損失: 0.1537, lb_score: 0.4635
# エポック 23: 損失: 0.1474, lb_score: 0.2459
# エポック 24: 損失: 0.1573, lb_score: 0.3029
# エポック 25: 損失: 0.1441, lb_score: 0.3595
# エポック 26: 損失: 0.1540, lb_score: 0.5208
# エポック 27: 損失: 0.1352, lb_score: 0.4603
# エポック 28: 損失: 0.1431, lb_score: 0.1588
# エポック 29: 損失: 0.1431, lb_score: 0.4508
# エポック 30: 損失: 0.1337, lb_score: 0.2054

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
#  0         apo-ferritin  709  36   12    24  697   0.016925  0.333333
#  1         beta-amylase    0  21    0    21    0   0.000000  0.000000
#  2   beta-galactosidase  555  24   14    10  541   0.025225  0.583333
#  3             ribosome  568  65    6    59  562   0.010563  0.092308
#  4        thyroglobulin  964  49   22    27  942   0.022822  0.448980
#  5  virus-like-particle  242  13   13     0  229   0.053719  1.000000
#
#      f-beta4  weight
#  0  0.158755       1
#  1  0.000000       0
#  2  0.253461       2
#  3  0.063433       1
#  4  0.213959       2
#  5  0.491111       1  ,
#  0.23544838408621654)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
