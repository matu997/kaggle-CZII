# %%
from helpers import *
from dataset import *
from model2_for41 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(100, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
    RandGaussianNoised(
        keys=["image"],
        prob=0.2,  # 適用確率
        mean=0.0,  # ノイズの平均
        std=0.05   # ノイズの標準偏差
    ),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 217
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 957895.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 29565.0

# %%
GPU_ID = 4
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:4

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.4816
# 検証_loss=1.5026729822158813
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 1.0830
# 検証_loss=1.6133099317550659
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   6  46    0    46   6        0.0     0.0      0.0
# 1         beta-amylase  12  10    0    10  12        0.0     0.0      0.0
# 2   beta-galactosidase   4  12    0    12   4        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   3  30    0    30   3        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 3/30
# ----------
# 訓練_loss: 0.7708
# 検証_loss=0.7960785269737244
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  1491  46    0    46  1491   0.000000  0.000000
# 1         beta-amylase  1776  10    0    10  1776   0.000000  0.000000
# 2   beta-galactosidase   648  12    0    12   648   0.000000  0.000000
# 3             ribosome  2495  31    0    31  2495   0.000000  0.000000
# 4        thyroglobulin  3468  30    0    30  3468   0.000000  0.000000
# 5  virus-like-particle    17  11   10     1     7   0.588235  0.909091
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.880829       1  , 0.12583271650629163)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1258
# エポック 4/30
# ----------
# 訓練_loss: 0.5527
# 検証_loss=1.1077038645744324
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   110  46    9    37   101   0.081818  0.195652
# 1         beta-amylase   744  10    0    10   744   0.000000  0.000000
# 2   beta-galactosidase  2513  12   10     2  2503   0.003979  0.833333
# 3             ribosome   205  31    0    31   205   0.000000  0.000000
# 4        thyroglobulin  2299  30    2    28  2297   0.000870  0.066667
# 5  virus-like-particle    62  11   11     0    51   0.177419  1.000000
#
#     f-beta4  weight
# 0  0.180851       1
# 1  0.000000       0
# 2  0.062847       2
# 3  0.000000       1
# 4  0.012235       2
# 5  0.785714       1  , 0.15953253484208932)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1595
# エポック 5/30
# ----------
# 訓練_loss: 0.4233
# 検証_loss=1.1835010349750519
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  214  46    6    40  208   0.028037  0.130435
# 1         beta-amylase  235  10    0    10  235   0.000000  0.000000
# 2   beta-galactosidase  715  12    9     3  706   0.012587  0.750000
# 3             ribosome  614  31    5    26  609   0.008143  0.161290
# 4        thyroglobulin  540  30   23     7  517   0.042593  0.766667
# 5  virus-like-particle   20  11   10     1   10   0.500000  0.909091
#
#     f-beta4  weight
# 0  0.107368       1
# 1  0.000000       0
# 2  0.168688       2
# 3  0.076577       1
# 4  0.383333       2
# 5  0.867347       1  , 0.30790493825574833)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3079
# エポック 6/30
# ----------
# 訓練_loss: 0.3563
# 検証_loss=1.9845866322517396
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  213  46    6    40  207   0.028169  0.130435
# 1         beta-amylase  124  10    0    10  124   0.000000  0.000000
# 2   beta-galactosidase  157  12    6     6  151   0.038217  0.500000
# 3             ribosome  918  31   10    21  908   0.010893  0.322581
# 4        thyroglobulin  379  30   19    11  360   0.050132  0.633333
# 5  virus-like-particle   41  11   11     0   30   0.268293  1.000000
#
#     f-beta4  weight
# 0  0.107482       1
# 1  0.000000       0
# 2  0.292264       2
# 3  0.120226       1
# 4  0.376019       2
# 5  0.861751       1  , 0.34657478474355774)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3466
# エポック 7/30
# ----------
# 訓練_loss: 0.3044
# 検証_loss=0.8683472454547883
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   253  46   11    35   242   0.043478  0.239130
# 1         beta-amylase   165  10    0    10   165   0.000000  0.000000
# 2   beta-galactosidase   557  12    8     4   549   0.014363  0.666667
# 3             ribosome  1182  31    9    22  1173   0.007614  0.290323
# 4        thyroglobulin   740  30   14    16   726   0.018919  0.466667
# 5  virus-like-particle    47  11   11     0    36   0.234043  1.000000
#
#     f-beta4  weight
# 0  0.189080       1
# 1  0.000000       0
# 2  0.181575       2
# 3  0.091180       1
# 4  0.195082       2
# 5  0.838565       1  , 0.2674485256427051)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2674
# エポック 8/30
# ----------
# 訓練_loss: 0.2867
# 検証_loss=2.2667834758758545
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  201  46    8    38  193   0.039801  0.173913
# 1         beta-amylase    1  10    0    10    1   0.000000  0.000000
# 2   beta-galactosidase  145  12    9     3  136   0.062069  0.750000
# 3             ribosome  227  31   13    18  214   0.057269  0.419355
# 4        thyroglobulin  530  30   19    11  511   0.035849  0.633333
# 5  virus-like-particle   17  11   11     0    6   0.647059  1.000000
#
#     f-beta4  weight
# 0  0.145144       1
# 1  0.000000       0
# 2  0.454006       2
# 3  0.305671       1
# 4  0.319802       2
# 5  0.968912       1  , 0.42390609140227553)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4239
# エポック 9/30
# ----------
# 訓練_loss: 0.2732
# 検証_loss=2.576172876358032
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   76  46    5    41   71   0.065789  0.108696
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  192  12    8     4  184   0.041667  0.666667
# 3             ribosome   41  31    7    24   34   0.170732  0.225806
# 4        thyroglobulin  519  30   23     7  496   0.044316  0.766667
# 5  virus-like-particle   10  11    9     2    1   0.900000  0.818182
#
#     f-beta4  weight
# 0  0.104680       1
# 1  0.000000       0
# 2  0.354167       2
# 3  0.221601       1
# 4  0.391391       2
# 5  0.822581       1  , 0.3771397219987122)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3771
# エポック 10/30
# ----------
# 訓練_loss: 0.2770
# 検証_loss=1.8611647844314576
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   53  46    8    38   45   0.150943  0.173913
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  207  12    8     4  199   0.038647  0.666667
# 3             ribosome   44  31    9    22   35   0.204545  0.290323
# 4        thyroglobulin  364  30   23     7  341   0.063187  0.766667
# 5  virus-like-particle   13  11   11     0    2   0.846154  1.000000
#
#     f-beta4  weight
# 0  0.172370       1
# 1  0.000000       0
# 2  0.340852       2
# 3  0.283333       1
# 4  0.463270       2
# 5  0.989418       1  , 0.4361951366404343)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4362
# エポック 11/30
# ----------
# 訓練_loss: 0.2537
# 検証_loss=1.6624704599380493
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  219  46   10    36  209   0.045662  0.217391
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  375  12    9     3  366   0.024000  0.750000
# 3             ribosome   60  31   12    19   48   0.200000  0.387097
# 4        thyroglobulin  737  30   23     7  714   0.031208  0.766667
# 5  virus-like-particle   13  11   11     0    2   0.846154  1.000000
#
#     f-beta4  weight
# 0  0.178010       1
# 1  0.000000       0
# 2  0.269841       2
# 3  0.366906       1
# 4  0.321282       2
# 5  0.989418       1  , 0.3880830223297284)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3881
# エポック 12/30
# ----------
# 訓練_loss: 0.2416
# 検証_loss=1.48819899559021
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   79  46    6    40   73   0.075949  0.130435
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  306  12   10     2  296   0.032680  0.833333
# 3             ribosome   43  31    9    22   34   0.209302  0.290323
# 4        thyroglobulin  467  30   23     7  444   0.049251  0.766667
# 5  virus-like-particle   18  11   11     0    7   0.611111  1.000000
#
#     f-beta4  weight
# 0  0.125153       1
# 1  0.000000       0
# 2  0.341365       2
# 3  0.283859       1
# 4  0.412883       2
# 5  0.963918       1  , 0.4116323424782)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4116
# エポック 13/30
# ----------
# 訓練_loss: 0.2249
# 検証_loss=1.1988033950328827
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  230  46   12    34  218   0.052174  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  260  12   10     2  250   0.038462  0.833333
# 3             ribosome   78  31    6    25   72   0.076923  0.193548
# 4        thyroglobulin  696  30   23     7  673   0.033046  0.766667
# 5  virus-like-particle   29  11   11     0   18   0.379310  1.000000
#
#     f-beta4  weight
# 0  0.211180       1
# 1  0.000000       0
# 2  0.376106       2
# 3  0.177700       1
# 4  0.332483       2
# 5  0.912195       1  , 0.38832199576885235)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3883
# エポック 14/30
# ----------
# 訓練_loss: 0.2281
# 検証_loss=2.812847685813904
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   28  46   12    34   16   0.428571  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   55  12    3     9   52   0.054545  0.250000
# 3             ribosome   54  31   17    14   37   0.314815  0.548387
# 4        thyroglobulin  237  30   17    13  220   0.071730  0.566667
# 5  virus-like-particle   20  11    9     2   11   0.450000  0.818182
#
#     f-beta4  weight
# 0  0.267016       1
# 1  0.000000       0
# 2  0.206478       2
# 3  0.525455       1
# 4  0.403068       2
# 5  0.780612       1  , 0.3988820919085)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3989
# エポック 15/30
# ----------
# 訓練_loss: 0.2265
# 検証_loss=3.3235485553741455
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    8  46    2    44    6   0.250000  0.043478
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   74  12    0    12   74   0.000000  0.000000
# 3             ribosome    2  31    0    31    2   0.000000  0.000000
# 4        thyroglobulin  176  30   10    20  166   0.056818  0.333333
# 5  virus-like-particle    8  11    8     3    0   1.000000  0.727273
#
#     f-beta4  weight
# 0  0.045699       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.259146       2
# 5  0.739130       1  , 0.18616029177723153)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1862
# エポック 16/30
# ----------
# 訓練_loss: 0.2108
# 検証_loss=4.730679202079773
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  17  46    6    40  11   0.352941  0.130435  0.135458
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  13  12    0    12  13   0.000000  0.000000  0.000000
# 3             ribosome  29  31    3    28  26   0.103448  0.096774  0.097143
# 4        thyroglobulin  38  30    1    29  37   0.026316  0.033333  0.032819
# 5  virus-like-particle  10  11    4     7   6   0.400000  0.363636  0.365591
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.09483278399429464)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0948
# エポック 17/30
# ----------
# 訓練_loss: 0.2071
# 検証_loss=1.8628112196922302
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  107  46   15    31   92   0.140187  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  292  12    9     3  283   0.030822  0.750000
# 3             ribosome  159  31    9    22  150   0.056604  0.290323
# 4        thyroglobulin  442  30   24     6  418   0.054299  0.800000
# 5  virus-like-particle   65  11   11     0   54   0.169231  1.000000
#
#     f-beta4  weight
# 0  0.302491       1
# 1  0.000000       0
# 2  0.316116       2
# 3  0.233588       1
# 4  0.442516       2
# 5  0.775934       1  , 0.4041823489057896)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4042
# エポック 18/30
# ----------
# 訓練_loss: 0.2024
# 検証_loss=0.876079934835434
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   77  46   14    32   63   0.181818  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  353  12   10     2  343   0.028329  0.833333
# 3             ribosome  244  31   11    20  233   0.045082  0.354839
# 4        thyroglobulin  610  30   17    13  593   0.027869  0.566667
# 5  virus-like-particle   23  11   11     0   12   0.478261  1.000000
#
#     f-beta4  weight
# 0  0.292743       1
# 1  0.000000       0
# 2  0.311927       2
# 3  0.252703       1
# 4  0.265138       2
# 5  0.939698       1  , 0.3770389375658944)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3770
# エポック 19/30
# ----------
# 訓練_loss: 0.2166
# 検証_loss=5.133684468269348
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   4  46    0    46   4        0.0     0.0      0.0
# 1         beta-amylase   0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase   3  12    0    12   3        0.0     0.0      0.0
# 3             ribosome  17  31    0    31  17        0.0     0.0      0.0
# 4        thyroglobulin  87  30    0    30  87        0.0     0.0      0.0
# 5  virus-like-particle   1  11    0    11   1        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 20/30
# ----------
# 訓練_loss: 0.2063
# 検証_loss=0.95364710688591
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   159  46   15    31   144   0.094340  0.326087
# 1         beta-amylase     0  10    0    10     0   0.000000  0.000000
# 2   beta-galactosidase   859  12    6     6   853   0.006985  0.500000
# 3             ribosome    90  31   11    20    79   0.122222  0.354839
# 4        thyroglobulin  1699  30   10    20  1689   0.005886  0.333333
# 5  virus-like-particle    81  11   11     0    70   0.135802  1.000000
#
#     f-beta4  weight
# 0  0.284916       1
# 1  0.000000       0
# 2  0.097050       2
# 3  0.319113       1
# 4  0.078017       2
# 5  0.727626       1  , 0.24025586042278896)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2403
# エポック 21/30
# ----------
# 訓練_loss: 0.2071
# 検証_loss=1.448557198047638
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   82  46    9    37   73   0.109756  0.195652
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  190  12   10     2  180   0.052632  0.833333
# 3             ribosome  190  31   21    10  169   0.110526  0.677419
# 4        thyroglobulin  524  30   19    11  505   0.036260  0.633333
# 5  virus-like-particle   27  11   11     0   16   0.407407  1.000000
#
#     f-beta4  weight
# 0  0.187042       1
# 1  0.000000       0
# 2  0.445026       2
# 3  0.520408       1
# 4  0.321713       2
# 5  0.921182       1  , 0.45173009212985626)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4517
# エポック 22/30
# ----------
# 訓練_loss: 0.1786
# 検証_loss=1.570932960510254
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   47  46   14    32   33   0.297872  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  149  12   10     2  139   0.067114  0.833333
# 3             ribosome  140  31   11    20  129   0.078571  0.354839
# 4        thyroglobulin  627  30   22     8  605   0.035088  0.733333
# 5  virus-like-particle   15  11   11     0    4   0.733333  1.000000
#
#     f-beta4  weight
# 0  0.303959       1
# 1  0.000000       0
# 2  0.498534       2
# 3  0.294025       1
# 4  0.337850       2
# 5  0.979058       1  , 0.46425848848795265)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4643
# エポック 23/30
# ----------
# 訓練_loss: 0.1787
# 検証_loss=1.5473808884620666
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   68  46   14    32   54   0.205882  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  248  12    9     3  239   0.036290  0.750000
# 3             ribosome  232  31   15    16  217   0.064655  0.483871
# 4        thyroglobulin  716  30    7    23  709   0.009777  0.233333
# 5  virus-like-particle   14  11   11     0    3   0.785714  1.000000
#
#     f-beta4  weight
# 0  0.296020       1
# 1  0.000000       0
# 2  0.347727       2
# 3  0.350275       1
# 4  0.099498       2
# 5  0.984211       1  , 0.3607080504372811)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3607
# エポック 24/30
# ----------
# 訓練_loss: 0.1767
# 検証_loss=1.7034424662590026
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   90  46   15    31   75   0.166667  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  407  12   10     2  397   0.024570  0.833333
# 3             ribosome  180  31    2    29  178   0.011111  0.064516
# 4        thyroglobulin  744  30   16    14  728   0.021505  0.533333
# 5  virus-like-particle   21  11   11     0   10   0.523810  1.000000
#
#     f-beta4  weight
# 0  0.308717       1
# 1  0.000000       0
# 2  0.283806       2
# 3  0.050296       1
# 4  0.222222       2
# 5  0.949239       1  , 0.33147261084966095)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3315
# エポック 25/30
# ----------
# 訓練_loss: 0.1657
# 検証_loss=1.8395343542098999
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  263  46   18    28  245   0.068441  0.391304
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  151  12    7     5  144   0.046358  0.583333
# 3             ribosome  196  31   20    11  176   0.102041  0.645161
# 4        thyroglobulin  463  30   21     9  442   0.045356  0.700000
# 5  virus-like-particle   61  11   11     0   50   0.180328  1.000000
#
#     f-beta4  weight
# 0  0.306306       1
# 1  0.000000       0
# 2  0.346939       2
# 3  0.491329       1
# 4  0.378579       2
# 5  0.789030       1  , 0.433957268474736)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4340
# エポック 26/30
# ----------
# 訓練_loss: 0.1704
# 検証_loss=1.3719626665115356
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   45  46   14    32   31   0.311111  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  229  12   10     2  219   0.043668  0.833333
# 3             ribosome   76  31   17    14   59   0.223684  0.548387
# 4        thyroglobulin  492  30   16    14  476   0.032520  0.533333
# 5  virus-like-particle   41  11   11     0   30   0.268293  1.000000
#
#     f-beta4  weight
# 0  0.304738       1
# 1  0.000000       0
# 2  0.403800       2
# 3  0.505245       1
# 4  0.279835       2
# 5  0.861751       1  , 0.43414359361933974)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4341
# エポック 27/30
# ----------
# 訓練_loss: 0.1694
# 検証_loss=3.407165217399597
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   60  46   12    34   48   0.200000  0.260870
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  149  12    8     4  141   0.053691  0.666667
# 3             ribosome   99  31   11    20   88   0.111111  0.354839
# 4        thyroglobulin  398  30   18    12  380   0.045226  0.600000
# 5  virus-like-particle   18  11   11     0    7   0.611111  1.000000
#
#     f-beta4  weight
# 0  0.256281       1
# 1  0.000000       0
# 2  0.398827       2
# 3  0.314286       1
# 4  0.348519       2
# 5  0.963918       1  , 0.4327396186302777)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4327
# エポック 28/30
# ----------
# 訓練_loss: 0.1743
# 検証_loss=2.949863600730896
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  119  46   15    31  104   0.126050  0.326087
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   91  12    6     6   85   0.065934  0.500000
# 3             ribosome   72  31   14    17   58   0.194444  0.451613
# 4        thyroglobulin  330  30   23     7  307   0.069697  0.766667
# 5  virus-like-particle   28  11   11     0   17   0.392857  1.000000
#
#     f-beta4  weight
# 0  0.298246       1
# 1  0.000000       0
# 2  0.360424       2
# 3  0.419014       1
# 4  0.482716       2
# 5  0.916667       1  , 0.4743152172159045)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4743
# エポック 29/30
# ----------
# 訓練_loss: 0.1570
# 検証_loss=3.4462375402450562
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   59  46   18    28   41   0.305085  0.391304
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  217  12    5     7  212   0.023041  0.416667
# 3             ribosome  248  31    7    24  241   0.028226  0.225806
# 4        thyroglobulin  264  30   21     9  243   0.079545  0.700000
# 5  virus-like-particle   14  11   11     0    3   0.785714  1.000000
#
#     f-beta4  weight
# 0  0.384906       1
# 1  0.000000       0
# 2  0.207824       2
# 3  0.159946       1
# 4  0.479839       2
# 5  0.984211       1  , 0.4149125377667882)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4149
# エポック 30/30
# ----------
# 訓練_loss: 0.1679
# 検証_loss=4.998675775527954
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   41  46    8    38   33   0.195122  0.173913
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   10  12    0    12   10   0.000000  0.000000
# 3             ribosome   77  31   16    15   61   0.207792  0.516129
# 4        thyroglobulin  147  30    1    29  146   0.006803  0.033333
# 5  virus-like-particle   13  11    8     3    5   0.615385  0.727273
#
#     f-beta4  weight
# 0  0.175032       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.474695       1
# 4  0.027113       2
# 5  0.719577       1  , 0.20336142282369105)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2034
#
# 全エポックの結果:
# エポック 1: 損失: 1.4816, lb_score: 0.0000
# エポック 2: 損失: 1.0830, lb_score: 0.0000
# エポック 3: 損失: 0.7708, lb_score: 0.1258
# エポック 4: 損失: 0.5527, lb_score: 0.1595
# エポック 5: 損失: 0.4233, lb_score: 0.3079
# エポック 6: 損失: 0.3563, lb_score: 0.3466
# エポック 7: 損失: 0.3044, lb_score: 0.2674
# エポック 8: 損失: 0.2867, lb_score: 0.4239
# エポック 9: 損失: 0.2732, lb_score: 0.3771
# エポック 10: 損失: 0.2770, lb_score: 0.4362
# エポック 11: 損失: 0.2537, lb_score: 0.3881
# エポック 12: 損失: 0.2416, lb_score: 0.4116
# エポック 13: 損失: 0.2249, lb_score: 0.3883
# エポック 14: 損失: 0.2281, lb_score: 0.3989
# エポック 15: 損失: 0.2265, lb_score: 0.1862
# エポック 16: 損失: 0.2108, lb_score: 0.0948
# エポック 17: 損失: 0.2071, lb_score: 0.4042
# エポック 18: 損失: 0.2024, lb_score: 0.3770
# エポック 19: 損失: 0.2166, lb_score: 0.0000
# エポック 20: 損失: 0.2063, lb_score: 0.2403
# エポック 21: 損失: 0.2071, lb_score: 0.4517
# エポック 22: 損失: 0.1786, lb_score: 0.4643
# エポック 23: 損失: 0.1787, lb_score: 0.3607
# エポック 24: 損失: 0.1767, lb_score: 0.3315
# エポック 25: 損失: 0.1657, lb_score: 0.4340
# エポック 26: 損失: 0.1704, lb_score: 0.4341
# エポック 27: 損失: 0.1694, lb_score: 0.4327
# エポック 28: 損失: 0.1743, lb_score: 0.4743
# エポック 29: 損失: 0.1570, lb_score: 0.4149
# エポック 30: 損失: 0.1679, lb_score: 0.2034

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
#  0         apo-ferritin  310  36   17    19  293   0.054839  0.472222
#  1         beta-amylase    0  21    0    21    0   0.000000  0.000000
#  2   beta-galactosidase  152  24    2    22  150   0.013158  0.083333
#  3             ribosome   88  65   19    46   69   0.215909  0.292308
#  4        thyroglobulin  337  49    7    42  330   0.020772  0.142857
#  5  virus-like-particle  244  13    9     4  235   0.036885  0.692308
#
#      f-beta4  weight
#  0  0.326185       1
#  1  0.000000       0
#  2  0.063433       2
#  3  0.286348       1
#  4  0.106155       2
#  5  0.338496       1  ,
#  0.18431490046905502)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
