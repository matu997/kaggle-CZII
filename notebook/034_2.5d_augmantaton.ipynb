# %%
from helpers import *
from dataset import *
from model2_for27 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        translate_range=(0, 200, 200),  # (X, Y, Z) 軸での移動範囲 (例: Y, Zのみ)
        prob=0.8,  # 適用される確率
        mode=("bilinear", "nearest"),  # 画像:補間, ラベル:最近傍
        padding_mode="border",  # 境界値を埋める
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 217
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1729361.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 676610.0

# %%
GPU_ID = 4
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:4

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 40
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/40
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.1047
# 検証_loss=0.4876652956008911
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin   24  46    0    46   24        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome    1  31    0    31    1        0.0     0.0      0.0
# 4        thyroglobulin  577  30    0    30  577        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/40
# ----------
# 訓練_loss: 0.2835
# 検証_loss=0.15312020480632782
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    6  46    0    46    6   0.000000  0.000000
# 1         beta-amylase  172  10    0    10  172   0.000000  0.000000
# 2   beta-galactosidase   54  12    0    12   54   0.000000  0.000000
# 3             ribosome  407  31   13    18  394   0.031941  0.419355
# 4        thyroglobulin   57  30    1    29   56   0.017544  0.033333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.244740       1
# 4  0.031657       2
# 5  0.000000       1  , 0.04400778110386678)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0440
# エポック 3/40
# ----------
# 訓練_loss: 0.0970
# 検証_loss=0.09946156889200211
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin    0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase    5  10    0    10   5   0.000000  0.000000  0.000000
# 2   beta-galactosidase    1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  127  31   29     2  98   0.228346  0.935484  0.791332
# 4        thyroglobulin   90  30    3    27  87   0.033333  0.100000  0.089474
# 5  virus-like-particle    0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13861137595191833)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1386
# エポック 4/40
# ----------
# 訓練_loss: 0.0601
# 検証_loss=0.07131781578063964
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase   10  10    0    10   10   0.000000  0.000000
# 2   beta-galactosidase    3  12    0    12    3   0.000000  0.000000
# 3             ribosome  429  31   10    21  419   0.023310  0.322581
# 4        thyroglobulin  398  30   28     2  370   0.070352  0.933333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.183784       1
# 4  0.542141       2
# 5  0.000000       1  , 0.1811523205600655)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1812
# エポック 5/40
# ----------
# 訓練_loss: 0.0480
# 検証_loss=0.07647389881312847
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    9  46    0    46    9   0.000000  0.000000
# 1         beta-amylase   39  10    0    10   39   0.000000  0.000000
# 2   beta-galactosidase  108  12    1    11  107   0.009259  0.083333
# 3             ribosome  195  31   29     2  166   0.148718  0.935484
# 4        thyroglobulin  168  30   24     6  144   0.142857  0.800000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.056667       2
# 3  0.713459       1
# 4  0.629630       2
# 5  0.000000       1  , 0.29800733543135854)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2980
# エポック 6/40
# ----------
# 訓練_loss: 0.0360
# 検証_loss=0.10370172783732415
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0     0.0000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0     0.0000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0     0.0000  0.000000  0.000000
# 3             ribosome  32  31   14    17  18     0.4375  0.451613  0.450758
# 4        thyroglobulin  19  30    0    30  19     0.0000  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0     0.0000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0643939393939394)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0644
# エポック 7/40
# ----------
# 訓練_loss: 0.0308
# 検証_loss=0.08081178162246942
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin    0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase    0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  118  31   29     2  89   0.245763  0.935484  0.802932
# 4        thyroglobulin   78  30    6    24  72   0.076923  0.200000  0.182796
# 5  virus-like-particle    0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1669318562772382)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1669
# エポック 8/40
# ----------
# 訓練_loss: 0.0265
# 検証_loss=0.08520418182015418
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   16  46    3    43   13   0.187500  0.065217
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome   38  31   19    12   19   0.500000  0.612903
# 4        thyroglobulin  165  30   26     4  139   0.157576  0.866667
# 5  virus-like-particle   13  11   11     0    2   0.846154  1.000000
#
#     f-beta4  weight
# 0  0.067819       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.604869       1
# 4  0.685271       2
# 5  0.989418       1  , 0.4332355268386789)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4332
# エポック 9/40
# ----------
# 訓練_loss: 0.0220
# 検証_loss=0.1030670776963234
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  12  46    0    46  12   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  14  12    0    12  14   0.000000  0.000000  0.000000
# 3             ribosome  20  31   11    20   9   0.550000  0.354839  0.362403
# 4        thyroglobulin  79  30    6    24  73   0.075949  0.200000  0.182469
# 5  virus-like-particle  14  11   10     1   4   0.714286  0.909091  0.894737
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.23172533301052273)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2317
# エポック 10/40
# ----------
# 訓練_loss: 0.0190
# 検証_loss=0.06135943215340376
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   11  46    8    38    3   0.727273  0.173913
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  124  12    5     7  119   0.040323  0.416667
# 3             ribosome   51  31   22     9   29   0.431373  0.709677
# 4        thyroglobulin  404  30   26     4  378   0.064356  0.866667
# 5  virus-like-particle   24  11   11     0   13   0.458333  1.000000
#
#     f-beta4  weight
# 0  0.182062       1
# 1  0.000000       0
# 2  0.268987       2
# 3  0.683729       1
# 4  0.500000       2
# 5  0.935000       1  , 0.47696652806694856)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4770
# エポック 11/40
# ----------
# 訓練_loss: 0.0181
# 検証_loss=0.10883278697729111
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  27  46   11    35  16   0.407407  0.239130  0.245085
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  24  31   10    21  14   0.416667  0.322581  0.326923
# 4        thyroglobulin   3  30    0    30   3   0.000000  0.000000  0.000000
# 5  virus-like-particle  14  11   10     1   4   0.714286  0.909091  0.894737
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20953501558109405)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2095
# エポック 12/40
# ----------
# 訓練_loss: 0.0164
# 検証_loss=0.07450132146477699
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   91  46   23    23  68   0.252747  0.500000  0.472793
# 1         beta-amylase    0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase    7  12    0    12   7   0.000000  0.000000  0.000000
# 3             ribosome   39  31   20    11  19   0.512821  0.645161  0.635514
# 4        thyroglobulin  115  30   25     5  90   0.217391  0.833333  0.714286
# 5  virus-like-particle   55  11   11     0  44   0.200000  1.000000  0.809524
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.4780574979033867)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4781
# エポック 13/40
# ----------
# 訓練_loss: 0.0166
# 検証_loss=0.14204069562256336
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  28  46    6    40  22   0.214286  0.130435  0.133508
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  22  31   13    18   9   0.590909  0.419355  0.426641
# 4        thyroglobulin  13  30    2    28  11   0.153846  0.066667  0.068966
# 5  virus-like-particle  14  11    8     3   6   0.571429  0.727273  0.715789
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20198132688729104)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2020
# エポック 14/40
# ----------
# 訓練_loss: 0.0155
# 検証_loss=0.0773552319034934
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    7  46    6    40    1   0.857143  0.130435
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    4  12    0    12    4   0.000000  0.000000
# 3             ribosome   22  31   14    17    8   0.636364  0.451613
# 4        thyroglobulin  159  30   24     6  135   0.150943  0.800000
# 5  virus-like-particle   11  11   10     1    1   0.909091  0.909091
#
#     f-beta4  weight
# 0  0.137281       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.459459       1
# 4  0.638498       2
# 5  0.909091       1  , 0.39754670939627246)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3975
# エポック 15/40
# ----------
# 訓練_loss: 0.0154
# 検証_loss=0.06720764953643084
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   25  46   14    32   11   0.560000  0.304348
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase  108  12    7     5  101   0.064815  0.583333
# 3             ribosome   29  31   10    21   19   0.344828  0.322581
# 4        thyroglobulin  437  30   23     7  414   0.052632  0.766667
# 5  virus-like-particle   12  11   11     0    1   0.916667  1.000000
#
#     f-beta4  weight
# 0  0.312746       1
# 1  0.000000       0
# 2  0.396667       2
# 3  0.323810       1
# 4  0.426390       2
# 5  0.994681       1  , 0.46819298593139125)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4682
# エポック 16/40
# ----------
# 訓練_loss: 0.0153
# 検証_loss=0.08000105693936348
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  57  46   32    14  25   0.561404  0.695652  0.686003
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  61  31   15    16  46   0.245902  0.483871  0.457810
# 4        thyroglobulin  65  30   15    15  50   0.230769  0.500000  0.467890
# 5  virus-like-particle  12  11   11     0   1   0.916667  1.000000  0.994681
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.4391818406341748)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4392
# エポック 17/40
# ----------
# 訓練_loss: 0.0141
# 検証_loss=0.15113725923001767
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  44  46   23    23  21   0.522727  0.500000  0.501282
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  18  31    8    23  10   0.444444  0.258065  0.264591
# 4        thyroglobulin  10  30    1    29   9   0.100000  0.033333  0.034694
# 5  virus-like-particle  11  11   10     1   1   0.909091  0.909091  0.909091
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.24919316502338815)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2492
# エポック 18/40
# ----------
# 訓練_loss: 0.0139
# 検証_loss=nan
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  52  46   24    22  28   0.461538  0.521739  0.517766
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   6  12    1    11   5   0.166667  0.083333  0.085859
# 3             ribosome  16  31    3    28  13   0.187500  0.096774  0.099609
# 4        thyroglobulin  39  30    9    21  30   0.230769  0.300000  0.294798
# 5  virus-like-particle  15  11   11     0   4   0.733333  1.000000  0.979058
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.33682085878924006)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3368
# エポック 19/40
# ----------
# 訓練_loss: 0.0134
# 検証_loss=nan
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   46  46   21    25   25   0.456522  0.456522
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   26  12    6     6   20   0.230769  0.500000
# 3             ribosome   58  31   14    17   44   0.241379  0.451613
# 4        thyroglobulin  331  30   24     6  307   0.072508  0.800000
# 5  virus-like-particle   12  11   11     0    1   0.916667  1.000000
#
#     f-beta4  weight
# 0  0.456522       1
# 1  0.000000       0
# 2  0.467890       2
# 3  0.429603       1
# 4  0.503083       2
# 5  0.994681       1  , 0.5461072175583013)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.5461
# エポック 20/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 21/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 22/40
# ----------
# 訓練_loss: 0.0618
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 23/40
# ----------
# 訓練_loss: 0.0827
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 24/40
# ----------
# 訓練_loss: 0.0857
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 25/40
# ----------
# 訓練_loss: 0.0747
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 26/40
# ----------
# 訓練_loss: 0.0682
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 27/40
# ----------
# 訓練_loss: 0.0709
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 28/40
# ----------
# 訓練_loss: 0.0685
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 29/40
# ----------
# 訓練_loss: 0.0636
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 30/40
# ----------
# 訓練_loss: 0.0668
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 31/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 32/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 33/40
# ----------
# 訓練_loss: 0.1267
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 34/40
# ----------
# 訓練_loss: 0.1286
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 35/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 36/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 37/40
# ----------
# 訓練_loss: 0.5334
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 38/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 39/40
# ----------
# 訓練_loss: 0.5563
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 40/40
# ----------
# 訓練_loss: nan
# location_df is empty,
# 検証_loss=nan
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
#
# 全エポックの結果:
# エポック 1: 損失: 1.1047, lb_score: 0.0000
# エポック 2: 損失: 0.2835, lb_score: 0.0440
# エポック 3: 損失: 0.0970, lb_score: 0.1386
# エポック 4: 損失: 0.0601, lb_score: 0.1812
# エポック 5: 損失: 0.0480, lb_score: 0.2980
# エポック 6: 損失: 0.0360, lb_score: 0.0644
# エポック 7: 損失: 0.0308, lb_score: 0.1669
# エポック 8: 損失: 0.0265, lb_score: 0.4332
# エポック 9: 損失: 0.0220, lb_score: 0.2317
# エポック 10: 損失: 0.0190, lb_score: 0.4770
# エポック 11: 損失: 0.0181, lb_score: 0.2095
# エポック 12: 損失: 0.0164, lb_score: 0.4781
# エポック 13: 損失: 0.0166, lb_score: 0.2020
# エポック 14: 損失: 0.0155, lb_score: 0.3975
# エポック 15: 損失: 0.0154, lb_score: 0.4682
# エポック 16: 損失: 0.0153, lb_score: 0.4392
# エポック 17: 損失: 0.0141, lb_score: 0.2492
# エポック 18: 損失: 0.0139, lb_score: 0.3368
# エポック 19: 損失: 0.0134, lb_score: 0.5461
# エポック 20: 損失: nan, lb_score: 0.0000
# エポック 21: 損失: nan, lb_score: 0.0000
# エポック 22: 損失: 0.0618, lb_score: 0.0000
# エポック 23: 損失: 0.0827, lb_score: 0.0000
# エポック 24: 損失: 0.0857, lb_score: 0.0000
# エポック 25: 損失: 0.0747, lb_score: 0.0000
# エポック 26: 損失: 0.0682, lb_score: 0.0000
# エポック 27: 損失: 0.0709, lb_score: 0.0000
# エポック 28: 損失: 0.0685, lb_score: 0.0000
# エポック 29: 損失: 0.0636, lb_score: 0.0000
# エポック 30: 損失: 0.0668, lb_score: 0.0000
# エポック 31: 損失: nan, lb_score: 0.0000
# エポック 32: 損失: nan, lb_score: 0.0000
# エポック 33: 損失: 0.1267, lb_score: 0.0000
# エポック 34: 損失: 0.1286, lb_score: 0.0000
# エポック 35: 損失: nan, lb_score: 0.0000
# エポック 36: 損失: nan, lb_score: 0.0000
# エポック 37: 損失: 0.5334, lb_score: 0.0000
# エポック 38: 損失: nan, lb_score: 0.0000
# エポック 39: 損失: 0.5563, lb_score: 0.0000
# エポック 40: 損失: nan, lb_score: 0.0000

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# location_df is empty,
# []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       2 submit_df=location_to_df(location)
#       3 submit_df.insert(loc=0, column='experiment', value=id)
# ----> 4 compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
#
# File ~/notebook/kaggle-CZII /notebook/helpers.py:524, in compute_lb(submit_df, overlay_dir)
#     522 print('')
#     523 eval_df = pd.DataFrame(eval_df)
# --> 524 gb = eval_df.groupby('particle_type').agg('sum').drop(columns=['id'])
#     525 gb.loc[:, 'precision'] = gb['hit'] / gb['P']
#     526 gb.loc[:, 'precision'] = gb['precision'].fillna(0)
#
# File ~/.conda/envs/ultralytics-env/lib/python3.11/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/.conda/envs/ultralytics-env/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/.conda/envs/ultralytics-env/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'particle_type'

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
