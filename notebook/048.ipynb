# %%
from helpers import *
from dataset import *
from model2_for48 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(0, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 217
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 583442.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1091224.0

# %%
GPU_ID = 0
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:0

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.2532
# 検証_loss=0.8897190093994141
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.7035
# 検証_loss=0.4108211100101471
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    1  46    0    46    1        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase   10  12    0    12   10        0.0     0.0      0.0
# 3             ribosome   77  31    0    31   77        0.0     0.0      0.0
# 4        thyroglobulin  186  30    0    30  186        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 3/30
# ----------
# 訓練_loss: 0.3139
# 検証_loss=0.20758552849292755
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  598  46    2    44  596   0.003344  0.043478
# 1         beta-amylase  569  10    0    10  569   0.000000  0.000000
# 2   beta-galactosidase  802  12    0    12  802   0.000000  0.000000
# 3             ribosome  453  31   25     6  428   0.055188  0.806452
# 4        thyroglobulin  387  30    0    30  387   0.000000  0.000000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.025487       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.447840       1
# 4  0.000000       2
# 5  0.000000       1  , 0.06761815539618418)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0676
# エポック 4/30
# ----------
# 訓練_loss: 0.1687
# 検証_loss=0.13246358335018157
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision   recall   f-beta4  \
# 0         apo-ferritin  252  46    0    46  252    0.00000  0.00000  0.000000
# 1         beta-amylase  104  10    0    10  104    0.00000  0.00000  0.000000
# 2   beta-galactosidase  189  12    0    12  189    0.00000  0.00000  0.000000
# 3             ribosome   61  31   26     5   35    0.42623  0.83871  0.793537
# 4        thyroglobulin   79  30    0    30   79    0.00000  0.00000  0.000000
# 5  virus-like-particle    0  11    0    11    0    0.00000  0.00000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11336240061554245)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1134
# エポック 5/30
# ----------
# 訓練_loss: 0.1114
# 検証_loss=0.10884366333484649
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   76  46    0    46   76   0.000000  0.000000
# 1         beta-amylase  136  10    0    10  136   0.000000  0.000000
# 2   beta-galactosidase  153  12    0    12  153   0.000000  0.000000
# 3             ribosome  150  31   23     8  127   0.153333  0.741935
# 4        thyroglobulin  115  30    2    28  113   0.017391  0.066667
# 5  virus-like-particle   57  11   11     0   46   0.192982  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.605263       1
# 4  0.057143       2
# 5  0.802575       1  , 0.21744628278236977)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2174
# エポック 6/30
# ----------
# 訓練_loss: 0.0708
# 検証_loss=0.07259241342544556
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    1  10    0    10    1   0.000000  0.000000
# 2   beta-galactosidase  108  12    0    12  108   0.000000  0.000000
# 3             ribosome  174  31   18    13  156   0.103448  0.580645
# 4        thyroglobulin    1  30    0    30    1   0.000000  0.000000
# 5  virus-like-particle   72  11   11     0   61   0.152778  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.456716       1
# 4  0.000000       2
# 5  0.754032       1  , 0.172964096567852)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1730
# エポック 7/30
# ----------
# 訓練_loss: 0.0465
# location_df is empty,
# 検証_loss=0.10493208020925522
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 8/30
# ----------
# 訓練_loss: 0.0392
# 検証_loss=0.08024200946092605
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome  118  31   27     4   91   0.228814  0.870968
# 4        thyroglobulin  156  30   14    16  142   0.089744  0.466667
# 5  virus-like-particle    3  11    3     8    0   1.000000  0.272727
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.747557       1
# 4  0.374214       2
# 5  0.284916       1  , 0.2544144110472318)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2544
# エポック 9/30
# ----------
# 訓練_loss: 0.0334
# 検証_loss=0.10336192212998867
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   8  12    0    12   8   0.000000  0.000000  0.000000
# 3             ribosome  14  31    2    29  12   0.142857  0.064516  0.066667
# 4        thyroglobulin  23  30    0    30  23   0.000000  0.000000  0.000000
# 5  virus-like-particle   7  11    7     4   0   1.000000  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10241998438719749)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1024
# エポック 10/30
# ----------
# 訓練_loss: 0.0307
# location_df is empty,
# 検証_loss=0.11532635390758514
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 11/30
# ----------
# 訓練_loss: 0.0268
# 検証_loss=0.1287335202097893
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  3  31    0    31   3        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 12/30
# ----------
# 訓練_loss: 0.0241
# 検証_loss=0.09270934127271176
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  53  31   25     6  28   0.471698  0.806452  0.774135
# 4        thyroglobulin  23  30    2    28  21   0.086957  0.066667  0.067594
# 5  virus-like-particle  11  11   11     0   0   1.000000  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.27276052247534827)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2728
# エポック 13/30
# ----------
# 訓練_loss: 0.0234
# 検証_loss=0.07490819282829761
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome   48  31   24     7   24   0.500000  0.774194
# 4        thyroglobulin  132  30   19    11  113   0.143939  0.633333
# 5  virus-like-particle   11  11   11     0    0   1.000000  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.750000       1
# 4  0.527778       2
# 5  1.000000       1  , 0.40079365079365076)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4008
# エポック 14/30
# ----------
# 訓練_loss: 0.0224
# 検証_loss=0.14155526980757713
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  4  31    0    31   4        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  1  11    1    10   0        1.0  0.090909  0.096045
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.013720742534301857)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0137
# エポック 15/30
# ----------
# 訓練_loss: 0.0201
# 検証_loss=0.16958154365420341
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  2  11    2     9   0        1.0  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.027287319422150878)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0273
# エポック 16/30
# ----------
# 訓練_loss: 0.0223
# 検証_loss=0.12378755249083043
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  6  31    3    28   3        0.5  0.096774  0.101594
# 4        thyroglobulin  5  30    0    30   5        0.0  0.000000  0.000000
# 5  virus-like-particle  8  11    8     3   0        1.0  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12010343718294525)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1201
# エポック 17/30
# ----------
# 訓練_loss: 0.0209
# location_df is empty,
# 検証_loss=0.1525571584701538
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 18/30
# ----------
# 訓練_loss: 0.0196
# 検証_loss=0.12433845400810242
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   4  46    2    44   2   0.500000  0.043478  0.045946
# 1         beta-amylase   3  10    0    10   3   0.000000  0.000000  0.000000
# 2   beta-galactosidase   2  12    0    12   2   0.000000  0.000000  0.000000
# 3             ribosome   7  31    4    27   3   0.571429  0.129032  0.135189
# 4        thyroglobulin  15  30    1    29  14   0.066667  0.033333  0.034343
# 5  virus-like-particle   8  11    8     3   0   1.000000  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.14127887374494688)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1413
# エポック 19/30
# ----------
# 訓練_loss: 0.0195
# 検証_loss=0.13055384643375872
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  7  31    2    29   5   0.285714  0.064516  0.067594
# 4        thyroglobulin  3  30    0    30   3   0.000000  0.000000  0.000000
# 5  virus-like-particle  9  11    8     3   1   0.888889  0.727273  0.735135
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11467565264781965)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1147
# エポック 20/30
# ----------
# 訓練_loss: 0.0188
# location_df is empty,
# 検証_loss=0.18667395487427713
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 21/30
# ----------
# 訓練_loss: 0.0201
# 検証_loss=0.1444774389266968
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  2  30    0    30   2        0.0  0.000000  0.000000
# 5  virus-like-particle  9  11    9     2   0        1.0  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11814671814671816)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1181
# エポック 22/30
# ----------
# 訓練_loss: 0.0176
# 検証_loss=0.13209766745567322
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  29  46    4    42  25   0.137931  0.086957  0.088889
# 1         beta-amylase   4  10    0    10   4   0.000000  0.000000  0.000000
# 2   beta-galactosidase   4  12    0    12   4   0.000000  0.000000  0.000000
# 3             ribosome  12  31    6    25   6   0.500000  0.193548  0.200787
# 4        thyroglobulin  11  30    2    28   9   0.181818  0.066667  0.069246
# 5  virus-like-particle  13  11   11     0   2   0.846154  1.000000  0.989418
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20251245022458703)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2025
# エポック 23/30
# ----------
# 訓練_loss: 0.0182
# 検証_loss=0.1355748139321804
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  5  31    0    31   5        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  9  11    9     2   0        1.0  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11814671814671816)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1181
# エポック 24/30
# ----------
# 訓練_loss: 0.0182
# 検証_loss=0.16137351244688034
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  2  46    0    46   2        0.0  0.000000  0.000000
# 1         beta-amylase  1  10    0    10   1        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  3  11    3     8   0        1.0  0.272727  0.284916
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0407023144453312)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0407
# エポック 25/30
# ----------
# 訓練_loss: 0.0167
# 検証_loss=0.12459129877388478
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  20  46    6    40  14        0.3  0.130435  0.134921
# 1         beta-amylase   2  10    0    10   2        0.0  0.000000  0.000000
# 2   beta-galactosidase   2  12    1    11   1        0.5  0.083333  0.087629
# 3             ribosome   6  31    3    28   3        0.5  0.096774  0.101594
# 4        thyroglobulin   4  30    0    30   4        0.0  0.000000  0.000000
# 5  virus-like-particle  11  11   11     0   0        1.0  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20168171319677225)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2017
# エポック 26/30
# ----------
# 訓練_loss: 0.0173
# 検証_loss=0.17040045708417892
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  7  11    7     4   0        1.0  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.09289617486338797)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0929
# エポック 27/30
# ----------
# 訓練_loss: 0.0164
# 検証_loss=0.2992426872253418
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  3  11    3     8   0        1.0  0.272727  0.284916
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0407023144453312)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0407
# エポック 28/30
# ----------
# 訓練_loss: 0.0161
# 検証_loss=0.24980098605155945
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  2  11    2     9   0        1.0  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.027287319422150878)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0273
# エポック 29/30
# ----------
# 訓練_loss: 0.0158
# 検証_loss=0.1377127267420292
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  10  31    8    23   2        0.8  0.258065  0.268775
# 4        thyroglobulin   5  30    0    30   5        0.0  0.000000  0.000000
# 5  virus-like-particle  11  11   11     0   0        1.0  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.18125352907961603)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1813
# エポック 30/30
# ----------
# 訓練_loss: 0.0154
# 検証_loss=0.12699706703424454
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  68  46   19    27  49   0.279412  0.413043  0.401741
# 1         beta-amylase   1  10    0    10   1   0.000000  0.000000  0.000000
# 2   beta-galactosidase  14  12    0    12  14   0.000000  0.000000  0.000000
# 3             ribosome  10  31    9    22   1   0.900000  0.290323  0.302372
# 4        thyroglobulin   7  30    0    30   7   0.000000  0.000000  0.000000
# 5  virus-like-particle  16  11   11     0   5   0.687500  1.000000  0.973958
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.2397244526239497)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2397
#
# 全エポックの結果:
# エポック 1: 損失: 1.2532, lb_score: 0.0000
# エポック 2: 損失: 0.7035, lb_score: 0.0000
# エポック 3: 損失: 0.3139, lb_score: 0.0676
# エポック 4: 損失: 0.1687, lb_score: 0.1134
# エポック 5: 損失: 0.1114, lb_score: 0.2174
# エポック 6: 損失: 0.0708, lb_score: 0.1730
# エポック 7: 損失: 0.0465, lb_score: 0.0000
# エポック 8: 損失: 0.0392, lb_score: 0.2544
# エポック 9: 損失: 0.0334, lb_score: 0.1024
# エポック 10: 損失: 0.0307, lb_score: 0.0000
# エポック 11: 損失: 0.0268, lb_score: 0.0000
# エポック 12: 損失: 0.0241, lb_score: 0.2728
# エポック 13: 損失: 0.0234, lb_score: 0.4008
# エポック 14: 損失: 0.0224, lb_score: 0.0137
# エポック 15: 損失: 0.0201, lb_score: 0.0273
# エポック 16: 損失: 0.0223, lb_score: 0.1201
# エポック 17: 損失: 0.0209, lb_score: 0.0000
# エポック 18: 損失: 0.0196, lb_score: 0.1413
# エポック 19: 損失: 0.0195, lb_score: 0.1147
# エポック 20: 損失: 0.0188, lb_score: 0.0000
# エポック 21: 損失: 0.0201, lb_score: 0.1181
# エポック 22: 損失: 0.0176, lb_score: 0.2025
# エポック 23: 損失: 0.0182, lb_score: 0.1181
# エポック 24: 損失: 0.0182, lb_score: 0.0407
# エポック 25: 損失: 0.0167, lb_score: 0.2017
# エポック 26: 損失: 0.0173, lb_score: 0.0929
# エポック 27: 損失: 0.0164, lb_score: 0.0407
# エポック 28: 損失: 0.0161, lb_score: 0.0273
# エポック 29: 損失: 0.0158, lb_score: 0.1813
# エポック 30: 損失: 0.0154, lb_score: 0.2397

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss  fp  precision    recall   f-beta4  \
#  0         apo-ferritin  115  36   28     8  87   0.243478  0.777778  0.688857
#  1         beta-amylase   18  21    0    21  18   0.000000  0.000000  0.000000
#  2   beta-galactosidase   63  24    3    21  60   0.047619  0.125000  0.114094
#  3             ribosome   45  65   26    39  19   0.577778  0.400000  0.407373
#  4        thyroglobulin    4  49    0    49   4   0.000000  0.000000  0.000000
#  5  virus-like-particle   22  13   13     0   9   0.590909  1.000000  0.960870
#
#     weight
#  0       1
#  1       0
#  2       2
#  3       1
#  4       2
#  5       1  ,
#  0.3264696408496562)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
