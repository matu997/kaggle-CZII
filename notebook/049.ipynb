# %%
from helpers import *
from dataset import *
from model2_for48 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        translate_range=(0, 100, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 218
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 476716.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 110159.0

# %%
GPU_ID = 2
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:2

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 0.9539
# 検証_loss=0.5602911233901977
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin  863  46    0    46  863        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase  195  12    0    12  195        0.0     0.0      0.0
# 3             ribosome    1  31    0    31    1        0.0     0.0      0.0
# 4        thyroglobulin    1  30    0    30    1        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.4144
# 検証_loss=0.2698671817779541
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   206  46    0    46   206   0.000000  0.000000
# 1         beta-amylase  1311  10    0    10  1311   0.000000  0.000000
# 2   beta-galactosidase   246  12    1    11   245   0.004065  0.083333
# 3             ribosome   774  31    7    24   767   0.009044  0.225806
# 4        thyroglobulin     1  30    0    30     1   0.000000  0.000000
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.038813       2
# 3  0.093701       1
# 4  0.000000       2
# 5  0.000000       1  , 0.024475194025404354)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0245
# エポック 3/30
# ----------
# 訓練_loss: 0.1927
# 検証_loss=0.147922582924366
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   30  46    0    46   30   0.000000  0.000000
# 1         beta-amylase  197  10    0    10  197   0.000000  0.000000
# 2   beta-galactosidase  281  12    0    12  281   0.000000  0.000000
# 3             ribosome  110  31   23     8   87   0.209091  0.741935
# 4        thyroglobulin  191  30    0    30  191   0.000000  0.000000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.645215       1
# 4  0.000000       2
# 5  0.000000       1  , 0.09217350306459218)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0922
# エポック 4/30
# ----------
# 訓練_loss: 0.1129
# 検証_loss=0.11294226944446564
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    1  46    0    46    1   0.000000  0.000000
# 1         beta-amylase   39  10    0    10   39   0.000000  0.000000
# 2   beta-galactosidase   38  12    0    12   38   0.000000  0.000000
# 3             ribosome  126  31   22     9  104   0.174603  0.709677
# 4        thyroglobulin  145  30    4    26  141   0.027586  0.133333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.601286       1
# 4  0.108800       2
# 5  0.000000       1  , 0.11698373909049149)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1170
# エポック 5/30
# ----------
# 訓練_loss: 0.0811
# 検証_loss=0.09231065958738327
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  f-beta4  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000    0.000
# 1         beta-amylase    9  10    0    10    9   0.000000  0.000000    0.000
# 2   beta-galactosidase   42  12    0    12   42   0.000000  0.000000    0.000
# 3             ribosome  104  31   21    10   83   0.201923  0.677419    0.595
# 4        thyroglobulin  145  30    0    30  145   0.000000  0.000000    0.000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000    0.000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.08499999999999999)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0850
# エポック 6/30
# ----------
# 訓練_loss: 0.0539
# 検証_loss=0.08657305613160134
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   3  12    0    12   3   0.000000  0.000000  0.000000
# 3             ribosome  27  31    9    22  18   0.333333  0.290323  0.292543
# 4        thyroglobulin   2  30    0    30   2   0.000000  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.041791860147500685)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0418
# エポック 7/30
# ----------
# 訓練_loss: 0.0367
# 検証_loss=0.10203170701861382
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 8/30
# ----------
# 訓練_loss: 0.0312
# 検証_loss=0.10466970019042492
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  3  31    0    31   3        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 9/30
# ----------
# 訓練_loss: 0.0296
# 検証_loss=0.1087785478681326
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  10  31    1    30   9        0.1  0.032258  0.033597
# 4        thyroglobulin   0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle   2  11    2     9   0        1.0  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.032086867699960026)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0321
# エポック 10/30
# ----------
# 訓練_loss: 0.0262
# 検証_loss=0.10573292821645737
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  21  12    0    12  21        0.0  0.000000  0.000000
# 3             ribosome  15  31    3    28  12        0.2  0.096774  0.099804
# 4        thyroglobulin  15  30    0    30  15        0.0  0.000000  0.000000
# 5  virus-like-particle  10  11    9     2   1        0.9  0.818182  0.822581
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13176927863500681)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1318
# エポック 11/30
# ----------
# 訓練_loss: 0.0249
# 検証_loss=0.11834104880690574
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  15  31    3    28  12        0.2  0.096774  0.099804
# 4        thyroglobulin   1  30    0    30   1        0.0  0.000000  0.000000
# 5  virus-like-particle  11  11   11     0   0        1.0  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.15711490075482248)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1571
# エポック 12/30
# ----------
# 訓練_loss: 0.0215
# 検証_loss=0.13169168084859847
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.00000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.00000
# 3             ribosome  6  31    0    31   6        0.0  0.000000  0.00000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.00000
# 5  virus-like-particle  6  11    6     5   0        1.0  0.545455  0.56044
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.08006279434850862)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0801
# エポック 13/30
# ----------
# 訓練_loss: 0.0200
# 検証_loss=0.1363852307200432
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.00000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.00000
# 3             ribosome  19  31    0    31  19        0.0  0.000000  0.00000
# 4        thyroglobulin   0  30    0    30   0        0.0  0.000000  0.00000
# 5  virus-like-particle   8  11    8     3   0        1.0  0.727273  0.73913
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10559006211180125)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1056
# エポック 14/30
# ----------
# 訓練_loss: 0.0196
# 検証_loss=0.12552302591502668
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   6  46    3    43   3      0.500  0.065217  0.068733
# 1         beta-amylase   0  10    0    10   0      0.000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0      0.000  0.000000  0.000000
# 3             ribosome  24  31    3    28  21      0.125  0.096774  0.098077
# 4        thyroglobulin  16  30    2    28  14      0.125  0.066667  0.068548
# 5  virus-like-particle  10  11   10     1   0      1.000  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.17398362079042018)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1740
# エポック 15/30
# ----------
# 訓練_loss: 0.0186
# 検証_loss=0.13367342948913574
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase   0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase   0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  12  31    0    31  12        0.0     0.0      0.0
# 4        thyroglobulin   0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  11  11   11     0   0        1.0     1.0      1.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.14285714285714285)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1429
# エポック 16/30
# ----------
# 訓練_loss: 0.0176
# 検証_loss=0.14455752857029439
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  14  31    1    30  13   0.071429  0.032258  0.033333
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   8  11    8     3   0   1.000000  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.110351966873706)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1104
# エポック 17/30
# ----------
# 訓練_loss: 0.0172
# 検証_loss=0.1223377488553524
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   2  46    0    46   2   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  15  31    4    27  11   0.266667  0.129032  0.133072
# 4        thyroglobulin   1  30    0    30   1   0.000000  0.000000  0.000000
# 5  virus-like-particle  11  11   11     0   0   1.000000  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1618674867207157)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1619
# エポック 18/30
# ----------
# 訓練_loss: 0.0170
# 検証_loss=0.14664556011557578
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   1  46    0    46   1      0.000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0      0.000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0      0.000  0.000000  0.000000
# 3             ribosome   5  31    3    28   2      0.600  0.096774  0.101796
# 4        thyroglobulin   8  30    1    29   7      0.125  0.033333  0.034836
# 5  virus-like-particle  10  11   10     1   0      1.000  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.15506386185097507)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1551
# エポック 19/30
# ----------
# 訓練_loss: 0.0163
# 検証_loss=0.21736141815781593
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  2  46    0    46   2   0.000000  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  1  31    0    31   1   0.000000  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  9  11    8     3   1   0.888889  0.727273  0.735135
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10501930501930502)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1050
# エポック 20/30
# ----------
# 訓練_loss: 0.0150
# 検証_loss=0.13807062171399592
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.00000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.00000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.00000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.00000
# 5  virus-like-particle  6  11    6     5   0        1.0  0.545455  0.56044
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.08006279434850862)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0801
# エポック 21/30
# ----------
# 訓練_loss: 0.0160
# 検証_loss=0.13107663579285145
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  18  31    5    26  13   0.277778  0.161290  0.165370
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   7  11    7     4   0   1.000000  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11652041054988047)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1165
# エポック 22/30
# ----------
# 訓練_loss: 0.0146
# 検証_loss=0.1218210618942976
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  27  31   14    17  13   0.518519  0.451613  0.455067
# 4        thyroglobulin  28  30    0    30  28   0.000000  0.000000  0.000000
# 5  virus-like-particle  12  11   11     0   1   0.916667  1.000000  0.994681
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20710682466713548)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2071
# エポック 23/30
# ----------
# 訓練_loss: 0.0142
# 検証_loss=0.14568537585437297
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  8  46    2    44   6       0.25  0.043478  0.045699
# 1         beta-amylase  0  10    0    10   0       0.00  0.000000  0.000000
# 2   beta-galactosidase  1  12    0    12   1       0.00  0.000000  0.000000
# 3             ribosome  1  31    1    30   0       1.00  0.032258  0.034205
# 4        thyroglobulin  0  30    0    30   0       0.00  0.000000  0.000000
# 5  virus-like-particle  7  11    7     4   0       1.00  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10431105430903265)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1043
# エポック 24/30
# ----------
# 訓練_loss: 0.0143
# 検証_loss=0.1427858415991068
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  3  46    2    44   1   0.666667  0.043478  0.046008
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  3  31    0    31   3   0.000000  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  9  11    9     2   0   1.000000  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12471930658669496)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1247
# エポック 25/30
# ----------
# 訓練_loss: 0.0143
# 検証_loss=0.12839948311448096
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   7  46    3    43   4   0.428571  0.065217  0.068641
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  26  12    2    10  24   0.076923  0.166667  0.155963
# 3             ribosome   7  31    6    25   1   0.857143  0.193548  0.202783
# 4        thyroglobulin   4  30    0    30   4   0.000000  0.000000  0.000000
# 5  virus-like-particle   9  11    9     2   0   1.000000  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.201482511251433)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2015
# エポック 26/30
# ----------
# 訓練_loss: 0.0149
# 検証_loss=0.14525377489626407
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  7  46    5    41   2   0.714286  0.108696  0.114401
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  1  31    0    31   1   0.000000  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  4  11    4     7   0   1.000000  0.363636  0.377778
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.07031126492768484)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0703
# エポック 27/30
# ----------
# 訓練_loss: 0.0142
# 検証_loss=0.1461297232657671
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  15  46   10    36   5   0.666667  0.217391  0.226365
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome   0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   2  11    2     9   0   1.000000  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.059625154689413574)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0596
# エポック 28/30
# ----------
# 訓練_loss: 0.0123
# location_df is empty,
# 検証_loss=0.6631368897855282
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 29/30
# ----------
# 訓練_loss: 0.0134
# 検証_loss=0.18281898386776446
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.00000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.00000
# 3             ribosome  3  31    0    31   3        0.0  0.000000  0.00000
# 4        thyroglobulin  1  30    0    30   1        0.0  0.000000  0.00000
# 5  virus-like-particle  8  11    8     3   0        1.0  0.727273  0.73913
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10559006211180125)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1056
# エポック 30/30
# ----------
# 訓練_loss: 0.0129
# 検証_loss=0.17986287362873554
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1        0.0  0.000000  0.000000
# 3             ribosome   3  31    0    31   3        0.0  0.000000  0.000000
# 4        thyroglobulin  20  30    2    28  18        0.1  0.066667  0.068000
# 5  virus-like-particle   9  11    9     2   0        1.0  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13757528957528958)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1376
#
# 全エポックの結果:
# エポック 1: 損失: 0.9539, lb_score: 0.0000
# エポック 2: 損失: 0.4144, lb_score: 0.0245
# エポック 3: 損失: 0.1927, lb_score: 0.0922
# エポック 4: 損失: 0.1129, lb_score: 0.1170
# エポック 5: 損失: 0.0811, lb_score: 0.0850
# エポック 6: 損失: 0.0539, lb_score: 0.0418
# エポック 7: 損失: 0.0367, lb_score: 0.0000
# エポック 8: 損失: 0.0312, lb_score: 0.0000
# エポック 9: 損失: 0.0296, lb_score: 0.0321
# エポック 10: 損失: 0.0262, lb_score: 0.1318
# エポック 11: 損失: 0.0249, lb_score: 0.1571
# エポック 12: 損失: 0.0215, lb_score: 0.0801
# エポック 13: 損失: 0.0200, lb_score: 0.1056
# エポック 14: 損失: 0.0196, lb_score: 0.1740
# エポック 15: 損失: 0.0186, lb_score: 0.1429
# エポック 16: 損失: 0.0176, lb_score: 0.1104
# エポック 17: 損失: 0.0172, lb_score: 0.1619
# エポック 18: 損失: 0.0170, lb_score: 0.1551
# エポック 19: 損失: 0.0163, lb_score: 0.1050
# エポック 20: 損失: 0.0150, lb_score: 0.0801
# エポック 21: 損失: 0.0160, lb_score: 0.1165
# エポック 22: 損失: 0.0146, lb_score: 0.2071
# エポック 23: 損失: 0.0142, lb_score: 0.1043
# エポック 24: 損失: 0.0143, lb_score: 0.1247
# エポック 25: 損失: 0.0143, lb_score: 0.2015
# エポック 26: 損失: 0.0149, lb_score: 0.0703
# エポック 27: 損失: 0.0142, lb_score: 0.0596
# エポック 28: 損失: 0.0123, lb_score: 0.0000
# エポック 29: 損失: 0.0134, lb_score: 0.1056
# エポック 30: 損失: 0.0129, lb_score: 0.1376

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
#  0         apo-ferritin   78  36   27     9   51   0.346154  0.750000
#  1         beta-amylase  111  21    8    13  103   0.072072  0.380952
#  2   beta-galactosidase  243  24   20     4  223   0.082305  0.833333
#  3             ribosome  149  65   41    24  108   0.275168  0.630769
#  4        thyroglobulin   93  49   39    10   54   0.419355  0.795918
#  5  virus-like-particle   13  13   13     0    0   1.000000  1.000000
#
#      f-beta4  weight
#  0  0.701835       1
#  1  0.304251       0
#  2  0.542265       2
#  3  0.586207       1
#  4  0.755986       2
#  5  1.000000       1  ,
#  0.6977919854998083)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
