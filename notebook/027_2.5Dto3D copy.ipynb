# %%
from helpers import *
from dataset import *
from model2_for27 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd
import os

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    ToTensorD(keys=["image", "label"]),  # まずテンソルに変換
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    #NormalizeIntensityd(keys="image"),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    RandAffined(
        keys=["image", "label"],
        translate_range=(0, 50, 50),  # (X, Y, Z) 軸での平行移動範囲
        prob=0.8,  # 適用される確率
        mode=("bilinear", "nearest"),  # 画像には補間を適用し、ラベルには最近傍補間
        padding_mode="constant",
    ),
    #32*640x640に拡大
    ResizeD(keys=["image", "label"], spatial_size=(32, 640, 640), mode="nearest"),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 215
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1024678.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 534053.0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
net = Net(pretrained=True,cfg=None).cuda()
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 40
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/40
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.4183
# mask_loss=1.022843337059021
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  11  30    0    30  11        0.0     0.0      0.0
# 5  virus-like-particle   4  11    0    11   4        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/40
# ----------
# 訓練_loss: 0.7667
# mask_loss=0.4617181122303009
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin      1  46    0    46      1   0.000000  0.000000
# 1         beta-amylase  14122  10    1     9  14121   0.000071  0.100000
# 2   beta-galactosidase      1  12    0    12      1   0.000000  0.000000
# 3             ribosome      1  31    0    31      1   0.000000  0.000000
# 4        thyroglobulin   3910  30    8    22   3902   0.002046  0.266667
# 5  virus-like-particle      0  11    0    11      0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.001190       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.030979       2
# 5  0.000000       1  , 0.00885128538887081)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0089
# エポック 3/40
# ----------
# 訓練_loss: 0.3259
# mask_loss=0.2127609670162201
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  895  46    0    46  895   0.000000  0.000000
# 1         beta-amylase  219  10    0    10  219   0.000000  0.000000
# 2   beta-galactosidase  146  12    0    12  146   0.000000  0.000000
# 3             ribosome  462  31   18    13  444   0.038961  0.580645
# 4        thyroglobulin  103  30    1    29  102   0.009709  0.033333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.319415       1
# 4  0.029160       2
# 5  0.000000       1  , 0.05396206975755564)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0540
# エポック 4/40
# ----------
# 訓練_loss: 0.1527
# mask_loss=0.1340712860226631
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  308  46    0    46  308   0.000000  0.000000
# 1         beta-amylase  163  10    0    10  163   0.000000  0.000000
# 2   beta-galactosidase   10  12    0    12   10   0.000000  0.000000
# 3             ribosome  277  31   13    18  264   0.046931  0.419355
# 4        thyroglobulin  209  30   10    20  199   0.047847  0.333333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.285899       1
# 4  0.246734       2
# 5  0.000000       1  , 0.11133826997040648)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1113
# エポック 5/40
# ----------
# 訓練_loss: 0.0970
# mask_loss=0.09635351076722146
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   18  46    0    46   18   0.000000  0.000000
# 1         beta-amylase  174  10    0    10  174   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome  315  31   14    17  301   0.044444  0.451613
# 4        thyroglobulin  231  30   10    20  221   0.043290  0.333333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.293465       1
# 4  0.239100       2
# 5  0.000000       1  , 0.11023779670082874)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1102
# エポック 6/40
# ----------
# 訓練_loss: 0.0627
# mask_loss=0.06851752921938896
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   40  46    0    46   40   0.000000  0.000000
# 1         beta-amylase  268  10    0    10  268   0.000000  0.000000
# 2   beta-galactosidase   17  12    0    12   17   0.000000  0.000000
# 3             ribosome  252  31   18    13  234   0.071429  0.580645
# 4        thyroglobulin  186  30   16    14  170   0.086022  0.533333
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.409091       1
# 4  0.408408       2
# 5  0.000000       1  , 0.17512967512967514)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1751
# エポック 7/40
# ----------
# 訓練_loss: 0.0399
# mask_loss=0.07646117936819792
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin   16  46    0    46   16   0.000000  0.000000
# 1         beta-amylase   14  10    0    10   14   0.000000  0.000000
# 2   beta-galactosidase   12  12    0    12   12   0.000000  0.000000
# 3             ribosome  177  31   20    11  157   0.112994  0.645161
# 4        thyroglobulin  135  30   11    19  124   0.081481  0.366667
# 5  virus-like-particle    5  11    5     6    0   1.000000  0.454545
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.505201       1
# 4  0.304065       2
# 5  0.469613       1  , 0.22613484790328026)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2261
# エポック 8/40
# ----------
# 訓練_loss: 0.0317
# mask_loss=0.09341264143586159
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  15  31    3    28  12   0.200000  0.096774  0.099804
# 4        thyroglobulin  52  30    1    29  51   0.019231  0.033333  0.031955
# 5  virus-like-particle   9  11    9     2   0   1.000000  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1415344438209821)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1415
# エポック 9/40
# ----------
# 訓練_loss: 0.0278
# mask_loss=0.06751810591667891
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin    0  46    0    46    0   0.000000  0.000000
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome   37  31   14    17   23   0.378378  0.451613
# 4        thyroglobulin  196  30   27     3  169   0.137755  0.900000
# 5  virus-like-particle   11  11   11     0    0   1.000000  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.446529       1
# 4  0.678994       2
# 5  1.000000       1  , 0.40064532090798505)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.4006
# エポック 10/40
# ----------
# 訓練_loss: 0.0242
# location_df is empty,
# mask_loss=0.11264998987317085
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 11/40
# ----------
# 訓練_loss: 0.0226
# mask_loss=0.11978839300572872
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  9  31    3    28   6   0.333333  0.096774  0.100990
# 4        thyroglobulin  0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  7  11    7     4   0   1.000000  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10732333186480239)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1073
# エポック 12/40
# ----------
# 訓練_loss: 0.0198
# mask_loss=0.11015255935490131
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase   1  10    0    10   1   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  27  31   14    17  13   0.518519  0.451613  0.455067
# 4        thyroglobulin   1  30    0    30   1   0.000000  0.000000  0.000000
# 5  virus-like-particle  10  11    9     2   1   0.900000  0.818182  0.822581
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.18252108096677272)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1825
# エポック 13/40
# ----------
# 訓練_loss: 0.0197
# mask_loss=0.11096088550984859
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1   0.000000  0.000000  0.00000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.00000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.00000
# 3             ribosome  28  31   11    20  17   0.392857  0.354839  0.35687
# 4        thyroglobulin   2  30    1    29   1   0.500000  0.033333  0.03527
# 5  virus-like-particle  11  11   11     0   0   1.000000  1.000000  1.00000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.20391566401353867)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2039
# エポック 14/40
# ----------
# 訓練_loss: 0.0179
# mask_loss=0.13656649738550186
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  1  12    0    12   1        0.0  0.000000  0.000000
# 3             ribosome  1  31    0    31   1        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  3  11    3     8   0        1.0  0.272727  0.284916
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0407023144453312)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0407
# エポック 15/40
# ----------
# 訓練_loss: 0.0170
# mask_loss=0.14426298514008523
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  4  46    0    46   4        0.0  0.000000  0.00000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase  1  12    0    12   1        0.0  0.000000  0.00000
# 3             ribosome  2  31    0    31   2        0.0  0.000000  0.00000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.00000
# 5  virus-like-particle  6  11    6     5   0        1.0  0.545455  0.56044
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.08006279434850862)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0801
# エポック 16/40
# ----------
# 訓練_loss: 0.0184
# location_df is empty,
# mask_loss=0.18676720485091208
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 17/40
# ----------
# 訓練_loss: 0.0156
# mask_loss=0.10296957343816757
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  30  31   12    19  18        0.4  0.387097  0.387833
# 4        thyroglobulin   0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle   9  11    9     2   0        1.0  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.17355138952097127)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1736
# エポック 18/40
# ----------
# 訓練_loss: 0.0154
# location_df is empty,
# mask_loss=0.15733625441789628
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 19/40
# ----------
# 訓練_loss: 0.0147
# mask_loss=0.11387648247182369
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  12  31    4    27   8   0.333333  0.129032  0.133858
# 4        thyroglobulin   1  30    0    30   1   0.000000  0.000000  0.000000
# 5  virus-like-particle  12  11   11     0   1   0.916667  1.000000  0.994681
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.16121987411148073)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1612
# エポック 20/40
# ----------
# 訓練_loss: 0.0147
# mask_loss=0.18611333556473256
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   9  46    2    44   7   0.222222  0.043478  0.045638
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   2  12    0    12   2   0.000000  0.000000  0.000000
# 3             ribosome  13  31    6    25   7   0.461538  0.193548  0.200393
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   8  11    8     3   0   1.000000  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.14073727799766772)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1407
# エポック 21/40
# ----------
# 訓練_loss: 0.0143
# mask_loss=0.17201032862067223
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  23  46    8    38  15   0.347826  0.173913  0.179183
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   3  12    0    12   3   0.000000  0.000000  0.000000
# 3             ribosome   2  31    1    30   1   0.500000  0.032258  0.034137
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.030474240269944823)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0305
# エポック 22/40
# ----------
# 訓練_loss: 0.0134
# mask_loss=0.14516435116529464
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  29  46   18    28  11    0.62069  0.391304  0.400000
# 1         beta-amylase   0  10    0    10   0    0.00000  0.000000  0.000000
# 2   beta-galactosidase  20  12    0    12  20    0.00000  0.000000  0.000000
# 3             ribosome  12  31    6    25   6    0.50000  0.193548  0.200787
# 4        thyroglobulin   0  30    0    30   0    0.00000  0.000000  0.000000
# 5  virus-like-particle  10  11   10     1   0    1.00000  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.21639512802835129)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2164
# エポック 23/40
# ----------
# 訓練_loss: 0.0130
# mask_loss=0.16124684773385525
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   6  46    0    46   6   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome   7  31    4    27   3   0.571429  0.129032  0.135189
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  10  11   10     1   0   1.000000  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1498810516318372)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1499
# エポック 24/40
# ----------
# 訓練_loss: 0.0130
# mask_loss=0.1521655272692442
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  12  46    3    43   9       0.25  0.065217  0.068182
# 1         beta-amylase   0  10    0    10   0       0.00  0.000000  0.000000
# 2   beta-galactosidase   7  12    0    12   7       0.00  0.000000  0.000000
# 3             ribosome   0  31    0    31   0       0.00  0.000000  0.000000
# 4        thyroglobulin   0  30    0    30   0       0.00  0.000000  0.000000
# 5  virus-like-particle   0  11    0    11   0       0.00  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.009740259740259742)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0097
# エポック 25/40
# ----------
# 訓練_loss: 0.0122
# mask_loss=0.11959821656346321
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   0  46    0    46   0   0.000000  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  12  31    5    26   7   0.416667  0.161290  0.167323
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   7  11    7     4   0   1.000000  0.636364  0.650273
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.11679943695562645)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1168
# エポック 26/40
# ----------
# 訓練_loss: 0.0123
# mask_loss=0.15710500366985797
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   6  46    0    46   6        0.0  0.000000  0.000000
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1        0.0  0.000000  0.000000
# 3             ribosome   2  31    1    30   1        0.5  0.032258  0.034137
# 4        thyroglobulin   0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  10  11   10     1   0        1.0  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13544500582977068)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1354
# エポック 27/40
# ----------
# 訓練_loss: 0.0117
# mask_loss=0.23571871370077133
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  7  46    0    46   7   0.000000  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  7  31    4    27   3   0.571429  0.129032  0.135189
# 4        thyroglobulin  5  30    0    30   5   0.000000  0.000000  0.000000
# 5  virus-like-particle  8  11    8     3   0   1.000000  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12490275736883051)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1249
# エポック 28/40
# ----------
# 訓練_loss: 0.0111
# mask_loss=0.16330651193857193
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  3  46    0    46   3        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  2  12    0    12   2        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  1  30    0    30   1        0.0  0.000000  0.000000
# 5  virus-like-particle  2  11    2     9   0        1.0  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.027287319422150878)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0273
# エポック 29/40
# ----------
# 訓練_loss: 0.0106
# mask_loss=0.1578155618160963
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  5  46    0    46   5        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  5  11    5     6   0        1.0  0.454545  0.469613
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.06708760852407261)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0671
# エポック 30/40
# ----------
# 訓練_loss: 0.0111
# mask_loss=0.34921807050704956
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  18  46    8    38  10   0.444444  0.173913  0.180371
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome   0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   2  11    2     9   0   1.000000  0.181818  0.191011
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.05305465553431458)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0531
# エポック 31/40
# ----------
# 訓練_loss: 0.0118
# mask_loss=0.21679073721170425
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  26  46   13    33  13        0.5  0.282609  0.290026
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1        0.0  0.000000  0.000000
# 3             ribosome   0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin   1  30    0    30   1        0.0  0.000000  0.000000
# 5  virus-like-particle   6  11    6     5   0        1.0  0.545455  0.560440
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12149511530838863)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1215
# エポック 32/40
# ----------
# 訓練_loss: 0.0099
# mask_loss=0.15693457685410978
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   1  46    1    45   0        1.0  0.021739  0.023066
# 1         beta-amylase   0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome   0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin   0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  10  11   10     1   0        1.0  0.909091  0.913978
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.1338635686252441)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1339
# エポック 33/40
# ----------
# 訓練_loss: 0.0104
# mask_loss=0.22078730687499046
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  12  46    7    39   5   0.583333  0.152174  0.159091
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome   0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin   0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle   3  11    3     8   0   1.000000  0.272727  0.284916
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.06342958717260393)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0634
# エポック 34/40
# ----------
# 訓練_loss: 0.0099
# mask_loss=0.29293819665908816
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  23  46   13    33  10   0.565217  0.282609  0.291173
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome   1  31    1    30   0   1.000000  0.032258  0.034205
# 4        thyroglobulin   1  30    0    30   1   0.000000  0.000000  0.000000
# 5  virus-like-particle   6  11    6     5   0   1.000000  0.545455  0.560440
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12654534104975884)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1265
# エポック 35/40
# ----------
# 訓練_loss: 0.0094
# mask_loss=0.1445441171526909
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  49  46   27    19  22    0.55102  0.586957  0.584713
# 1         beta-amylase   0  10    0    10   0    0.00000  0.000000  0.000000
# 2   beta-galactosidase   2  12    1    11   1    0.50000  0.083333  0.087629
# 3             ribosome   1  31    1    30   0    1.00000  0.032258  0.034205
# 4        thyroglobulin   0  30    0    30   0    0.00000  0.000000  0.000000
# 5  virus-like-particle  11  11   11     0   0    1.00000  1.000000  1.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.25631090559189584)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2563
# エポック 36/40
# ----------
# 訓練_loss: 0.0101
# mask_loss=0.138423453271389
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0  0.000000  0.000000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  4  11    4     7   0        1.0  0.363636  0.377778
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.053968253968253964)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0540
# エポック 37/40
# ----------
# 訓練_loss: 0.0091
# mask_loss=0.20338307842612266
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0  0.000000  0.00000
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.00000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.00000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.00000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.00000
# 5  virus-like-particle  6  11    6     5   0        1.0  0.545455  0.56044
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.08006279434850862)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0801
# エポック 38/40
# ----------
# 訓練_loss: 0.0093
# mask_loss=0.1405405320227146
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  6  46    6    40   0        1.0  0.130435  0.137466
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  9  11    9     2   0        1.0  0.818182  0.827027
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.13778476204352216)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1378
# エポック 39/40
# ----------
# 訓練_loss: 0.0093
# mask_loss=0.2600896775722504
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  5  46    4    42   1        0.8  0.086957  0.091768
# 1         beta-amylase  0  10    0    10   0        0.0  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0        0.0  0.000000  0.000000
# 3             ribosome  0  31    0    31   0        0.0  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0        0.0  0.000000  0.000000
# 5  virus-like-particle  6  11    6     5   0        1.0  0.545455  0.560440
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.09317249166873225)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0932
# エポック 40/40
# ----------
# 訓練_loss: 0.0090
# mask_loss=0.22687344998121262
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  9  46    6    40   3   0.666667  0.130435  0.136913
# 1         beta-amylase  0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  0  12    0    12   0   0.000000  0.000000  0.000000
# 3             ribosome  0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin  0  30    0    30   0   0.000000  0.000000  0.000000
# 5  virus-like-particle  8  11    8     3   0   1.000000  0.727273  0.739130
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12514902663720873)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1251
#
# 全エポックの結果:
# エポック 1: 損失: 1.4183, lb_score: 0.0000
# エポック 2: 損失: 0.7667, lb_score: 0.0089
# エポック 3: 損失: 0.3259, lb_score: 0.0540
# エポック 4: 損失: 0.1527, lb_score: 0.1113
# エポック 5: 損失: 0.0970, lb_score: 0.1102
# エポック 6: 損失: 0.0627, lb_score: 0.1751
# エポック 7: 損失: 0.0399, lb_score: 0.2261
# エポック 8: 損失: 0.0317, lb_score: 0.1415
# エポック 9: 損失: 0.0278, lb_score: 0.4006
# エポック 10: 損失: 0.0242, lb_score: 0.0000
# エポック 11: 損失: 0.0226, lb_score: 0.1073
# エポック 12: 損失: 0.0198, lb_score: 0.1825
# エポック 13: 損失: 0.0197, lb_score: 0.2039
# エポック 14: 損失: 0.0179, lb_score: 0.0407
# エポック 15: 損失: 0.0170, lb_score: 0.0801
# エポック 16: 損失: 0.0184, lb_score: 0.0000
# エポック 17: 損失: 0.0156, lb_score: 0.1736
# エポック 18: 損失: 0.0154, lb_score: 0.0000
# エポック 19: 損失: 0.0147, lb_score: 0.1612
# エポック 20: 損失: 0.0147, lb_score: 0.1407
# エポック 21: 損失: 0.0143, lb_score: 0.0305
# エポック 22: 損失: 0.0134, lb_score: 0.2164
# エポック 23: 損失: 0.0130, lb_score: 0.1499
# エポック 24: 損失: 0.0130, lb_score: 0.0097
# エポック 25: 損失: 0.0122, lb_score: 0.1168
# エポック 26: 損失: 0.0123, lb_score: 0.1354
# エポック 27: 損失: 0.0117, lb_score: 0.1249
# エポック 28: 損失: 0.0111, lb_score: 0.0273
# エポック 29: 損失: 0.0106, lb_score: 0.0671
# エポック 30: 損失: 0.0111, lb_score: 0.0531
# エポック 31: 損失: 0.0118, lb_score: 0.1215
# エポック 32: 損失: 0.0099, lb_score: 0.1339
# エポック 33: 損失: 0.0104, lb_score: 0.0634
# エポック 34: 損失: 0.0099, lb_score: 0.1265
# エポック 35: 損失: 0.0094, lb_score: 0.2563
# エポック 36: 損失: 0.0101, lb_score: 0.0540
# エポック 37: 損失: 0.0091, lb_score: 0.0801
# エポック 38: 損失: 0.0093, lb_score: 0.1378
# エポック 39: 損失: 0.0093, lb_score: 0.0932
# エポック 40: 損失: 0.0090, lb_score: 0.1251

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=6, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=1, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
#  0         apo-ferritin  74  36   33     3  41   0.445946  0.916667  0.863077
#  1         beta-amylase   0  21    0    21   0   0.000000  0.000000  0.000000
#  2   beta-galactosidase   2  24    1    23   1   0.500000  0.041667  0.044041
#  3             ribosome  68  65   47    18  21   0.691176  0.723077  0.721119
#  4        thyroglobulin   0  49    0    49   0   0.000000  0.000000  0.000000
#  5  virus-like-particle  14  13   13     0   1   0.928571  1.000000  0.995495
#
#     weight
#  0       1
#  1       0
#  2       2
#  3       1
#  4       2
#  5       1  ,
#  0.38111063624297575)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
# Out:
# 現在のセルまたは前のセルでコードを実行中に、カーネル (Kernel) がクラッシュしました。
#
# エラーの原因を特定するには、セル内のコードを確認してください。
#
# 詳細については<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a>をクリックします。
#
# 詳細については、Jupyter <a href='command:jupyter.viewOutput'>ログ</a> を参照してください。
