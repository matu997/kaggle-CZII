# %%
from helpers import *
from dataset import *
from model2_for46 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
DEBAG = False
#DEBAG = True

# %%
mask_size2 = {key: math.floor(value * 0.8) for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 0,
#  'apo-ferritin': 4,
#  'beta-amylase': 5,
#  'beta-galactosidase': 7,
#  'ribosome': 12,
#  'thyroglobulin': 10,
#  'virus-like-particle': 11}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (24, 184, 630, 630)
# (24, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start + random.randint(-stride//2, stride//2)
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) > 0:
                    self.indices.append((idx, start, end))

    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant"),
    
    # 7. ランダムな平行移動とスケール、回転を適用
    RandAffined(
        keys=["image", "label"],
        prob=0.5,  # 適用確率
        rotate_range=(0.1, 0.1, 0.1),  # 回転範囲 (ラジアン単位, 各軸: X, Y, Z)
        shear_range=(0.1, 0.1, 0.1),   # シアー範囲 (各軸: X, Y, Z)
        scale_range=(0.3, 0.3, 0.3),   # スケール範囲 (各軸: X, Y, Z)
        translate_range=(0, 109, 100),  # 平行移動範囲 (各軸: X, Y, Z)
        mode=("bilinear", "nearest"),  # 補間方法 (画像: bilinear, ラベル: nearest)
        padding_mode="border"  # 境界の埋め方
    ),
    
    # 8. ランダムコントラスト調整
    RandAdjustContrastd(keys=["image"], prob=0.5, gamma=(0.8, 1.2)),  # コントラストを80%~120%に変更
    RandGaussianNoised(
        keys=["image"],
        prob=0.5,  # 適用確率
        mean=0.5,  # ノイズの平均
        std=0.05   # ノイズの標準偏差
    ),
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 220
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 653430.0
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 260061.0

# %%
GPU_ID = 0
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:0

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 30
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/30
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.3262
# 検証_loss=1.5908870220184326
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  2  46    0    46   2        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/30
# ----------
# 訓練_loss: 0.8622
# 検証_loss=1.7773033380508423
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin     5  46    0    46     5   0.000000  0.000000
# 1         beta-amylase     1  10    0    10     1   0.000000  0.000000
# 2   beta-galactosidase  7490  12    3     9  7487   0.000401  0.250000
# 3             ribosome  3937  31    5    26  3932   0.001270  0.161290
# 4        thyroglobulin  9659  30   11    19  9648   0.001139  0.366667
# 5  virus-like-particle    10  11    4     7     6   0.400000  0.363636
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.006639       2
# 3  0.019174       1
# 4  0.018444       2
# 5  0.365591       1  , 0.062132975870429256)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0621
# エポック 3/30
# ----------
# 訓練_loss: 0.5931
# 検証_loss=2.122640907764435
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  1140  46    4    42  1136   0.003509  0.086957
# 1         beta-amylase   512  10    0    10   512   0.000000  0.000000
# 2   beta-galactosidase   986  12    3     9   983   0.003043  0.250000
# 3             ribosome   611  31   11    20   600   0.018003  0.354839
# 4        thyroglobulin   992  30    4    26   988   0.004032  0.133333
# 5  virus-like-particle    11  11    3     8     8   0.272727  0.272727
#
#     f-beta4  weight
# 0  0.036247       1
# 1  0.000000       0
# 2  0.043294       2
# 3  0.168925       1
# 4  0.046196       2
# 5  0.272727       1  , 0.09383976724946039)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0938
# エポック 4/30
# ----------
# 訓練_loss: 0.4547
# 検証_loss=2.0430733919143678
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   790  46    3    43   787   0.003797  0.065217
# 1         beta-amylase   419  10    0    10   419   0.000000  0.000000
# 2   beta-galactosidase   618  12    3     9   615   0.004854  0.250000
# 3             ribosome   236  31   19    12   217   0.080508  0.612903
# 4        thyroglobulin  1047  30    4    26  1043   0.003820  0.133333
# 5  virus-like-particle     8  11    8     3     0   1.000000  0.727273
#
#     f-beta4  weight
# 0  0.033421       1
# 1  0.000000       0
# 2  0.062963       2
# 3  0.441257       1
# 4  0.044532       2
# 5  0.739130       1  , 0.20411391747006588)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.2041
# エポック 5/30
# ----------
# 訓練_loss: 0.3874
# 検証_loss=2.631282615661621
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  202  46    0    46  202   0.000000  0.000000
# 1         beta-amylase   37  10    0    10   37   0.000000  0.000000
# 2   beta-galactosidase  213  12    0    12  213   0.000000  0.000000
# 3             ribosome   49  31    0    31   49   0.000000  0.000000
# 4        thyroglobulin  252  30    3    27  249   0.011905  0.100000
# 5  virus-like-particle    5  11    4     7    1   0.800000  0.363636
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.069672       2
# 5  0.375691       1  , 0.07357641000426982)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0736
# エポック 6/30
# ----------
# 訓練_loss: 0.3512
# 検証_loss=1.9817571640014648
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type      P   T  hit  miss     fp  precision    recall  \
# 0         apo-ferritin    734  46    0    46    734   0.000000  0.000000
# 1         beta-amylase   8931  10    0    10   8931   0.000000  0.000000
# 2   beta-galactosidase    552  12    0    12    552   0.000000  0.000000
# 3             ribosome   5920  31   10    21   5910   0.001689  0.322581
# 4        thyroglobulin  10201  30   13    17  10188   0.001274  0.433333
# 5  virus-like-particle     20  11   11     0      9   0.550000  1.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.026496       1
# 4  0.020691       2
# 5  0.954082       1  , 0.1459942550122649)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1460
# エポック 7/30
# ----------
# 訓練_loss: 0.3078
# 検証_loss=3.1788390636444093
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  138  46    8    38  130   0.057971  0.173913
# 1         beta-amylase   30  10    0    10   30   0.000000  0.000000
# 2   beta-galactosidase  111  12    0    12  111   0.000000  0.000000
# 3             ribosome   36  31    8    23   28   0.222222  0.258065
# 4        thyroglobulin   89  30    1    29   88   0.011236  0.033333
# 5  virus-like-particle   11  11    9     2    2   0.818182  0.818182
#
#     f-beta4  weight
# 0  0.155606       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.255639       1
# 4  0.029877       2
# 5  0.818182       1  , 0.18416875393637616)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1842
# エポック 8/30
# ----------
# 訓練_loss: 0.2864
# 検証_loss=3.1922971487045286
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  984  46    8    38  976   0.008130  0.173913
# 1         beta-amylase    5  10    0    10    5   0.000000  0.000000
# 2   beta-galactosidase  158  12    1    11  157   0.006329  0.083333
# 3             ribosome   27  31    0    31   27   0.000000  0.000000
# 4        thyroglobulin  341  30    2    28  339   0.005865  0.066667
# 5  virus-like-particle   19  11   10     1    9   0.526316  0.909091
#
#     f-beta4  weight
# 0  0.079070       1
# 1  0.000000       0
# 2  0.048571       2
# 3  0.000000       1
# 4  0.041413       2
# 5  0.871795       1  , 0.16154761693538244)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1615
# エポック 9/30
# ----------
# 訓練_loss: 0.2560
# 検証_loss=3.4033207654953004
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  147  46    5    41  142   0.034014  0.108696
# 1         beta-amylase    2  10    0    10    2   0.000000  0.000000
# 2   beta-galactosidase   53  12    0    12   53   0.000000  0.000000
# 3             ribosome   15  31    2    29   13   0.133333  0.064516
# 4        thyroglobulin  247  30    1    29  246   0.004049  0.033333
# 5  virus-like-particle   17  11   10     1    7   0.588235  0.909091
#
#     f-beta4  weight
# 0  0.096263       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.066536       1
# 4  0.023384       2
# 5  0.880829       1  , 0.15577078536429756)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1558
# エポック 10/30
# ----------
# 訓練_loss: 0.2498
# 検証_loss=3.4185046434402464
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  5025  46    5    41  5020   0.000995  0.108696
# 1         beta-amylase     0  10    0    10     0   0.000000  0.000000
# 2   beta-galactosidase   880  12    1    11   879   0.001136  0.083333
# 3             ribosome    10  31    0    31    10   0.000000  0.000000
# 4        thyroglobulin   147  30    0    30   147   0.000000  0.000000
# 5  virus-like-particle     8  11    8     3     0   1.000000  0.727273
#
#     f-beta4  weight
# 0  0.014754       1
# 1  0.000000       0
# 2  0.015858       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.739130       1  , 0.11222874794466979)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1122
# エポック 11/30
# ----------
# 訓練_loss: 0.2385
# 検証_loss=3.5648948431015013
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  266  46    6    40  260   0.022556  0.130435
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    6  12    0    12    6   0.000000  0.000000
# 3             ribosome   11  31    1    30   10   0.090909  0.032258
# 4        thyroglobulin   17  30    0    30   17   0.000000  0.000000
# 5  virus-like-particle   11  11    8     3    3   0.727273  0.727273
#
#     f-beta4  weight
# 0  0.101796       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.033531       1
# 4  0.000000       2
# 5  0.727273       1  , 0.12322852949292377)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1232
# エポック 12/30
# ----------
# 訓練_loss: 0.2402
# 検証_loss=4.307483434677124
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  20  46    8    38  12       0.40  0.173913  0.179894
# 1         beta-amylase   0  10    0    10   0       0.00  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1       0.00  0.000000  0.000000
# 3             ribosome   0  31    0    31   0       0.00  0.000000  0.000000
# 4        thyroglobulin   2  30    0    30   2       0.00  0.000000  0.000000
# 5  virus-like-particle   4  11    3     8   1       0.75  0.272727  0.283333
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0661753590325019)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0662
# エポック 13/30
# ----------
# 訓練_loss: 0.2080
# 検証_loss=4.548033237457275
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  32  46    2    44  30   0.062500  0.043478  0.044271
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  17  12    0    12  17   0.000000  0.000000  0.000000
# 3             ribosome   0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin  39  30    1    29  38   0.025641  0.033333  0.032755
# 5  virus-like-particle   4  11    4     7   0   1.000000  0.363636  0.377778
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.06965131548765942)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0697
# エポック 14/30
# ----------
# 訓練_loss: 0.1847
# 検証_loss=4.540573334693908
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  64  46    3    43  61   0.046875  0.065217  0.063750
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   2  12    0    12   2   0.000000  0.000000  0.000000
# 3             ribosome   0  31    0    31   0   0.000000  0.000000  0.000000
# 4        thyroglobulin  26  30    0    30  26   0.000000  0.000000  0.000000
# 5  virus-like-particle   6  11    5     6   1   0.833333  0.454545  0.467033
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.07582613814756671)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0758
# エポック 15/30
# ----------
# 訓練_loss: 0.1914
# 検証_loss=4.616901683807373
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  20  46    2    44  18       0.10  0.043478  0.044974
# 1         beta-amylase   0  10    0    10   0       0.00  0.000000  0.000000
# 2   beta-galactosidase   6  12    0    12   6       0.00  0.000000  0.000000
# 3             ribosome   1  31    0    31   1       0.00  0.000000  0.000000
# 4        thyroglobulin   8  30    0    30   8       0.00  0.000000  0.000000
# 5  virus-like-particle   4  11    3     8   1       0.75  0.272727  0.283333
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.04690098261526833)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0469
# エポック 16/30
# ----------
# 訓練_loss: 0.2056
# 検証_loss=4.776685357093811
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   3  46    0    46   3        0.0     0.0      0.0
# 1         beta-amylase   0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  14  12    0    12  14        0.0     0.0      0.0
# 3             ribosome  11  31    0    31  11        0.0     0.0      0.0
# 4        thyroglobulin  19  30    0    30  19        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 17/30
# ----------
# 訓練_loss: 0.1798
# 検証_loss=4.449841070175171
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  24  46    3    43  21   0.125000  0.065217  0.067105
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  28  12    0    12  28   0.000000  0.000000  0.000000
# 3             ribosome   4  31    0    31   4   0.000000  0.000000  0.000000
# 4        thyroglobulin  28  30    0    30  28   0.000000  0.000000  0.000000
# 5  virus-like-particle  11  11    7     4   4   0.636364  0.636364  0.636364
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10049555707450444)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1005
# エポック 18/30
# ----------
# 訓練_loss: 0.1849
# 検証_loss=4.419029021263123
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  74  46    8    38  66   0.108108  0.173913  0.167901
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  67  12    1    11  66   0.014925  0.083333  0.065637
# 3             ribosome   5  31    0    31   5   0.000000  0.000000  0.000000
# 4        thyroglobulin  84  30    1    29  83   0.011905  0.033333  0.030142
# 5  virus-like-particle  14  11    9     2   5   0.642857  0.818182  0.805263
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.16638888738286167)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1664
# エポック 19/30
# ----------
# 訓練_loss: 0.1789
# 検証_loss=5.040282201766968
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  2  46    0    46   2        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 20/30
# ----------
# 訓練_loss: 0.1744
# 検証_loss=4.7868064641952515
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  53  46    3    43  50   0.056604  0.065217  0.064639
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  15  12    0    12  15   0.000000  0.000000  0.000000
# 3             ribosome  75  31    0    31  75   0.000000  0.000000  0.000000
# 4        thyroglobulin  76  30    0    30  76   0.000000  0.000000  0.000000
# 5  virus-like-particle   1  11    0    11   1   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.009234111895708854)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0092
# エポック 21/30
# ----------
# 訓練_loss: 0.1679
# 検証_loss=4.561506295204163
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  802  46   16    30  786   0.019950  0.347826
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase   19  12    0    12   19   0.000000  0.000000
# 3             ribosome    7  31    1    30    6   0.142857  0.032258
# 4        thyroglobulin   32  30    0    30   32   0.000000  0.000000
# 5  virus-like-particle    4  11    4     7    0   1.000000  0.363636
#
#     f-beta4  weight
# 0  0.176853       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.033797       1
# 4  0.000000       2
# 5  0.377778       1  , 0.08406115005633628)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0841
# エポック 22/30
# ----------
# 訓練_loss: 0.1609
# 検証_loss=5.921272563934326
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  3  46    0    46   3        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 23/30
# ----------
# 訓練_loss: 0.1692
# location_df is empty,
# 検証_loss=5.214198589324951
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 24/30
# ----------
# 訓練_loss: 0.1668
# 検証_loss=5.030245304107666
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin  83  46    9    37  74   0.108434  0.195652  0.186813
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase  14  12    0    12  14   0.000000  0.000000  0.000000
# 3             ribosome  54  31    1    30  53   0.018519  0.032258  0.030909
# 4        thyroglobulin  25  30    0    30  25   0.000000  0.000000  0.000000
# 5  virus-like-particle  13  11    7     4   6   0.538462  0.636364  0.629630
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.12105027247884391)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1211
# エポック 25/30
# ----------
# 訓練_loss: 0.1581
# 検証_loss=4.808724355697632
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   7  46    2    44   5   0.285714  0.043478  0.045760
# 1         beta-amylase   0  10    0    10   0   0.000000  0.000000  0.000000
# 2   beta-galactosidase   7  12    0    12   7   0.000000  0.000000  0.000000
# 3             ribosome  29  31    6    25  23   0.206897  0.193548  0.194286
# 4        thyroglobulin  45  30    0    30  45   0.000000  0.000000  0.000000
# 5  virus-like-particle   6  11    5     6   1   0.833333  0.454545  0.467033
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.10101130171501252)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.1010
# エポック 26/30
# ----------
# 訓練_loss: 0.1582
# 検証_loss=5.647596144676209
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  4  46    0    46   4        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  4  12    0    12   4        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  3  30    0    30   3        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 27/30
# ----------
# 訓練_loss: 0.1510
# location_df is empty,
# 検証_loss=7.199254274368286
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 28/30
# ----------
# 訓練_loss: 0.1331
# 検証_loss=6.073979043960572
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  5  30    0    30   5        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 29/30
# ----------
# 訓練_loss: 0.1385
# 検証_loss=6.632551670074463
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  4  46    0    46   4        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 30/30
# ----------
# 訓練_loss: 0.1379
# 検証_loss=5.0866944789886475
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  162  46   25    21  137   0.154321  0.543478
# 1         beta-amylase    0  10    0    10    0   0.000000  0.000000
# 2   beta-galactosidase    0  12    0    12    0   0.000000  0.000000
# 3             ribosome    0  31    0    31    0   0.000000  0.000000
# 4        thyroglobulin    0  30    0    30    0   0.000000  0.000000
# 5  virus-like-particle    0  11    0    11    0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.473274       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.000000       1
# 4  0.000000       2
# 5  0.000000       1  , 0.06761056315622017)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0676
#
# 全エポックの結果:
# エポック 1: 損失: 1.3262, lb_score: 0.0000
# エポック 2: 損失: 0.8622, lb_score: 0.0621
# エポック 3: 損失: 0.5931, lb_score: 0.0938
# エポック 4: 損失: 0.4547, lb_score: 0.2041
# エポック 5: 損失: 0.3874, lb_score: 0.0736
# エポック 6: 損失: 0.3512, lb_score: 0.1460
# エポック 7: 損失: 0.3078, lb_score: 0.1842
# エポック 8: 損失: 0.2864, lb_score: 0.1615
# エポック 9: 損失: 0.2560, lb_score: 0.1558
# エポック 10: 損失: 0.2498, lb_score: 0.1122
# エポック 11: 損失: 0.2385, lb_score: 0.1232
# エポック 12: 損失: 0.2402, lb_score: 0.0662
# エポック 13: 損失: 0.2080, lb_score: 0.0697
# エポック 14: 損失: 0.1847, lb_score: 0.0758
# エポック 15: 損失: 0.1914, lb_score: 0.0469
# エポック 16: 損失: 0.2056, lb_score: 0.0000
# エポック 17: 損失: 0.1798, lb_score: 0.1005
# エポック 18: 損失: 0.1849, lb_score: 0.1664
# エポック 19: 損失: 0.1789, lb_score: 0.0000
# エポック 20: 損失: 0.1744, lb_score: 0.0092
# エポック 21: 損失: 0.1679, lb_score: 0.0841
# エポック 22: 損失: 0.1609, lb_score: 0.0000
# エポック 23: 損失: 0.1692, lb_score: 0.0000
# エポック 24: 損失: 0.1668, lb_score: 0.1211
# エポック 25: 損失: 0.1581, lb_score: 0.1010
# エポック 26: 損失: 0.1582, lb_score: 0.0000
# エポック 27: 損失: 0.1510, lb_score: 0.0000
# エポック 28: 損失: 0.1331, lb_score: 0.0000
# エポック 29: 損失: 0.1385, lb_score: 0.0000
# エポック 30: 損失: 0.1379, lb_score: 0.0676

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_99_9']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 64
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_99_9 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=0, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_99_9']
#  TS_99_9 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
#  0         apo-ferritin  7138  36    0    36  7138   0.000000  0.000000
#  1         beta-amylase     0  21    0    21     0   0.000000  0.000000
#  2   beta-galactosidase   354  24   17     7   337   0.048023  0.708333
#  3             ribosome   360  65    7    58   353   0.019444  0.107692
#  4        thyroglobulin   716  49   38    11   678   0.053073  0.775510
#  5  virus-like-particle   474  13   12     1   462   0.025316  0.923077
#
#      f-beta4  weight
#  0  0.000000       1
#  1  0.000000       0
#  2  0.391599       2
#  3  0.085000       1
#  4  0.430667       2
#  5  0.299120       1  ,
#  0.2898073428451084)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
