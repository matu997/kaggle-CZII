# %%
from helpers import *
from dataset import *
from model2_for48 import *
from czii_helper import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import random
import torchvision.transforms as T
import cv2
import math
import cc3d
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, NormalizeIntensityd, ToTensorD
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import precision_score, recall_score, f1_score
from monai.transforms import RandFlipd,RandRotated,RandZoomd,RandAffined,ResizeD,SpatialPadd,RandRotate90d,EnsureChannelFirstd,Orientationd,RandAdjustContrastd,RandGaussianNoised

# %%
#DEBAG = False
DEBAG = True

# %%
mask_size2 = {key: value  for key, value in mask_size.items()}
mask_size2
# Out:
# {'defolt': 1,
#  'apo-ferritin': 6,
#  'beta-amylase': 6.5,
#  'beta-galactosidase': 9,
#  'ribosome': 15,
#  'thyroglobulin': 13,
#  'virus-like-particle': 13.5}

# %%
MODE = 'local'
valid_dir = '../input/czii-cryo-et-object-identification/train'

cfg = dotdict(
    arch ='resnet34d',
    checkpoint=\
    '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00010164-extern.pth',
   # '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-aug-noise-00003956.pth',
       #  '/kaggle/input/hengck-czii-cryo-et-weights-01/resnet34d-00002300.pth',
       # '/kaggle/input/hengck-czii-cryo-et-weights-01/00003531.pth',
    threshold={ 
        'apo-ferritin': 0.05,
        'beta-amylase': 0.05,
        'beta-galactosidase': 0.05,
        'ribosome': 0.05,
        'thyroglobulin': 0.05,
        'virus-like-particle': 0.20,
    }, 
)

# %%
train_dir = '../input/czii-cryo-et-object-identification/train/static/ExperimentRuns/'
mask_dir = '../input/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/'

diff =["denoised","isonetcorrected","wbp","ctfdeconvolved"]
#diff =["denoised","isonetcorrected","wbp","ctfdeconvolved","denoised"]
#diff =["denoised"]

valid_id = ['TS_99_9', "TS_6_4", "TS_6_6", "TS_69_2", "TS_73_6", "TS_86_3"]
if DEBAG:
    valid_id = ["TS_5_4"]
test_id = ["TS_5_4"]

volumes = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.float32)
masks = np.empty((len(valid_id)*len(diff), 184, 630, 630), dtype=np.uint8)

n = 0
for idx in range(len(valid_id)):
    for diff_type in diff:
        data = read_diff_data(valid_id[idx], train_dir, diff_type)
        data = data.astype(np.float32)
        volumes[n, :, :, :] = data
        
        y = read_one_truth(valid_id[idx], mask_dir)
        mask_data = generate_mask(y, mask_size2)
        mask_data = mask_data.astype(np.uint8)
        masks[n, :, :, :] = mask_data
        n += 1
print(volumes.shape)
print(masks.shape)

print_slices(volumes, masks,dim=4,idx=0,depth=62)
# Out:
# (4, 184, 630, 630)
# (4, 184, 630, 630)

# %%
class VolumeDatasetSlices(Dataset):
    def __init__(self, vol_data, mask_data, patch_size=32, stride=16, transform=None):
        """
        Args:
            vol_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            mask_data (numpy.ndarray): 形状 (N, D, H, W) を想定 (例: (N, 184, 640, 640))
            patch_size (int): 切り出したい深さ方向のスライス数 (例: 32)
            stride (int): スライドウィンドウの移動量 (例: 16)
            transform (callable, optional): MONAIの辞書ベースTransformsなど
        """
        self.vol_data = vol_data
        self.mask_data = mask_data
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform

        self.indices = []
        # 全サンプルに対してスライスの開始・終了位置をまとめる
        for idx in range(len(vol_data)):
            d = vol_data[idx].shape[0]  # 深さ(D次元)の大きさ
            # 0, stride, 2*stride, ... のように動かしながら、patch_sizeぶん取り出せる範囲でスライス
            for start in range(0, d - patch_size + 1, stride):
                #ランダムに動かす
                start = start 
                end = start + patch_size
                # (サンプル番号, スライス開始, スライス終了) を記録
                #マスクが含まれるスライスのみを記録
                if np.sum(mask_data[idx][start:end]) >= 0:
                    self.indices.append((idx, start, end))
            start = d - patch_size
            end = d
            if np.sum(mask_data[idx][start:end]) >= 0:
                self.indices.append((idx, start, end))


    def __len__(self):
        # スライスの総数を返す
        return len(self.indices)

    def __getitem__(self, i):
        idx, start, end = self.indices[i]

        # （idx番目のボリューム・マスク） のうち, 深さ方向を [start:end] で切り出す
        volume = self.vol_data[idx][start:end]  # (patch_size, H, W)
        mask   = self.mask_data[idx][start:end] # (patch_size, H, W)

        data_dict = {"image": volume, "label": mask}
        if self.transform:
            data_dict = self.transform(data_dict)

        return data_dict["image"], data_dict["label"]

# --- 使い方の例 ---

# 変換の定義
# ToTensorD で numpy -> torch.Tensor に変換し、さらに正規化を行う
transforms = Compose([
    # 1. Tensor形式に変換
    ToTensorD(keys=["image", "label"]),
    
    # 2. チャンネルの次元を先頭に移動
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    
    # 3. データをRAS方向に揃える
    Orientationd(keys=["image", "label"], axcodes="RAS"),
        
    # 4. ランダム90度回転を適用
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[1, 2]),
    
    # 5. ランダム反転 (空間軸 0 に沿って)
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    
    # 6. パディングを適用して (32, 640, 640) に拡張
    SpatialPadd(keys=["image", "label"], spatial_size=(32, 640, 640), mode="constant", method="end"),
    
])

# %%
dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=transforms
)
raw_dataset = VolumeDatasetSlices(
    vol_data=volumes, 
    mask_data=masks, 
    patch_size=32, 
    stride=16,
    transform=None
)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
no_transform_dataloader = DataLoader(raw_dataset, batch_size=1, shuffle=True)
# データを取り出す
#i = 0
#print(len(dataloader))  # 6
#for volume, mask in dataloader:
#    i += 1
#    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
#    print_slices(volume[0], mask[0], dim=3, idx=0, depth=16)
#    if i == 3:
#        break

# %%
 #データを取り出す
i = 0
print(len(dataloader))  # 6
for volume, mask in dataloader:
    i += 1
    print(volume.shape, mask.shape)  # torch.Size([1, 32, 640, 640]) torch.Size([1, 32, 640, 640])
    print_slices(volume[0], mask[0], dim=4, idx=0, depth=12)
    #print_volume_slices(mask[0], dim=4, idx=0, depth=12)
    print(np.sum(mask[0].numpy()))
    if i == 2:
        break
# Out:
# 44
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1549315
# torch.Size([1, 1, 32, 640, 640]) torch.Size([1, 1, 32, 640, 640])
# 1209206

# %%
GPU_ID = 2
device = torch.device(f'cuda:{GPU_ID}' if torch.cuda.is_available() else 'cpu')
print(device)
net = Net(pretrained=True,cfg=None).to(device)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# cuda:2

# %%
global train_batch, test_batch

# %%
from torch.optim.lr_scheduler import LambdaLR

# 学習ループにCV計算を追加
num_epochs = 60
learning_rate = 1e-3
accumulation_steps = 4  # 勾配を累積するステップ数

optimizer = torch.optim.AdamW(
    net.parameters(),
    amsgrad=False,
    betas=(0.9, 0.999),
    capturable=False,
    differentiable=False,
    eps=1e-08,
    foreach=None,
    fused=None,
    lr=learning_rate,
    weight_decay=0.01
)

warmup_steps = 30
total_steps = num_epochs * len(dataloader)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))  # 線形ウォームアップ
    return 0.5 * (1. + np.cos(np.pi * (current_step - warmup_steps) / (total_steps - warmup_steps)))

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

scaler = torch.cuda.amp.GradScaler(init_scale=4096)

epoch_losses = []
cv_scores = []  # CVスコアの記録リスト
mask_losses = []

global_step = 0

for epoch in range(num_epochs):
    if epoch % 5 == 0:
        optimizer = torch.optim.AdamW(
            net.parameters(),
            amsgrad=False,
            betas=(0.9, 0.999),
            capturable=False,
            differentiable=False,
            eps=1e-08,
            foreach=None,
            fused=None,
            lr=learning_rate,
            weight_decay=0.01
        )

    print(f"エポック {epoch + 1}/{num_epochs}")
    print("-" * 10)

    net.train()
    running_loss = 0.0

    for i, (volumes, masks) in enumerate(dataloader):
        # 1次元削減
        volumes = volumes.squeeze(0)
        masks = masks.squeeze(0)

        batch, D, H, W = volumes.shape

        # パディング
        volumes = np.pad(volumes, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
        masks = np.pad(masks, [[0, 0], [0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

        if np.sum(masks) == 0:
            continue
        batch = {
            'image': torch.from_numpy(volumes).to(device).float(),
            'mask': torch.from_numpy(masks).to(device).long(),
        }

        #後で検証用に使うために保存
        train_batch = batch

        optimizer.zero_grad(set_to_none=True) if i % accumulation_steps == 0 else None

        with torch.amp.autocast(device_type="cuda", enabled=True):
            output = net(batch)
            loss = output['mask_loss'] / accumulation_steps  # 累積ステップ数でスケーリング

        scaler.scale(loss).backward()

        if (i + 1) % accumulation_steps == 0 or (i + 1) == len(dataloader):
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            global_step += 1

        running_loss += loss.item() * accumulation_steps  # スケーリングを戻して加算

    epoch_loss = running_loss / len(dataloader)
    epoch_losses.append(epoch_loss)
    print(f"訓練_loss: {epoch_loss:.4f}")

    # エポックごとにCVスコアを計算
    gb, lb_score, mask_loss = evaluate_cv(net, test_id, cfg, valid_dir, device, mask_size)  # test_id: 検証用データIDリスト
    cv_scores.append(lb_score)
    #lbスコアが最大のモデルを保存
    if lb_score == max(cv_scores):
        torch.save({'state_dict': net.state_dict()}, '../model/resnet34d.pth')
    mask_losses.append(np.mean(mask_loss))
    print(f"CVスコア: lb_score: {lb_score:.4f}")

# 最終的なスコアを出力
print("\n全エポックの結果:")
for epoch, (loss, lb_score) in enumerate(zip(epoch_losses, cv_scores), start=1):
    print(f"エポック {epoch}: 損失: {loss:.4f}, lb_score: {lb_score:.4f}")
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# エポック 1/60
# ----------
# Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# 訓練_loss: 1.8461
# 検証_loss=1.8200447450984607
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  90  46    0    46  90        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  15  11    0    11  15        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 2/60
# ----------
# 訓練_loss: 1.6254
# 検証_loss=1.7199925834482366
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    1  46    0    46    1        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome    2  31    0    31    2        0.0     0.0      0.0
# 4        thyroglobulin    1  30    0    30    1        0.0     0.0      0.0
# 5  virus-like-particle  769  11    0    11  769        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 3/60
# ----------
# 訓練_loss: 1.4871
# 検証_loss=1.650427135554227
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  2  31    0    31   2        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  1  11    0    11   1        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 4/60
# ----------
# 訓練_loss: 1.3686
# 検証_loss=1.6024589646946301
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  44  46    0    46  44        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  11  11    0    11  11        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 5/60
# ----------
# 訓練_loss: 1.2634
# 検証_loss=1.3339090238917957
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  10  11    0    11  10        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 6/60
# ----------
# 訓練_loss: 1.1694
# 検証_loss=1.2527615807273171
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   2  31    0    31   2        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  10  11    0    11  10        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 7/60
# ----------
# 訓練_loss: 1.0681
# 検証_loss=1.008257513696497
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin   1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  13  11    0    11  13        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 8/60
# ----------
# 訓練_loss: 0.9656
# 検証_loss=0.987253958528692
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 9/60
# ----------
# 訓練_loss: 0.8509
# 検証_loss=0.8636689348654314
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 10/60
# ----------
# 訓練_loss: 0.7333
# 検証_loss=0.706124874678525
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    2  46    0    46    2        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome  178  31    0    31  178        0.0     0.0      0.0
# 4        thyroglobulin   61  30    0    30   61        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 11/60
# ----------
# 訓練_loss: 0.6307
# 検証_loss=0.5357180373235182
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision  recall  f-beta4  \
# 0         apo-ferritin     1  46    0    46     1        0.0     0.0      0.0
# 1         beta-amylase     1  10    0    10     1        0.0     0.0      0.0
# 2   beta-galactosidase  3905  12    0    12  3905        0.0     0.0      0.0
# 3             ribosome   577  31    0    31   577        0.0     0.0      0.0
# 4        thyroglobulin     1  30    0    30     1        0.0     0.0      0.0
# 5  virus-like-particle     0  11    0    11     0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 12/60
# ----------
# 訓練_loss: 0.5365
# 検証_loss=0.5561706315387379
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin     4  46    0    46     4   0.000000  0.000000
# 1         beta-amylase     8  10    0    10     8   0.000000  0.000000
# 2   beta-galactosidase  2771  12    3     9  2768   0.001083  0.250000
# 3             ribosome  1335  31    3    28  1332   0.002247  0.096774
# 4        thyroglobulin     1  30    0    30     1   0.000000  0.000000
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.017212       2
# 3  0.027854       1
# 4  0.000000       2
# 5  0.000000       1  , 0.008896885941145443)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0089
# エポック 13/60
# ----------
# 訓練_loss: 0.4532
# 検証_loss=0.3608151240782304
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin   349  46    0    46   349   0.000000  0.000000
# 1         beta-amylase   149  10    0    10   149   0.000000  0.000000
# 2   beta-galactosidase  1035  12    0    12  1035   0.000000  0.000000
# 3             ribosome   934  31    5    26   929   0.005353  0.161290
# 4        thyroglobulin  1142  30    2    28  1140   0.001751  0.066667
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.000000       2
# 3  0.059441       1
# 4  0.020962       2
# 5  0.000000       1  , 0.014480587230278967)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0145
# エポック 14/60
# ----------
# 訓練_loss: 0.3793
# 検証_loss=0.33805989948186005
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  1882  46    0    46  1882   0.000000  0.000000
# 1         beta-amylase   434  10    0    10   434   0.000000  0.000000
# 2   beta-galactosidase  3962  12    4     8  3958   0.001010  0.333333
# 3             ribosome  3918  31    3    28  3915   0.000766  0.096774
# 4        thyroglobulin  1408  30    1    29  1407   0.000710  0.033333
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.000000       0
# 2  0.016370       2
# 3  0.011554       1
# 4  0.009004       2
# 5  0.000000       1  , 0.008900306948757949)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0089
# エポック 15/60
# ----------
# 訓練_loss: 0.3183
# 検証_loss=0.29303005066784943
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  4337  46    0    46  4337   0.000000  0.000000
# 1         beta-amylase  4759  10    5     5  4754   0.001051  0.500000
# 2   beta-galactosidase  2226  12    4     8  2222   0.001797  0.333333
# 3             ribosome  2625  31   16    15  2609   0.006095  0.516129
# 4        thyroglobulin  3703  30    5    25  3698   0.001350  0.166667
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#     f-beta4  weight
# 0  0.000000       1
# 1  0.017280       0
# 2  0.028122       2
# 3  0.087152       1
# 4  0.020320       2
# 5  0.000000       1  , 0.026291010418365807)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0263
# エポック 16/60
# ----------
# 訓練_loss: 0.2666
# 検証_loss=0.25101927464658563
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision    recall  \
# 0         apo-ferritin  3596  46    0    46  3596   0.000000  0.000000
# 1         beta-amylase   575  10    0    10   575   0.000000  0.000000
# 2   beta-galactosidase   288  12    0    12   288   0.000000  0.000000
# 3             ribosome   370  31    0    31   370   0.000000  0.000000
# 4        thyroglobulin  3832  30    4    26  3828   0.001044  0.133333
# 5  virus-like-particle     0  11    0    11     0   0.000000  0.000000
#
#    f-beta4  weight
# 0  0.00000       1
# 1  0.00000       0
# 2  0.00000       2
# 3  0.00000       1
# 4  0.01577       2
# 5  0.00000       1  , 0.0045056983832494025)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0045
# エポック 17/60
# ----------
# 訓練_loss: 0.2171
# 検証_loss=0.19791128418662332
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type     P   T  hit  miss    fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1458  46    0    46  1458        0.0     0.0      0.0
# 1         beta-amylase   641  10    0    10   641        0.0     0.0      0.0
# 2   beta-galactosidase   428  12    0    12   428        0.0     0.0      0.0
# 3             ribosome  1912  31    0    31  1912        0.0     0.0      0.0
# 4        thyroglobulin  1934  30    0    30  1934        0.0     0.0      0.0
# 5  virus-like-particle     0  11    0    11     0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 18/60
# ----------
# 訓練_loss: 0.1789
# 検証_loss=0.15049717304381457
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  f-beta4  \
# 0         apo-ferritin  171  46    0    46  171    0.00000  0.000000     0.00
# 1         beta-amylase  123  10    0    10  123    0.00000  0.000000     0.00
# 2   beta-galactosidase   96  12    0    12   96    0.00000  0.000000     0.00
# 3             ribosome  184  31    2    29  182    0.01087  0.064516     0.05
# 4        thyroglobulin  215  30    0    30  215    0.00000  0.000000     0.00
# 5  virus-like-particle    0  11    0    11    0    0.00000  0.000000     0.00
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0071428571428571435)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0071
# エポック 19/60
# ----------
# 訓練_loss: 0.1501
# 検証_loss=0.13509481806646695
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin   29  46    0    46   29        0.0     0.0      0.0
# 1         beta-amylase   66  10    0    10   66        0.0     0.0      0.0
# 2   beta-galactosidase    1  12    0    12    1        0.0     0.0      0.0
# 3             ribosome   22  31    0    31   22        0.0     0.0      0.0
# 4        thyroglobulin  843  30    0    30  843        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 20/60
# ----------
# 訓練_loss: 0.1284
# 検証_loss=0.1322386542504484
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  24  46    0    46  24        0.0     0.0      0.0
# 1         beta-amylase  12  10    0    10  12        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   2  31    0    31   2        0.0     0.0      0.0
# 4        thyroglobulin  25  30    0    30  25        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 21/60
# ----------
# 訓練_loss: 0.1118
# 検証_loss=0.1270537091927095
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  22  46    0    46  22        0.0     0.0      0.0
# 1         beta-amylase  28  10    0    10  28        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome   5  31    0    31   5        0.0     0.0      0.0
# 4        thyroglobulin  14  30    0    30  14        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 22/60
# ----------
# 訓練_loss: 0.0930
# 検証_loss=0.11184418912638318
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  2  46    0    46   2        0.0     0.0      0.0
# 1         beta-amylase  2  10    0    10   2        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  5  30    0    30   5        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 23/60
# ----------
# 訓練_loss: 0.0782
# 検証_loss=0.09597536447373303
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 24/60
# ----------
# 訓練_loss: 0.0653
# 検証_loss=0.09963523765856569
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin   11  46    0    46   11        0.0     0.0      0.0
# 1         beta-amylase    1  10    0    10    1        0.0     0.0      0.0
# 2   beta-galactosidase    2  12    0    12    2        0.0     0.0      0.0
# 3             ribosome  305  31    0    31  305        0.0     0.0      0.0
# 4        thyroglobulin  338  30    0    30  338        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 25/60
# ----------
# 訓練_loss: 0.0571
# 検証_loss=0.08975480937144974
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision    recall   f-beta4  \
# 0         apo-ferritin   1  46    0    46   1   0.000000  0.000000  0.000000
# 1         beta-amylase   5  10    0    10   5   0.000000  0.000000  0.000000
# 2   beta-galactosidase   1  12    0    12   1   0.000000  0.000000  0.000000
# 3             ribosome  13  31    0    31  13   0.000000  0.000000  0.000000
# 4        thyroglobulin  70  30    2    28  68   0.028571  0.066667  0.061818
# 5  virus-like-particle   0  11    0    11   0   0.000000  0.000000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.01766233766233766)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0177
# エポック 26/60
# ----------
# 訓練_loss: 0.0548
# 検証_loss=0.09034088194708932
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase   1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase   1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  23  31    0    31  23        0.0     0.0      0.0
# 4        thyroglobulin   3  30    0    30   3        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 27/60
# ----------
# 訓練_loss: 0.0458
# 検証_loss=0.08922859772362492
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  2  10    0    10   2        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  2  30    0    30   2        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 28/60
# ----------
# 訓練_loss: 0.0395
# 検証_loss=0.08888742319223555
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision   recall   f-beta4  \
# 0         apo-ferritin  0  46    0    46   0      0.000  0.00000  0.000000
# 1         beta-amylase  1  10    0    10   1      0.000  0.00000  0.000000
# 2   beta-galactosidase  0  12    0    12   0      0.000  0.00000  0.000000
# 3             ribosome  8  31    5    26   3      0.625  0.16129  0.168651
# 4        thyroglobulin  6  30    0    30   6      0.000  0.00000  0.000000
# 5  virus-like-particle  0  11    0    11   0      0.000  0.00000  0.000000
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.024092970521541947)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0241
# エポック 29/60
# ----------
# 訓練_loss: 0.0367
# 検証_loss=0.09206581776115028
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 30/60
# ----------
# 訓練_loss: 0.0333
# 検証_loss=0.09031329765407876
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  1  46    0    46   1        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 31/60
# ----------
# 訓練_loss: 0.0361
# 検証_loss=0.10148178491826085
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin  169  46    0    46  169        0.0     0.0      0.0
# 1         beta-amylase   10  10    0    10   10        0.0     0.0      0.0
# 2   beta-galactosidase    5  12    0    12    5        0.0     0.0      0.0
# 3             ribosome  156  31    0    31  156        0.0     0.0      0.0
# 4        thyroglobulin  184  30    0    30  184        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 32/60
# ----------
# 訓練_loss: 0.0322
# 検証_loss=0.11027379613369703
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  4  46    0    46   4        0.0     0.0      0.0
# 1         beta-amylase  1  10    0    10   1        0.0     0.0      0.0
# 2   beta-galactosidase  1  12    0    12   1        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  5  30    0    30   5        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 33/60
# ----------
# 訓練_loss: 0.0291
# 検証_loss=0.10531626218421893
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 34/60
# ----------
# 訓練_loss: 0.0281
# 検証_loss=0.10922370241446928
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 35/60
# ----------
# 訓練_loss: 0.0278
# location_df is empty,
# 検証_loss=0.10639884386380966
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 36/60
# ----------
# 訓練_loss: 0.0303
# 検証_loss=0.09713082015514374
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 37/60
# ----------
# 訓練_loss: 0.0270
# location_df is empty,
# 検証_loss=0.12073445729699663
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 38/60
# ----------
# 訓練_loss: 0.0253
# location_df is empty,
# 検証_loss=0.11036913008005782
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 39/60
# ----------
# 訓練_loss: 0.0239
# 検証_loss=0.10776745930144732
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 40/60
# ----------
# 訓練_loss: 0.0228
# location_df is empty,
# 検証_loss=0.12608219454572958
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 41/60
# ----------
# 訓練_loss: 0.0279
# 検証_loss=0.12871926777403464
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type   P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin   0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase   0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase   0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  15  31    0    31  15        0.0     0.0      0.0
# 4        thyroglobulin   0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle   0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 42/60
# ----------
# 訓練_loss: 0.0243
# 検証_loss=0.1721762710155665
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 43/60
# ----------
# 訓練_loss: 0.0216
# location_df is empty,
# 検証_loss=0.1339312900143506
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 44/60
# ----------
# 訓練_loss: 0.0205
# location_df is empty,
# 検証_loss=0.11685305779842152
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 45/60
# ----------
# 訓練_loss: 0.0196
# location_df is empty,
# 検証_loss=0.13320229581387882
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 46/60
# ----------
# 訓練_loss: 0.0222
# 検証_loss=0.12764641147805378
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  3  31    0    31   3        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 47/60
# ----------
# 訓練_loss: 0.0207
# 検証_loss=0.1322880113624375
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  2  31    0    31   2        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 48/60
# ----------
# 訓練_loss: 0.0191
# 検証_loss=0.13476430021480404
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 49/60
# ----------
# 訓練_loss: 0.0177
# 検証_loss=0.06424041210398586
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision    recall  \
# 0         apo-ferritin  103  46    3    43  100   0.029126  0.065217
# 1         beta-amylase    1  10    0    10    1   0.000000  0.000000
# 2   beta-galactosidase   70  12    1    11   69   0.014286  0.083333
# 3             ribosome   72  31   21    10   51   0.291667  0.677419
# 4        thyroglobulin   88  30   18    12   70   0.204545  0.600000
# 5  virus-like-particle   53  11   11     0   42   0.207547  1.000000
#
#     f-beta4  weight
# 0  0.060787       1
# 1  0.000000       0
# 2  0.064885       2
# 3  0.628521       1
# 4  0.538732       2
# 5  0.816594       1  , 0.3875910635852834)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.3876
# エポック 50/60
# ----------
# 訓練_loss: 0.0161
# location_df is empty,
# 検証_loss=0.1351141992702403
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 51/60
# ----------
# 訓練_loss: 0.0231
# 検証_loss=0.14383626481073655
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 52/60
# ----------
# 訓練_loss: 0.0183
# 検証_loss=0.13185973035764287
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type    P   T  hit  miss   fp  precision  recall  f-beta4  \
# 0         apo-ferritin    0  46    0    46    0        0.0     0.0      0.0
# 1         beta-amylase    0  10    0    10    0        0.0     0.0      0.0
# 2   beta-galactosidase    0  12    0    12    0        0.0     0.0      0.0
# 3             ribosome  272  31    0    31  272        0.0     0.0      0.0
# 4        thyroglobulin    0  30    0    30    0        0.0     0.0      0.0
# 5  virus-like-particle    0  11    0    11    0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 53/60
# ----------
# 訓練_loss: 0.0163
# 検証_loss=0.1410105683925477
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  7  31    0    31   7        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 54/60
# ----------
# 訓練_loss: 0.0150
# location_df is empty,
# 検証_loss=0.14993586030852218
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 55/60
# ----------
# 訓練_loss: 0.0141
# location_df is empty,
# 検証_loss=0.14661709201225842
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 56/60
# ----------
# 訓練_loss: 0.0192
# 検証_loss=0.13484634601362896
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  0  31    0    31   0        0.0     0.0      0.0
# 4        thyroglobulin  1  30    0    30   1        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 57/60
# ----------
# 訓練_loss: 0.0151
# location_df is empty,
# 検証_loss=0.139651198183525
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 58/60
# ----------
# 訓練_loss: 0.0134
# location_df is empty,
# 検証_loss=0.1405365146611902
# particle_type not found, skipping groupby.
# CVスコア: lb_score: 0.0000
# エポック 59/60
# ----------
# 訓練_loss: 0.0121
# 検証_loss=0.14367337089920926
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
# エポック 60/60
# ----------
# 訓練_loss: 0.0108
# 検証_loss=0.14958323990206487
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
# 0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
# 1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
# 2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
# 3             ribosome  1  31    0    31   1        0.0     0.0      0.0
# 4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
# 5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#    weight
# 0       1
# 1       0
# 2       2
# 3       1
# 4       2
# 5       1  , 0.0)
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# CVスコア: lb_score: 0.0000
#
# 全エポックの結果:
# エポック 1: 損失: 1.8461, lb_score: 0.0000
# エポック 2: 損失: 1.6254, lb_score: 0.0000
# エポック 3: 損失: 1.4871, lb_score: 0.0000
# エポック 4: 損失: 1.3686, lb_score: 0.0000
# エポック 5: 損失: 1.2634, lb_score: 0.0000
# エポック 6: 損失: 1.1694, lb_score: 0.0000
# エポック 7: 損失: 1.0681, lb_score: 0.0000
# エポック 8: 損失: 0.9656, lb_score: 0.0000
# エポック 9: 損失: 0.8509, lb_score: 0.0000
# エポック 10: 損失: 0.7333, lb_score: 0.0000
# エポック 11: 損失: 0.6307, lb_score: 0.0000
# エポック 12: 損失: 0.5365, lb_score: 0.0089
# エポック 13: 損失: 0.4532, lb_score: 0.0145
# エポック 14: 損失: 0.3793, lb_score: 0.0089
# エポック 15: 損失: 0.3183, lb_score: 0.0263
# エポック 16: 損失: 0.2666, lb_score: 0.0045
# エポック 17: 損失: 0.2171, lb_score: 0.0000
# エポック 18: 損失: 0.1789, lb_score: 0.0071
# エポック 19: 損失: 0.1501, lb_score: 0.0000
# エポック 20: 損失: 0.1284, lb_score: 0.0000
# エポック 21: 損失: 0.1118, lb_score: 0.0000
# エポック 22: 損失: 0.0930, lb_score: 0.0000
# エポック 23: 損失: 0.0782, lb_score: 0.0000
# エポック 24: 損失: 0.0653, lb_score: 0.0000
# エポック 25: 損失: 0.0571, lb_score: 0.0177
# エポック 26: 損失: 0.0548, lb_score: 0.0000
# エポック 27: 損失: 0.0458, lb_score: 0.0000
# エポック 28: 損失: 0.0395, lb_score: 0.0241
# エポック 29: 損失: 0.0367, lb_score: 0.0000
# エポック 30: 損失: 0.0333, lb_score: 0.0000
# エポック 31: 損失: 0.0361, lb_score: 0.0000
# エポック 32: 損失: 0.0322, lb_score: 0.0000
# エポック 33: 損失: 0.0291, lb_score: 0.0000
# エポック 34: 損失: 0.0281, lb_score: 0.0000
# エポック 35: 損失: 0.0278, lb_score: 0.0000
# エポック 36: 損失: 0.0303, lb_score: 0.0000
# エポック 37: 損失: 0.0270, lb_score: 0.0000
# エポック 38: 損失: 0.0253, lb_score: 0.0000
# エポック 39: 損失: 0.0239, lb_score: 0.0000
# エポック 40: 損失: 0.0228, lb_score: 0.0000
# エポック 41: 損失: 0.0279, lb_score: 0.0000
# エポック 42: 損失: 0.0243, lb_score: 0.0000
# エポック 43: 損失: 0.0216, lb_score: 0.0000
# エポック 44: 損失: 0.0205, lb_score: 0.0000
# エポック 45: 損失: 0.0196, lb_score: 0.0000
# エポック 46: 損失: 0.0222, lb_score: 0.0000
# エポック 47: 損失: 0.0207, lb_score: 0.0000
# エポック 48: 損失: 0.0191, lb_score: 0.0000
# エポック 49: 損失: 0.0177, lb_score: 0.3876
# エポック 50: 損失: 0.0161, lb_score: 0.0000
# エポック 51: 損失: 0.0231, lb_score: 0.0000
# エポック 52: 損失: 0.0183, lb_score: 0.0000
# エポック 53: 損失: 0.0163, lb_score: 0.0000
# エポック 54: 損失: 0.0150, lb_score: 0.0000
# エポック 55: 損失: 0.0141, lb_score: 0.0000
# エポック 56: 損失: 0.0192, lb_score: 0.0000
# エポック 57: 損失: 0.0151, lb_score: 0.0000
# エポック 58: 損失: 0.0134, lb_score: 0.0000
# エポック 59: 損失: 0.0121, lb_score: 0.0000
# エポック 60: 損失: 0.0108, lb_score: 0.0000

# %%
out = output['particle']
out = out.squeeze(0).detach().cpu().numpy()

# %%
print_volume_slices(out, dim=4, idx=5, depth=12)

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# 左側の軸（Training LossとMask Loss）
ax1.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o', label='Training Loss', color='blue')
ax1.plot(range(1, len(mask_losses) + 1), mask_losses, marker='x', label='Mask Loss', color='green')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_yscale('log')  # 対数スケール（任意）
ax1.set_ylim(0.001, 10) 
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 右側の軸（CV Score）
ax2 = ax1.twinx()
ax2.plot(range(1, len(cv_scores) + 1), cv_scores, marker='x', label='CV Score', color='red')
ax2.set_ylabel('CV Score', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 0.8)

# 凡例を追加
fig.legend(loc="upper right", bbox_to_anchor=(1, 0.9))
plt.title('Training Loss, Mask Loss, and CV Score Over Epochs')

#薄い線を追加
for i in range(1, len(epoch_losses)):
    plt.axvline(i, color='gray', linestyle='--', linewidth=0.5)

# グラフ表示
plt.show()

# %%
test_id = ['TS_5_4']
net.eval()
submit_df = []

for i, id in enumerate(test_id):
    print(f"Evaluating CV for ID {id} ({i+1}/{len(test_id)})")
    volume = read_one_data(id, static_dir=f'{valid_dir}/static/ExperimentRuns')
    y = read_one_truth(id, f'{valid_dir}/overlay/ExperimentRuns')
    mask = generate_mask(y, mask_size)
    
    D, H, W = volume.shape

    probability = np.zeros((7, D, H, W), dtype=np.float32)
    count = np.zeros((7, D, H, W), dtype=np.float32)
    pad_volume = np.pad(volume, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)
    pad_mask = np.pad(mask, [[0, 0], [0, 640 - H], [0, 640 - W]], mode='constant', constant_values=0)

    num_slice = 32
    mask_loss =[]
    zz = list(range(0, D - num_slice, num_slice // 2)) + [D - num_slice]
    for z in zz:
        image = pad_volume[z:z + num_slice]
        mask = pad_mask[z:z + num_slice]
        batch = {
            'image': torch.from_numpy(image).unsqueeze(0).to(device).float(),
            'mask': torch.from_numpy(mask).unsqueeze(0).to(device).long(),
        }
        test_batch = batch
        with torch.amp.autocast(device_type="cuda", enabled=True):
            with torch.no_grad():
                output = net(batch)

        #valid loglossを表示
        mask_loss.append(output['mask_loss'].item())

        prob = output['particle'][0].cpu().numpy()
        probability[:, z:z + num_slice] += prob[:, :, :H, :W]
        count[:, z:z + num_slice] += 1

    probability = probability / (count + 0.0001)
# Out:
# Evaluating CV for ID TS_5_4 (1/1)

# %%
print_volume_slices(probability, dim=4, idx=1, depth=65)

# %%
location = probability_to_location(probability, cfg)
submit_df=location_to_df(location)
submit_df.insert(loc=0, column='experiment', value=id)
compute_lb(submit_df, f'{valid_dir}/overlay/ExperimentRuns')
# Out:
# ['TS_5_4']
#  TS_5_4 virus-like-particle
# (         particle_type  P   T  hit  miss  fp  precision  recall  f-beta4  \
#  0         apo-ferritin  0  46    0    46   0        0.0     0.0      0.0
#  1         beta-amylase  0  10    0    10   0        0.0     0.0      0.0
#  2   beta-galactosidase  0  12    0    12   0        0.0     0.0      0.0
#  3             ribosome  1  31    0    31   1        0.0     0.0      0.0
#  4        thyroglobulin  0  30    0    30   0        0.0     0.0      0.0
#  5  virus-like-particle  0  11    0    11   0        0.0     0.0      0.0
#
#     weight
#  0       1
#  1       0
#  2       2
#  3       1
#  4       2
#  5       1  ,
#  0.0)

# %%
image = batch['image'][0].cpu().numpy()
mask = batch['mask'][0].cpu().numpy()

print_slices(image, mask, dim=3, idx=0, depth=0)
